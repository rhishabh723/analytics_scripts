# %%
# PRIMARY
"ATL":"#C8102E",
"BKN":"707372",
"BOS":"#007A33",
"BUF":"#418FDE",
"CHA":"#00778B",
"CHI":"#BA0C2F",
"CLE":"#6F263D",
"DAL":"#0050B5",
"DEN":"#1d428a",
"DET":"#1D4289",
"GSW":"#1D4289",
"HOU":"#BA0C2F",
"IND":"#041E42",
"LAC":"#0C2340",
"LAL":"#6a00ed",
"MEM":"#0C2340",
"MIA":"#862633",
"MIL":"#2C5234",
"MIN":"#236192",
"NOP":"#85714d",
"NYK":"#FF8200",
"OKC":"#0072CE",
"ORL":"#0057B7",
"PHI":"#1D4289",
"PHX":"#e56020",
"POR":"#C8102E",
"SAC":"#965ddd",
"SAS":"#9EA2A2",
"SEA":"#00653A",
"TOR":"#C8102E",
"UTA":"#0C2340",
"WAS":"#C8102E"

# PRIMARY
"Hawks":"#C8102E",
"Bobcats":"#E35205",
"Nets":"#707372",
"Celtics":"#007A33",
"SuperSonics":"#00653A",
"Hornets":"#00778B",
"Braves":"#418FDE",
"Bulls":"#BA0C2F",
"Cavaliers":"#6F263D",
"Mavericks":"#0050B5",
"Nuggets":"#1d428a",
"Pistons":"#1D4289",
"Warriors":"#1D4289",
"Rockets":"#BA0C2F",
"Pacers":"#041E42",
"Clippers":"#0C2340",
"Lakers":"#6a00ed",
"Grizzlies":"#0C2340",
"Heat":"#862633",
"Bucks":"#2C5234",
"Timberwolves":"#236192",
"Pelicans":"#85714d",
"Knicks":"#FF8200",
"Thunder":"#0072CE",
"Magic":"#0057B7",
"76ers":"#1D4289",
"Suns":"#e56020",
"Trail Blazers":"#C8102E",
"Kings":"#965ddd",
"Spurs":"#9EA2A2",
"Raptors":"#C8102E",
"Jazz":"#0C2340",
"Wizards":"#C8102E",
"Royals":"#003DA5",
"Bullets":"#C8102E"

# PRIMARY
"Atlanta Hawks":"#C8102E",
"Charlotte Bobcats":"#E35205",
"Brooklyn Nets":"#707372",
"Boston Celtics":"#007A33",
"Seattle SuperSonics":"#00653A",
"Charlotte Hornets":"#00778B",
"Buffalo Braves":"#418FDE",
"Chicago Bulls":"#BA0C2F",
"Cleveland Cavaliers":"#6F263D",
"Dallas Mavericks":"#0050B5",
"Denver Nuggets":"#1d428a",
"Detroit Pistons":"#1D4289",
"Golden State Warriors":"#1D4289",
"Houston Rockets":"#BA0C2F",
"Indiana Pacers":"#041E42",
"Los Angeles Clippers":"#0C2340",
"Los Angeles Lakers":"#6a00ed",
"Memphis Grizzlies":"#0C2340",
"Miami Heat":"#862633",
"Milwaukee Bucks":"#2C5234",
"Minnesota Timberwolves":"#236192",
"New Orleans Pelicans":"#85714d",
"New York Knicks":"#FF8200",
"Oklahoma City Thunder":"#0072CE",
"Orlando Magic":"#0057B7",
"Philadelphia 76ers":"#1D4289",
"Phoenix Suns":"#e56020",
"Portland Trail Blazers":"#C8102E",
"Sacramento Kings":"#965ddd",
"San Antonio Spurs":"#9EA2A2",
"Toronto Raptors":"#C8102E",
"Utah Jazz":"#0C2340",
"Washingotn Wizards":"#C8102E",
"Rochester Royals":"#003DA5",
"Washington Bullets":"#C8102E"

# %%
# SECONDARY
"ATL":"#FFC72C",
"BKN":"373A36",
"BOS":"#007A33",
"BUF":"#418FDE",
"CHA":"#211747",
"CHI":"#BA0C2F",
"CLE":"#B9975B",
"DAL":"#0C2340",
"DEN":"#862633",
"DET":"#C8102E",
"GSW":"#FFC72C",
"HOU":"#BA0C2F",
"IND":"#FFC72C",
"LAC":"#C8102E",
"LAL":"#FFC72C",
"MEM":"#7D9CC0",
"MIA":"#FFA400",
"MIL":"#DDCBA4",
"MIN":"#236192",
"NOP":"#B9975B",
"NYK":"#1D4289",
"OKC":"#F9423A",
"ORL":"#0057B7",
"PHI":"#C8102E",
"PHX":"#CB6015",
"POR":"#C8102E",
"SAC":"#707372",
"SAS":"#9EA2A2",
"SEA":"#00653A",
"TOR":"#330072",
"UTA":"#572C5F",
"WAS":"#C8102E"

# SECONDARY
"Hawks":"#FFC72C",
"Bobcats":"#E35205",
"Nets":"#373A36",
"Celtics":"#007A33",
"SuperSonics":"#00653A",
"Hornets":"#211747",
"Braves":"#418FDE",
"Bulls":"#BA0C2F",
"Cavaliers":"#B9975B",
"Mavericks":"#0C2340",
"Nuggets":"#862633",
"Pistons":"#C8102E",
"Warriors":"#FFC72C",
"Rockets":"#BA0C2F",
"Pacers":"#FFC72C",
"Clippers":"#C8102E",
"Lakers":"#FFC72C",
"Grizzlies":"#7D9CC0",
"Heat":"#FFA400",
"Bucks":"#DDCBA4",
"Timberwolves":"#236192",
"Pelicans":"#B9975B",
"Knicks":"#1D4289",
"Thunder":"#F9423A",
"Magic":"#0057B7",
"76ers":"#C8102E",
"Suns":"#CB6015",
"Trail Blazers":"#C8102E",
"Kings":"#707372",
"Spurs":"#9EA2A2",
"Raptors":"#330072",
"Jazz":"#572C5F",
"Wizards":"#C8102E",
"Royals":"#003DA5",
"Bullets":"#D50032"

# %%
#Primary
def team_color(team):
    if team =="Hawks":
        return "#C8102E"
    elif team =="Mavericks":
        return '#0050B5'
    elif team =="Grizzlies":
        return '#0C2340'
    elif team =="Heat":
        return '#862633'
    elif team =="Nuggets":
        return '#1d428a'
    elif team =="Pistons":
        return '#1D4289'
    elif team =="Warriors":
        return '#1D4289'
    elif team =="Rockets":
        return '#BA0C2F'
    elif team =="Pacers":
        return '#041E42'
    elif team =="Clippers":
        return '#0C2340'
    elif team =="Lakers":
        return '#330072'
    elif team =="Trail Blazers":
        return '#C8102E'
    elif team =="Suns":
        return '#e56020'
    elif team =="76ers":
        return '#1D4289'
    elif team =="Magic":
        return '#0057B7'
    elif team =="Thunder":
        return '#0072CE'
    elif team =="Knicks":
        return '#FF8200'
    elif team =="Pelicans":
        return '#85714d'
    elif team =="Timberwolves":
        return '#236192'
    elif team =="Bucks":
        return '#2C5234'
    elif team =="Bobcats":
        return '#E35205'
    elif team =="Nets":
        return '#707372'
    elif team =="Celtics":
        return '#007A33'
    elif team =="SuperSonics":
        return '#00653A'
    elif team =="Hornets":
        return '#00778B'
    elif team =="Braves":
        return '#418FDE'
    elif team =="Bulls":
        return '#BA0C2F'       
    elif team =="Cavaliers":
        return '#6F263D'
    elif team =="Bullets":
        return '#C8102E'
    elif team =="Royals":
        return '#003DA5'
    elif team =="Wizards":
        return '#C8102E'
    elif team =="Jazz":
        return '#0C2340' 
    elif team =="Raptors":
        return '#C8102E'
    elif team =="Spurs":
        return '#9EA2A2'
    elif team =="Kings":
        return '#965ddd'                  
    else:
        return '#3860C6'
    

    #Primary
def team_color(team):
    if team =="ATL":
        return "#C8102E"
    elif team =="DAL":
        return '#0050B5'
    elif team =="MEM":
        return '#0C2340'
    elif team =="MIA":
        return '#862633'
    elif team =="DEN":
        return '#1d428a'
    elif team =="DET":
        return '#1D4289'
    elif team =="GSW":
        return '#1D4289'
    elif team =="HOU":
        return '#BA0C2F'
    elif team =="IND":
        return '#041E42'
    elif team =="LAC":
        return '#0C2340'
    elif team =="LAL":
        return '#330072'
    elif team =="POR":
        return '#C8102E'
    elif team =="PHX":
        return '#e56020'
    elif team =="PHI":
        return '#1D4289'
    elif team =="ORL":
        return '#0057B7'
    elif team =="OKC":
        return '#0072CE'
    elif team =="NYK":
        return '#FF8200'
    elif team =="NOP":
        return '#85714d'
    elif team =="MIN":
        return '#236192'
    elif team =="MIL":
        return '#2C5234'
    elif team =="BKN":
        return '#707372'
    elif team =="BOS":
        return '#007A33'
    elif team =="SEA":
        return '#00653A'
    elif team =="CHA":
        return '#00778B'
    elif team =="BUF":
        return '#418FDE'
    elif team =="CHI":
        return '#BA0C2F'       
    elif team =="CLE":
        return '#6F263D'
    elif team =="WAS":
        return '#C8102E'
    elif team =="UTA":
        return '#0C2340' 
    elif team =="TOR":
        return '#C8102E'
    elif team =="SAS":
        return '#9EA2A2'
    elif team =="SAC":
        return '#965ddd'                  
    else:
        return '#3860C6'

# %%
#Secondary
def team_color(team):
    if team =="Hawks":
        return "#FFC72C"
    elif team =="Mavericks":
        return '#0C2340'
    elif team =="Grizzlies":
        return '#7D9CC0'
    elif team =="Heat":
        return '#FFA400'
    elif team =="Nuggets":
        return '#862633'
    elif team =="Pistons":
        return '#C8102E'
    elif team =="Warriors":
        return '#FFC72C'
    elif team =="Rockets":
        return '#BA0C2F'
    elif team =="Pacers":
        return '#FFC72C'
    elif team =="Clippers":
        return '#C8102E'
    elif team =="Lakers":
        return '#FFC72C'
    elif team =="Trail Blazers":
        return '#C8102E'
    elif team =="Suns":
        return '#CB6015'
    elif team =="76ers":
        return '#C8102E'
    elif team =="Magic":
        return '#0057B7'
    elif team =="Thunder":
        return '#F9423A'
    elif team =="Knicks":
        return '#1D4289'
    elif team =="Pelicans":
        return '#B9975B'
    elif team =="Timberwolves":
        return '#236192'
    elif team =="Bucks":
        return '#DDCBA4'
    elif team =="Bobcats":
        return '#E35205'
    elif team =="Nets":
        return '#373A36'
    elif team =="Celtics":
        return '#007A33'
    elif team =="SuperSonics":
        return '#00653A'
    elif team =="Hornets":
        return '#211747'
    elif team =="Braves":
        return '#418FDE'
    elif team =="Bulls":
        return '#BA0C2F'       
    elif team =="Cavaliers":
        return '#B9975B'
    elif team =="Bullets":
        return '#D50032'
    elif team =="Royals":
        return '#003DA5'
    elif team =="Wizards":
        return '#C8102E'
    elif team =="Jazz":
        return '#572C5F' 
    elif team =="Raptors":
        return '#330072'
    elif team =="Spurs":
        return '#9EA2A2'
    elif team =="Kings":
        return '#707372'                  
    else:
        return '#3860C6'
    

    def team_color(team):
    if team =="Atlanta Hawks":
        return "#C8102E"
    elif team =="Dallas Mavericks":
        return '#0050B5'
    elif team =="Memphis Grizzlies":
        return '#0C2340'
    elif team =="Miami Heat":
        return '#862633'
    elif team =="Denver Nuggets":
        return '#0C2340'
    elif team =="Detroit Pistons":
        return '#1D4289'
    elif team =="Golden State Warriors":
        return '#1D4289'
    elif team =="Houston Rockets":
        return '#BA0C2F'
    elif team =="Indiana Pacers":
        return '#041E42'
    elif team =="Los Angeles Clippers":
        return '#0C2340'
    elif team =="Los Angeles Lakers":
        return '#6a00ed'
    elif team =="Portland Trail Blazers":
        return '#C8102E'
    elif team =="Phoenix Suns":
        return '#e56020'
    elif team =="Philadelphia 76ers":
        return '#1D4289'
    elif team =="Orlando Magic":
        return '#0057B7'
    elif team =="Oklahoma City Thunder":
        return '#0072CE'
    elif team =="New York Knicks":
        return '#FF8200'
    elif team =="New Orleans Pelicans":
        return '#0C2340'
    elif team =="Minnesota Timberwolves":
        return '#0C2340'
    elif team =="Milwaukee Bucks":
        return '#2C5234'
    elif team =="Brooklyn Nets":
        return '#707372'
    elif team =="Boston Celtics":
        return '#007A33'
    elif team =="Seattle SuperSonics":
        return '#00653A'
    elif team =="Charlotte Hornets":
        return '#00778B'
    elif team =="Buffalo Braves":
        return '#418FDE'
    elif team =="Chicago Bulls":
        return '#BA0C2F'       
    elif team =="Cleveland Cavaliers":
        return '#6F263D'
    elif team =="Washington Wizards":
        return '#C8102E'
    elif team =="Utah Jazz":
        return '#0C2340' 
    elif team =="Toronto Raptors":
        return '#C8102E'
    elif team =="San Antonio Spurs":
        return '#9EA2A2'
    elif team =="Sacramento Kings":
        return '#582C83'                  
    else:
        return '#3860C6'

# %%
def team_id(team):
    if team =="1610612737":
        return "ATL"
    elif team =="1610612738":
        return 'BOS'
    elif team =="1610612739":
        return 'CLE'
    elif team =="1610612740":
        return 'NOP'
    elif team =="1610612741":
        return 'CHI'
    elif team =="1610612742":
        return 'DAL'
    elif team =="1610612743":
        return 'DEN'
    elif team =="1610612744":
        return 'GSW'
    elif team =="1610612745":
        return 'HOU'
    elif team =="1610612746":
        return 'LAC'
    elif team =="1610612747":
        return 'LAL'
    elif team =="1610612748":
        return 'MIA'
    elif team =="1610612749":
        return 'MIL'
    elif team =="1610612750":
        return 'MIN'
    elif team =="1610612751":
        return 'BKN'
    elif team =="1610612752":
        return 'NYK'
    elif team =="1610612753":
        return 'ORL'
    elif team =="1610612754":
        return 'IND'
    elif team =="1610612755":
        return 'PHI'
    elif team =="1610612756":
        return 'PHX'
    elif team =="1610612757":
        return 'POR'
    elif team =="1610612758":
        return 'SAC'
    elif team =="1610612759":
        return 'SAS'
    elif team =="1610612760":
        return 'OKC'
    elif team =="1610612761":
        return 'TOR'
    elif team =="1610612762":
        return 'UTA'
    elif team =="1610612763":
        return 'MEM'
    elif team =="1610612764":
        return 'WAS'
    elif team =="1610612765":
        return 'DET'
    elif team =="1610612766":
        return 'CHA'                
    else:
        return '#3860C6'
