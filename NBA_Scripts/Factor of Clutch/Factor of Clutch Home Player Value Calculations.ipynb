# %%
import pandas as pd
import numpy as np
import itertools
import datetime
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import *
from datetime import datetime, timedelta, date
# %load_ext google.colab.data_table
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Standard plotly imports
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
#Change the date to the previous day
query = """
SELECT
A.GAME_ID, GAME_DATE, MATCHUP, EVENTNUM, PERIOD, PCTIMESTRING, EVENTMSGTYPE, EVENTMSGACTIONTYPE,
CASE WHEN EVENTMSGTYPE=1 THEN 'Made FG'
     WHEN EVENTMSGTYPE=2 THEN 'Missed FG'
     WHEN EVENTMSGTYPE=3 THEN 'Free Throw Attempts'
     WHEN EVENTMSGTYPE=4 THEN 'Rebound'
     WHEN EVENTMSGTYPE=5 THEN 'Turnover'
     WHEN EVENTMSGTYPE=6 THEN 'Foul'
     WHEN EVENTMSGTYPE=7 THEN 'Violation'
     WHEN EVENTMSGTYPE=8 THEN 'Substitution'
     WHEN EVENTMSGTYPE=9 THEN 'Timeout'
     WHEN EVENTMSGTYPE=10 THEN 'Jump Ball'
     WHEN EVENTMSGTYPE=11 THEN 'Ejection'
     WHEN EVENTMSGTYPE=12 THEN 'Period Begin'
     WHEN EVENTMSGTYPE=13 THEN 'Period End'
     END as Event,
CASE WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=0 THEN 'No Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=1 THEN 'Jump Shot/3PT Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=2 THEN 'RUNNING JUMP SHOT/ 3PT RUNNING JUMP SHOT'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=3 THEN 'Hook Shot/3PT Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=4 THEN 'Tip Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=5 THEN 'Layup/3PT Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=6 THEN 'Driving Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=7 THEN 'Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=8 THEN 'Slam Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=9 THEN 'Driving Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=40 THEN '3PT Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=41 THEN 'Running Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=42 THEN 'Driving Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=43 THEN 'Alley-oop Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=44 THEN 'Reverse Layup/3PT Reverse Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=46 THEN 'Running Jump Shot/3PT Running Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=47 THEN 'Turnaround Jump Shot/3PT Turnaround Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=49 THEN 'Driving Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=50 THEN 'Running Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=51 THEN 'Reverse Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=52 THEN 'Alley-oop Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=54 THEN 'Running Tip Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=56 THEN 'Running Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=57 THEN 'Driving Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=58 THEN 'Turnaround Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=59 THEN 'Finger Roll/3PT Finger Roll'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=60 THEN 'Running Finger Roll'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=61 THEN 'Driving Finger Roll'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=62 THEN 'Turnaround Finger Roll'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=63 THEN 'Fadeaway Jumper/3PT Fadeaway Jumper'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=64 THEN 'Follow up Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=65 THEN 'Jump Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=66 THEN 'Jump Bank Shot/3PT Jump Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=67 THEN 'Hook Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=71 THEN 'Finger Roll Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=72 THEN 'Putback Layup/3PT Putback Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=73 THEN 'Driving Reverse Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=74 THEN 'Running Reverse Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=75 THEN 'Driving Finger Roll Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=76 THEN 'Running Finger Roll Layup'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=77 THEN 'Driving Jump Shot/3PT Driving Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=78 THEN 'Floating Jump Shot/3PT Floating Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=79 THEN 'Pullup Jump Shot/3PT Pullup Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=80 THEN 'Step Back Jump Shot/3PT Step Back Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=81 THEN 'Pullup Bank Shot/3PT Pullup Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=82 THEN 'Driving Bank Shot/3PT Driving Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=83 THEN 'Fadeaway Bank Shot/3PT Fadeaway Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=84 THEN 'Running Bank Shot/3PT Running Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=85 THEN 'Turnaround Bank Shot/3PT Turnaround Bank Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=86 THEN 'Turnaround Fadeaway/3PT Turnaround Fadeaway'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=87 THEN 'Putback Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=88 THEN 'Driving Slam Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=89 THEN 'Reverse Slam Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=90 THEN 'Running Slam Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=91 THEN 'Putback Reverse Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=92 THEN 'Putback Slam Dunk'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=93 THEN 'Driving Bank Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=94 THEN 'Jump Bank Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=95 THEN 'Running Bank Hook Shot/3PT Running Bank Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=96 THEN 'Turnaround Bank Hook Shot/3PT Turnaround Bank Hook Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=97 THEN 'Tip Layup Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=98 THEN 'Cutting Layup Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=99 THEN 'Cutting Finger Roll Layup Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=100 THEN 'Running Alley-oop Layup Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=101 THEN 'Driving Floating Jump Shot/3PT Driving Floating Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=102 THEN 'Driving Floating Bank Jump Shot/3PT Driving Floating Bank Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=103 THEN 'Running Pull/3PT Running Pull'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=104 THEN 'Step Back Bank Jump Shot/3PT Step Back Bank Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=105 THEN 'Turnaround Fadeaway Bank Jump Shot/3PT Turnaround Fadeaway Bank Jump Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=106 THEN 'Running Alley-oop Dunk Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=107 THEN 'Tip Dunk Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=108 THEN 'Cutting Dunk Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=109 THEN 'Driving Reverse Dunk Shot'
     WHEN EVENTMSGTYPE IN (1,2) AND EVENTMSGACTIONTYPE=110 THEN 'Running Reverse Dunk Shot'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=10 THEN 'Free Throw 1 of 1'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=11 THEN 'Free Throw 1 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=12 THEN 'Free Throw 2 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=13 THEN 'Free Throw 1 of 3'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=14 THEN 'Free Throw 2 of 3'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=15 THEN 'Free Throw 3 of 3'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=16 THEN 'Free Throw Technical 1 of 1'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=18 THEN 'Free Throw Flagrant 1 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=19 THEN 'Free Throw Flagrant 2 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=20 THEN 'Free Throw Flagrant 1 of 1'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=21 THEN 'Free Throw Technical 1 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=22 THEN 'Free Throw Technical 2 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=25 THEN 'Free Throw Clear Path 1 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=26 THEN 'Free Throw Clear Path 2 of 2'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=27 THEN 'Free Throw Flagrant 1 of 3'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=28 THEN 'Free Throw Flagrant 2 of 3'
     WHEN EVENTMSGTYPE IN (3) AND EVENTMSGACTIONTYPE=29 THEN 'Free Throw Flagrant 3 of 3'
     WHEN EVENTMSGTYPE IN (4) THEN 'Rebound'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=0 THEN 'Flagrant Foul: No Turnover'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=1 THEN 'Bad Pass TO: Steal'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=2 THEN 'Lost Ball TO: Steal'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=4 THEN 'Traveling TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=6 THEN 'Double Dribble TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=7 THEN 'Discontinue Dribble TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=8 THEN '3 Second Violation TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=9 THEN '5 Second Violation TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=10 THEN '8 Second Violation TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=11 THEN 'Shot Clock TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=12 THEN 'Inbound TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=13 THEN 'Backcourt TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=14 THEN 'Illegal pick TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=15 THEN 'Offensive Goaltending TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=16 THEN 'Isolation Violation TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=17 THEN 'Lane Violation TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=18 THEN 'Jump Ball Violation TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=19 THEN 'Kicked Ball Violation TO '
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=20 THEN 'Illegal Assist TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=21 THEN 'Palming TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=22 THEN 'Post up TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=23 THEN 'Double personal TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=32 THEN 'Opposite basket TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=33 THEN 'Punched ball TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=34 THEN 'Swinging elbows TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=35 THEN 'Basket from below TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=36 THEN 'Illegal Screen'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=37 THEN 'Offensive Foul TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=38 THEN '5 second inbound TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=39 THEN 'Step out of bounds TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=40 THEN 'Out of bounds lost ball TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=41 THEN 'Poss lost ball TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=42 THEN 'Excess Timeout TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=43 THEN 'Player OOB TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=44 THEN 'Too many players TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=45 THEN 'Out of bounds bad pass TO'
     WHEN EVENTMSGTYPE IN (5) AND EVENTMSGACTIONTYPE=52 THEN 'STL TO'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=1 THEN 'Personal Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=2 THEN 'S Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=3 THEN 'L.B. Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=4 THEN 'Offensive Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=5 THEN 'In. Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=6 THEN 'Away from play foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=7 THEN 'Elbow Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=8 THEN 'Punch Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=9 THEN 'C.P. Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=10 THEN 'Double personal Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=11 THEN 'T. Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=12 THEN 'Non-Unsportsmanlike Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=13 THEN 'Hanging Tech Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=14 THEN 'Flagrant Foul Type 1'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=15 THEN 'Flagrant Foul Type 2'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=16 THEN 'Double Technical'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=17 THEN 'Team T. Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=18 THEN 'Team Delay Technical'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=19 THEN 'Taunting '
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=25 THEN 'Excess Timeout Technical'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=26 THEN 'Offensive Charge Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=27 THEN 'Personal Block Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=28 THEN 'Personal Take Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=29 THEN 'Shooting Block Foul'
     WHEN EVENTMSGTYPE IN (6) AND EVENTMSGACTIONTYPE=30 THEN 'Too many Players Foul'
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=0 THEN 'Violation: No violation'
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=1 THEN 'Violation: Delay of game '
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=2 THEN 'Defensive Goaltending'
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=3 THEN 'Lane Violation'
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=4 THEN 'Jump Ball Violation'
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=5 THEN 'Kicked Ball Violation'
     WHEN EVENTMSGTYPE IN (7) AND EVENTMSGACTIONTYPE=6 THEN 'Double Lane Violation'
     WHEN EVENTMSGTYPE IN (8)  THEN 'Substitution'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=0 THEN 'Timeout: No Timeout'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=1 THEN 'Timeout Regular'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=2 THEN 'Timeout Short'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=3 THEN 'Timeout official TV'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=4 THEN 'Timeout Official'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=5 THEN 'Timeout Advance'
     WHEN EVENTMSGTYPE IN (9) AND EVENTMSGACTIONTYPE=7 THEN 'Coach Challenge'
     WHEN EVENTMSGTYPE IN (10) AND EVENTMSGACTIONTYPE=0 THEN 'Jump ball'
     WHEN EVENTMSGTYPE IN (10) AND EVENTMSGACTIONTYPE=1 THEN 'Jump ball CC'
     WHEN EVENTMSGTYPE IN (11) AND EVENTMSGACTIONTYPE=0 THEN 'Ejection: No ejection'
     WHEN EVENTMSGTYPE IN (11) AND EVENTMSGACTIONTYPE=1 THEN 'Ejection: Second Technical'
     WHEN EVENTMSGTYPE IN (11) AND EVENTMSGACTIONTYPE=2 THEN 'Ejection: Second Flagrant Type 1 '
     WHEN EVENTMSGTYPE IN (11) AND EVENTMSGACTIONTYPE=3 THEN 'Ejection: First Flagrant Type 2'
     WHEN EVENTMSGTYPE IN (11) AND EVENTMSGACTIONTYPE=4 THEN 'Ejection: Other'
     WHEN EVENTMSGTYPE IN (12) THEN 'Start of period'
     WHEN EVENTMSGTYPE IN (13) THEN 'End of period'
     ELSE 'No event'
     END as Event_Type,

HOMEDESCRIPTION, NEUTRALDESCRIPTION, VISITORDESCRIPTION, SCORE, SCOREMARGIN, PERSON1TYPE, PLAYER1_ID, PLAYER1_NAME, PLAYER1_TEAM_ID, PLAYER1_TEAM_CITY, PLAYER1_TEAM_NICKNAME, PLAYER1_TEAM_ABBREVIATION, PERSON2TYPE, PLAYER2_ID, PLAYER2_NAME, PLAYER2_TEAM_ID, PLAYER2_TEAM_CITY, PLAYER2_TEAM_NICKNAME, PLAYER2_TEAM_ABBREVIATION, PERSON3TYPE, PLAYER3_ID, PLAYER3_NAME, PLAYER3_TEAM_ID, PLAYER3_TEAM_CITY, PLAYER3_TEAM_NICKNAME, PLAYER3_TEAM_ABBREVIATION, VIDEO_AVAILABLE_FLAG, WCTIMESTRING, A.Season
FROM
`perceptive-ivy-290216.play_by_play.reg_season_22_23` A
INNER JOIN
nba_game_player_team_ids.game_ids_reg_season B
ON A.GAME_ID =B.GAME_ID
-- WHERE A.GAME_ID='0022001010'
AND MATCHUP LIKE '%@ DEN%'
ORDER BY 4"""
project_id = "perceptive-ivy-290216"
df_bq = pd.read_gbq(query=query, project_id=project_id, dialect='standard')

# %%
query2 = """
SELECT TEAM_ABBREVIATION, GAME_ID, GAME_DATE, WL, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PF, PTS FROM `perceptive-ivy-290216.nba_api_team_boxscore.team_box_96_onwards`
WHERE TEAM_ABBREVIATION="DEN"
AND SEASON='2022-23'
AND MATCHUP LIKE "%DEN vs.%"
"""
project_id = "perceptive-ivy-290216"
result_bq = pd.read_gbq(query=query2, project_id=project_id, dialect='standard')
result_bq.head()
# Out:
# Warning: Total number of columns (22) exceeds max_columns (20). Falling back to pandas display.
#   TEAM_ABBREVIATION     GAME_ID   GAME_DATE WL  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0               DEN  0022201147  2023-03-30  L   32   80   0.400     4    28
# 1               DEN  0022200989  2023-03-08  L   37   88   0.420    15    40
# 2               DEN  0022201014  2023-03-12  L   45   90   0.500    12    31
# 3               DEN  0022200362  2022-12-06  L   40   78   0.513    13    32
# 4               DEN  0022200219  2022-11-16  L   36   82   0.439    14    38
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0    0.143   20   32   0.625    11    29   40   21    4    5   10  21   88
# 1    0.375    7   15   0.467    11    33   44   26    5    2   11  16   96
# 2    0.387   18   24   0.750    15    34   49   27    4    8   15  19  120
# 3    0.406   22   28   0.786     8    28   36   30    8    4   17  28  115
# 4    0.368   17   20   0.850     8    34   42   18    3    5   15  25  103

# %%
#Change the date to the previous day
query_shooting = """
SELECT
GAME_ID as GAME, PLAYER_NAME, PERIOD PERIOD_LOC, MINUTES_REMAINING, SECONDS_REMAINING, SHOT_TYPE, SHOT_ZONE_BASIC
FROM `perceptive-ivy-290216.nba_api_shooting_location.x_y_location`
WHERE SEASON='2022-23'
# AND GAME_ID='0041500407'
ORDER BY PERIOD, MINUTES_REMAINING DESC, SECONDS_REMAINING DESC
"""
project_id = "perceptive-ivy-290216"
shooting_df = pd.read_gbq(query=query_shooting, project_id=project_id, dialect='standard')
shooting_df.head()
# Out:
#          GAME     PLAYER_NAME  PERIOD_LOC  MINUTES_REMAINING  \
# 0  0022200180    Bobby Portis           1                 12
# 1  0022200524     Buddy Hield           1                 11
# 2  0022200472  Alperen Sengun           1                 11
# 3  0022200378     Buddy Hield           1                 11
# 4  0022200957      Jaden Ivey           1                 11
#
#    SECONDS_REMAINING       SHOT_TYPE    SHOT_ZONE_BASIC
# 0                  0  2PT Field Goal    Restricted Area
# 1                 57  3PT Field Goal  Above the Break 3
# 2                 56  2PT Field Goal    Restricted Area
# 3                 56  2PT Field Goal    Restricted Area
# 4                 55  2PT Field Goal    Restricted Area

# %%
#Making sure all games are in here
df_bq.GAME_ID.nunique()
# Out:
# 41

# %%
game=df_bq

# %%
game=game.replace("TIE",'0')

# %%
game["RK"] = game.groupby("GAME_ID")["EVENTNUM"].rank(method="dense", ascending=True)

# %%
game = game.sort_values(['GAME_ID','EVENTNUM']).reset_index(drop=True)

# %%
#Make the first row of each game id as 0 for score and score margin, otherwise the next game inherits the prior game's score and scoremargin in the next steps due to no delineation
for index, row in game.iterrows():
  if game.loc[index, 'RK']==1.0:
    game.loc[index, 'SCOREMARGIN']=0
    game.loc[index, 'SCORE']='0-0'

# %%
game['SCOREMARGIN'] = game['SCOREMARGIN'].fillna(method='ffill')
game['SCORE'] = game['SCORE'].fillna(method='ffill')
game=game.fillna('No')
game['SCOREMARGIN']=game['SCOREMARGIN'].astype(int)

# %%
game[['MINUTE', 'SECOND']] = game['PCTIMESTRING'].str.split(':', 1, expand=True)
game["MINUTE"]=game["MINUTE"].astype(int)
game["SECOND"]=game["SECOND"].astype(int)
game["SECONDS"]=game["MINUTE"]*60+game["SECOND"]
# Out:
# <ipython-input-14-0c3f1d875fae>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   game[['MINUTE', 'SECOND']] = game['PCTIMESTRING'].str.split(':', 1, expand=True)

# %%
game.sort_values(['GAME_ID', 'PERIOD', 'SECONDS'], ascending=[True, True, False], inplace=True)
game['overall_rank'] = 1
game['overall_rank'] = game.groupby(['GAME_ID'])['overall_rank'].cumsum()
game.head()
# Out:
# Warning: Total number of columns (44) exceeds max_columns (20). Falling back to pandas display.
#       GAME_ID   GAME_DATE    MATCHUP  EVENTNUM  PERIOD PCTIMESTRING  \
# 0  0022200035  2022-10-22  OKC @ DEN         2       1        12:00
# 1  0022200035  2022-10-22  OKC @ DEN         4       1        12:00
# 2  0022200035  2022-10-22  OKC @ DEN         7       1        11:47
# 3  0022200035  2022-10-22  OKC @ DEN         8       1        11:45
# 4  0022200035  2022-10-22  OKC @ DEN         9       1        11:40
#
#    EVENTMSGTYPE  EVENTMSGACTIONTYPE         Event               Event_Type  \
# 0            12                   0  Period Begin          Start of period
# 1            10                   0     Jump Ball                Jump ball
# 2             2                   1     Missed FG  Jump Shot/3PT Jump Shot
# 3             4                   0       Rebound                  Rebound
# 4             5                   1      Turnover       Bad Pass TO: Steal
#
#                                     HOMEDESCRIPTION  \
# 0                                                No
# 1  Jump Ball Jokic vs. Robinson-Earl: Tip to Giddey
# 2                                                No
# 3                      Murray REBOUND (Off:0 Def:1)
# 4                  Murray Bad Pass Turnover (P1.T1)
#
#                   NEUTRALDESCRIPTION           VISITORDESCRIPTION SCORE  \
# 0  Start of 1st Period (9:17 PM EST)                           No   0-0
# 1                                 No                           No   0-0
# 2                                 No  MISS Dort 24' 3PT Jump Shot   0-0
# 3                                 No                           No   0-0
# 4                                 No     Pokusevski STEAL (1 STL)   0-0
#
#    SCOREMARGIN  PERSON1TYPE  PLAYER1_ID   PLAYER1_NAME PLAYER1_TEAM_ID  \
# 0            0          0.0           0             No              No
# 1            0          4.0      203999   Nikola Jokic    1610612743.0
# 2            0          5.0     1629652  Luguentz Dort    1610612760.0
# 3            0          4.0     1627750   Jamal Murray    1610612743.0
# 4            0          4.0     1627750   Jamal Murray    1610612743.0
#
#   PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 0                No                    No                        No
# 1            Denver               Nuggets                       DEN
# 2     Oklahoma City               Thunder                       OKC
# 3            Denver               Nuggets                       DEN
# 4            Denver               Nuggets                       DEN
#
#    PERSON2TYPE  PLAYER2_ID            PLAYER2_NAME PLAYER2_TEAM_ID  \
# 0            0           0                      No              No
# 1            5     1630526  Jeremiah Robinson-Earl    1610612760.0
# 2            0           0                      No              No
# 3            0           0                      No              No
# 4            5     1630197      Aleksej Pokusevski    1610612760.0
#
#   PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  \
# 0                No                    No                        No
# 1     Oklahoma City               Thunder                       OKC
# 2                No                    No                        No
# 3                No                    No                        No
# 4     Oklahoma City               Thunder                       OKC
#
#    PERSON3TYPE  PLAYER3_ID PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 0            0           0           No              No                No
# 1            5     1630581  Josh Giddey    1610612760.0     Oklahoma City
# 2            0           0           No              No                No
# 3            0           0           No              No                No
# 4            0           0           No              No                No
#
#   PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG  \
# 0                    No                        No                     0
# 1               Thunder                       OKC                     1
# 2                    No                        No                     1
# 3                    No                        No                     1
# 4                    No                        No                     1
#
#   WCTIMESTRING   Season   RK  MINUTE  SECOND  SECONDS  overall_rank
# 0      9:17 PM  2022-23  1.0      12       0      720             1
# 1      9:17 PM  2022-23  2.0      12       0      720             2
# 2      9:17 PM  2022-23  3.0      11      47      707             3
# 3      9:17 PM  2022-23  4.0      11      45      705             4
# 4      9:17 PM  2022-23  5.0      11      40      700             5

# %%
# game_edited=pd.concat([game,game[['SECONDS']].shift(periods=-1).rename({'SECONDS':'SECONDS_SHIFTED'}, axis=1)], axis=1)
game_edited=pd.concat([game,game[['SECONDS']].diff().rename({'SECONDS':'SECONDS_Diff'}, axis=1)], axis=1)
game_edited=pd.concat([game_edited,game_edited[['SCOREMARGIN']].diff().rename({'SCOREMARGIN':'SCOREMARGIN_Diff'}, axis=1)], axis=1)
game_edited["SECONDS_Diff"]=game_edited["SECONDS_Diff"].abs()
game_edited["SCOREMARGIN_Diff"]=game_edited["SCOREMARGIN_Diff"].abs()
game_edited.tail()
# Out:
# Warning: Total number of columns (46) exceeds max_columns (20). Falling back to pandas display.
#           GAME_ID   GAME_DATE    MATCHUP  EVENTNUM  PERIOD PCTIMESTRING  \
# 18979  0022201227  2023-04-09  SAC @ DEN       620       4         0:33
# 18980  0022201227  2023-04-09  SAC @ DEN       622       4         0:09
# 18981  0022201227  2023-04-09  SAC @ DEN       623       4         0:01
# 18982  0022201227  2023-04-09  SAC @ DEN       624       4         0:01
# 18983  0022201227  2023-04-09  SAC @ DEN       625       4         0:00
#
#        EVENTMSGTYPE  EVENTMSGACTIONTYPE       Event  \
# 18979             1                  50     Made FG
# 18980             5                  11    Turnover
# 18981             2                  79   Missed FG
# 18982             4                   0     Rebound
# 18983            13                   0  Period End
#
#                                   Event_Type  \
# 18979                           Running Dunk
# 18980                          Shot Clock TO
# 18981  Pullup Jump Shot/3PT Pullup Jump Shot
# 18982                                Rebound
# 18983                          End of period
#
#                            HOMEDESCRIPTION               NEUTRALDESCRIPTION  \
# 18979                                   No                               No
# 18980  NUGGETS Turnover: Shot Clock (T#20)                               No
# 18981                                   No                               No
# 18982                                   No                               No
# 18983                                   No  End of 4th Period (5:44 PM EST)
#
#                                VISITORDESCRIPTION     SCORE  SCOREMARGIN  \
# 18979  Metu 3' Running Dunk (9 PTS) (Ellis 1 AST)  95 - 109           14
# 18980                                          No  95 - 109           14
# 18981          MISS Metu 27' 3PT Pullup Jump Shot  95 - 109           14
# 18982                               Kings Rebound  95 - 109           14
# 18983                                          No  95 - 109           14
#
#        PERSON1TYPE  PLAYER1_ID   PLAYER1_NAME PLAYER1_TEAM_ID  \
# 18979          5.0     1629002  Chimezie Metu    1610612758.0
# 18980          2.0  1610612743             No              No
# 18981          5.0     1629002  Chimezie Metu    1610612758.0
# 18982          3.0  1610612758             No              No
# 18983          0.0           0             No              No
#
#       PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 18979        Sacramento                 Kings                       SAC
# 18980                No                    No                        No
# 18981        Sacramento                 Kings                       SAC
# 18982                No                    No                        No
# 18983                No                    No                        No
#
#        PERSON2TYPE  PLAYER2_ID PLAYER2_NAME PLAYER2_TEAM_ID PLAYER2_TEAM_CITY  \
# 18979            5     1631165   Keon Ellis    1610612758.0        Sacramento
# 18980            0           0           No              No                No
# 18981            0           0           No              No                No
# 18982            0           0           No              No                No
# 18983            0           0           No              No                No
#
#       PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE  \
# 18979                 Kings                       SAC            0
# 18980                    No                        No            1
# 18981                    No                        No            0
# 18982                    No                        No            0
# 18983                    No                        No            0
#
#        PLAYER3_ID PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 18979           0           No              No                No
# 18980           0           No              No                No
# 18981           0           No              No                No
# 18982           0           No              No                No
# 18983           0           No              No                No
#
#       PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG  \
# 18979                    No                        No                     1
# 18980                    No                        No                     0
# 18981                    No                        No                     1
# 18982                    No                        No                     1
# 18983                    No                        No                     1
#
#       WCTIMESTRING   Season     RK  MINUTE  SECOND  SECONDS  overall_rank  \
# 18979      5:43 PM  2022-23  435.0       0      33       33           435
# 18980      5:44 PM  2022-23  436.0       0       9        9           436
# 18981      5:44 PM  2022-23  437.0       0       1        1           437
# 18982      5:44 PM  2022-23  438.0       0       1        1           438
# 18983      5:44 PM  2022-23  439.0       0       0        0           439
#
#        SECONDS_Diff  SCOREMARGIN_Diff
# 18979           5.0               2.0
# 18980          24.0               0.0
# 18981           8.0               0.0
# 18982           0.0               0.0
# 18983           1.0               0.0

# %%
BLOCK_ALL_GAMES=game_edited
BLOCK_ALL_GAMES=BLOCK_ALL_GAMES[BLOCK_ALL_GAMES["Event_Type"]!="Start of period"]
BLOCK_ALL_GAMES=BLOCK_ALL_GAMES.sort_values(by=["GAME_ID","PERIOD","SECONDS"], ascending=[True, True, False])


BLOCK_1=game_edited[game_edited['GAME_ID'].isin(['0022201227'])]
BLOCK_1=BLOCK_1[BLOCK_1["Event_Type"]!="Start of period"]
BLOCK_1=BLOCK_1.sort_values(by=["GAME_ID","PERIOD","SECONDS"], ascending=[True, True, False])
BLOCK_1.head()
# Out:
# Warning: Total number of columns (46) exceeds max_columns (20). Falling back to pandas display.
#           GAME_ID   GAME_DATE    MATCHUP  EVENTNUM  PERIOD PCTIMESTRING  \
# 18546  0022201227  2023-04-09  SAC @ DEN         4       1        12:00
# 18547  0022201227  2023-04-09  SAC @ DEN         7       1        11:39
# 18548  0022201227  2023-04-09  SAC @ DEN         9       1        11:22
# 18568  0022201227  2023-04-09  SAC @ DEN        41       1        11:15
# 18549  0022201227  2023-04-09  SAC @ DEN        13       1        11:06
#
#        EVENTMSGTYPE  EVENTMSGACTIONTYPE      Event  \
# 18546            10                   0  Jump Ball
# 18547             1                 108    Made FG
# 18548             1                   9    Made FG
# 18568             7                   5  Violation
# 18549             2                  63  Missed FG
#
#                                 Event_Type  \
# 18546                            Jump ball
# 18547                    Cutting Dunk Shot
# 18548                         Driving Dunk
# 18568                Kicked Ball Violation
# 18549  Fadeaway Jumper/3PT Fadeaway Jumper
#
#                                     HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 18546   Jump Ball Jordan vs. Sabonis: Tip to Barnes                 No
# 18547                                            No                 No
# 18548  Braun 2' Driving Dunk (2 PTS) (Jordan 1 AST)                 No
# 18568       Jordan Violation:Kicked Ball (D.Taylor)                 No
# 18549                                            No                 No
#
#                                       VISITORDESCRIPTION   SCORE  SCOREMARGIN  \
# 18546                                                 No     0-0            0
# 18547  Sabonis 3' Cutting Dunk Shot (2 PTS) (Huerter ...   2 - 0           -2
# 18548                                                 No   2 - 2            0
# 18568                                                 No  14 - 6           -8
# 18549                       MISS Fox 16' Fadeaway Jumper   2 - 2            0
#
#        PERSON1TYPE  PLAYER1_ID      PLAYER1_NAME PLAYER1_TEAM_ID  \
# 18546          4.0      201599    DeAndre Jordan    1610612743.0
# 18547          5.0     1627734  Domantas Sabonis    1610612758.0
# 18548          4.0     1631128   Christian Braun    1610612743.0
# 18568          4.0      201599    DeAndre Jordan    1610612743.0
# 18549          5.0     1628368      De'Aaron Fox    1610612758.0
#
#       PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 18546            Denver               Nuggets                       DEN
# 18547        Sacramento                 Kings                       SAC
# 18548            Denver               Nuggets                       DEN
# 18568            Denver               Nuggets                       DEN
# 18549        Sacramento                 Kings                       SAC
#
#        PERSON2TYPE  PLAYER2_ID      PLAYER2_NAME PLAYER2_TEAM_ID  \
# 18546            5     1627734  Domantas Sabonis    1610612758.0
# 18547            5     1628989     Kevin Huerter    1610612758.0
# 18548            4      201599    DeAndre Jordan    1610612743.0
# 18568            0           0                No              No
# 18549            0           0                No              No
#
#       PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  \
# 18546        Sacramento                 Kings                       SAC
# 18547        Sacramento                 Kings                       SAC
# 18548            Denver               Nuggets                       DEN
# 18568                No                    No                        No
# 18549                No                    No                        No
#
#        PERSON3TYPE  PLAYER3_ID     PLAYER3_NAME PLAYER3_TEAM_ID  \
# 18546            5      203084  Harrison Barnes    1610612758.0
# 18547            0           0               No              No
# 18548            0           0               No              No
# 18568            1           0               No              No
# 18549            0           0               No              No
#
#       PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  \
# 18546        Sacramento                 Kings                       SAC
# 18547                No                    No                        No
# 18548                No                    No                        No
# 18568                No                    No                        No
# 18549                No                    No                        No
#
#        VIDEO_AVAILABLE_FLAG WCTIMESTRING   Season    RK  MINUTE  SECOND  \
# 18546                     1      3:41 PM  2022-23   2.0      12       0
# 18547                     1      3:42 PM  2022-23   3.0      11      39
# 18548                     1      3:42 PM  2022-23   4.0      11      22
# 18568                     0      3:42 PM  2022-23  24.0      11      15
# 18549                     1      3:42 PM  2022-23   5.0      11       6
#
#        SECONDS  overall_rank  SECONDS_Diff  SCOREMARGIN_Diff
# 18546      720             2           0.0               0.0
# 18547      699             3          21.0               2.0
# 18548      682             4          17.0               2.0
# 18568      675             5           7.0               8.0
# 18549      666             6           9.0               8.0

# %%
#Add a column to check scoremargin and if it is =/>/< than 0
for index,row in BLOCK_1.iterrows():
  if row['SCOREMARGIN']==0:
    BLOCK_1.loc[index,'LEAD_LAG'] = 'ALL'
  elif row['SCOREMARGIN']>0:
    BLOCK_1.loc[index,'LEAD_LAG'] = 'HOME LEAD'
  elif row['SCOREMARGIN']<0:
    BLOCK_1.loc[index,'LEAD_LAG'] = 'HOME DEFICIT'

# %%
BLOCK_1.head()
# Out:
# Warning: Total number of columns (47) exceeds max_columns (20). Falling back to pandas display.
#           GAME_ID   GAME_DATE    MATCHUP  EVENTNUM  PERIOD PCTIMESTRING  \
# 18546  0022201227  2023-04-09  SAC @ DEN         4       1        12:00
# 18547  0022201227  2023-04-09  SAC @ DEN         7       1        11:39
# 18548  0022201227  2023-04-09  SAC @ DEN         9       1        11:22
# 18568  0022201227  2023-04-09  SAC @ DEN        41       1        11:15
# 18549  0022201227  2023-04-09  SAC @ DEN        13       1        11:06
#
#        EVENTMSGTYPE  EVENTMSGACTIONTYPE      Event  \
# 18546            10                   0  Jump Ball
# 18547             1                 108    Made FG
# 18548             1                   9    Made FG
# 18568             7                   5  Violation
# 18549             2                  63  Missed FG
#
#                                 Event_Type  \
# 18546                            Jump ball
# 18547                    Cutting Dunk Shot
# 18548                         Driving Dunk
# 18568                Kicked Ball Violation
# 18549  Fadeaway Jumper/3PT Fadeaway Jumper
#
#                                     HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 18546   Jump Ball Jordan vs. Sabonis: Tip to Barnes                 No
# 18547                                            No                 No
# 18548  Braun 2' Driving Dunk (2 PTS) (Jordan 1 AST)                 No
# 18568       Jordan Violation:Kicked Ball (D.Taylor)                 No
# 18549                                            No                 No
#
#                                       VISITORDESCRIPTION   SCORE  SCOREMARGIN  \
# 18546                                                 No     0-0            0
# 18547  Sabonis 3' Cutting Dunk Shot (2 PTS) (Huerter ...   2 - 0           -2
# 18548                                                 No   2 - 2            0
# 18568                                                 No  14 - 6           -8
# 18549                       MISS Fox 16' Fadeaway Jumper   2 - 2            0
#
#        PERSON1TYPE  PLAYER1_ID      PLAYER1_NAME PLAYER1_TEAM_ID  \
# 18546          4.0      201599    DeAndre Jordan    1610612743.0
# 18547          5.0     1627734  Domantas Sabonis    1610612758.0
# 18548          4.0     1631128   Christian Braun    1610612743.0
# 18568          4.0      201599    DeAndre Jordan    1610612743.0
# 18549          5.0     1628368      De'Aaron Fox    1610612758.0
#
#       PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 18546            Denver               Nuggets                       DEN
# 18547        Sacramento                 Kings                       SAC
# 18548            Denver               Nuggets                       DEN
# 18568            Denver               Nuggets                       DEN
# 18549        Sacramento                 Kings                       SAC
#
#        PERSON2TYPE  PLAYER2_ID      PLAYER2_NAME PLAYER2_TEAM_ID  \
# 18546            5     1627734  Domantas Sabonis    1610612758.0
# 18547            5     1628989     Kevin Huerter    1610612758.0
# 18548            4      201599    DeAndre Jordan    1610612743.0
# 18568            0           0                No              No
# 18549            0           0                No              No
#
#       PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  \
# 18546        Sacramento                 Kings                       SAC
# 18547        Sacramento                 Kings                       SAC
# 18548            Denver               Nuggets                       DEN
# 18568                No                    No                        No
# 18549                No                    No                        No
#
#        PERSON3TYPE  PLAYER3_ID     PLAYER3_NAME PLAYER3_TEAM_ID  \
# 18546            5      203084  Harrison Barnes    1610612758.0
# 18547            0           0               No              No
# 18548            0           0               No              No
# 18568            1           0               No              No
# 18549            0           0               No              No
#
#       PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  \
# 18546        Sacramento                 Kings                       SAC
# 18547                No                    No                        No
# 18548                No                    No                        No
# 18568                No                    No                        No
# 18549                No                    No                        No
#
#        VIDEO_AVAILABLE_FLAG WCTIMESTRING   Season    RK  MINUTE  SECOND  \
# 18546                     1      3:41 PM  2022-23   2.0      12       0
# 18547                     1      3:42 PM  2022-23   3.0      11      39
# 18548                     1      3:42 PM  2022-23   4.0      11      22
# 18568                     0      3:42 PM  2022-23  24.0      11      15
# 18549                     1      3:42 PM  2022-23   5.0      11       6
#
#        SECONDS  overall_rank  SECONDS_Diff  SCOREMARGIN_Diff      LEAD_LAG
# 18546      720             2           0.0               0.0           ALL
# 18547      699             3          21.0               2.0  HOME DEFICIT
# 18548      682             4          17.0               2.0           ALL
# 18568      675             5           7.0               8.0  HOME DEFICIT
# 18549      666             6           9.0               8.0           ALL

# %%
#Add a column to check scoremargin and if it is =/>/< than 0
for index,row in BLOCK_ALL_GAMES.iterrows():
  if row['SCOREMARGIN']==0:
    BLOCK_ALL_GAMES.loc[index,'LEAD_LAG'] = 'ALL'
  elif row['SCOREMARGIN']>0:
    BLOCK_ALL_GAMES.loc[index,'LEAD_LAG'] = 'HOME LEAD'
  elif row['SCOREMARGIN']<0:
    BLOCK_ALL_GAMES.loc[index,'LEAD_LAG'] = 'HOME DEFICIT'

# %%
#Add a column to check scoremargin and if it is =/>/< than 0
for index,row in BLOCK_ALL_GAMES.iterrows():
  if ((row['SECONDS']<=720) & (row['SECONDS']>300)):
    BLOCK_ALL_GAMES.loc[index,'CLUTCH'] = '6-12 MIN'
  elif ((row['SECONDS']<=300) & (row['SECONDS']>120)):
    BLOCK_ALL_GAMES.loc[index,'CLUTCH'] = '2-5 MIN'
  elif ((row['SECONDS']<=120)):
    BLOCK_ALL_GAMES.loc[index,'CLUTCH'] = 'LESS THAN 2 MIN'
  # elif ((row['SECONDS']<=120) & (row['SECONDS']>60)):
  #   BLOCK_ALL_GAMES.loc[index,'CLUTCH'] = '1-2 MIN'
  # elif ((row['SECONDS']<=60) & (row['SECONDS']>30)):
  #   BLOCK_ALL_GAMES.loc[index,'CLUTCH'] = '30 SEC-1 MIN'
  # elif ((row['SECONDS']<=30)):
  #   BLOCK_ALL_GAMES.loc[index,'CLUTCH'] = 'LESS THAN 30 SEC'

# %%
#Add a column to check scoremargin and if it is =/>/< than 0
for index,row in BLOCK_ALL_GAMES.iterrows():
  if row['SCOREMARGIN']==0:
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '0'
  elif ((row['SCOREMARGIN']<=5) & (row['SCOREMARGIN']>0)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '<=5'
  elif ((row['SCOREMARGIN']<=10) & (row['SCOREMARGIN']>5)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '6-10'
  elif ((row['SCOREMARGIN']<=20) & (row['SCOREMARGIN']>10)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '11-20'
  elif ((row['SCOREMARGIN']>20)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '>20'

  elif ((row['SCOREMARGIN']>=-5) & (row['SCOREMARGIN']<0)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '<=5'
  elif ((row['SCOREMARGIN']>=-10) & (row['SCOREMARGIN']<-5)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '6-10'
  elif ((row['SCOREMARGIN']>=-20) & (row['SCOREMARGIN']<-10)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '11-20'
  elif ((row['SCOREMARGIN']<-20)):
    BLOCK_ALL_GAMES.loc[index,'MARGIN'] = '>20'

# %%
BLOCK_ALL_GAMES=BLOCK_ALL_GAMES.merge(result_bq, how='left', left_on=['GAME_ID','GAME_DATE'], right_on=['GAME_ID','GAME_DATE'])
BLOCK_ALL_GAMES.head()
# Out:
# Warning: Total number of columns (69) exceeds max_columns (20). Falling back to pandas display.
#       GAME_ID   GAME_DATE    MATCHUP  EVENTNUM  PERIOD PCTIMESTRING  \
# 0  0022200035  2022-10-22  OKC @ DEN         4       1        12:00
# 1  0022200035  2022-10-22  OKC @ DEN         7       1        11:47
# 2  0022200035  2022-10-22  OKC @ DEN         8       1        11:45
# 3  0022200035  2022-10-22  OKC @ DEN         9       1        11:40
# 4  0022200035  2022-10-22  OKC @ DEN        11       1        11:34
#
#    EVENTMSGTYPE  EVENTMSGACTIONTYPE      Event                     Event_Type  \
# 0            10                   0  Jump Ball                      Jump ball
# 1             2                   1  Missed FG        Jump Shot/3PT Jump Shot
# 2             4                   0    Rebound                        Rebound
# 3             5                   1   Turnover             Bad Pass TO: Steal
# 4             2                 103  Missed FG  Running Pull/3PT Running Pull
#
#                                     HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 0  Jump Ball Jokic vs. Robinson-Earl: Tip to Giddey                 No
# 1                                                No                 No
# 2                      Murray REBOUND (Off:0 Def:1)                 No
# 3                  Murray Bad Pass Turnover (P1.T1)                 No
# 4                                                No                 No
#
#                                   VISITORDESCRIPTION SCORE  SCOREMARGIN  \
# 0                                                 No   0-0            0
# 1                        MISS Dort 24' 3PT Jump Shot   0-0            0
# 2                                                 No   0-0            0
# 3                           Pokusevski STEAL (1 STL)   0-0            0
# 4  MISS Gilgeous-Alexander 26' 3PT Running Pull-U...   0-0            0
#
#    PERSON1TYPE  PLAYER1_ID             PLAYER1_NAME PLAYER1_TEAM_ID  \
# 0          4.0      203999             Nikola Jokic    1610612743.0
# 1          5.0     1629652            Luguentz Dort    1610612760.0
# 2          4.0     1627750             Jamal Murray    1610612743.0
# 3          4.0     1627750             Jamal Murray    1610612743.0
# 4          5.0     1628983  Shai Gilgeous-Alexander    1610612760.0
#
#   PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 0            Denver               Nuggets                       DEN
# 1     Oklahoma City               Thunder                       OKC
# 2            Denver               Nuggets                       DEN
# 3            Denver               Nuggets                       DEN
# 4     Oklahoma City               Thunder                       OKC
#
#    PERSON2TYPE  PLAYER2_ID            PLAYER2_NAME PLAYER2_TEAM_ID  \
# 0            5     1630526  Jeremiah Robinson-Earl    1610612760.0
# 1            0           0                      No              No
# 2            0           0                      No              No
# 3            5     1630197      Aleksej Pokusevski    1610612760.0
# 4            0           0                      No              No
#
#   PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  \
# 0     Oklahoma City               Thunder                       OKC
# 1                No                    No                        No
# 2                No                    No                        No
# 3     Oklahoma City               Thunder                       OKC
# 4                No                    No                        No
#
#    PERSON3TYPE  PLAYER3_ID PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 0            5     1630581  Josh Giddey    1610612760.0     Oklahoma City
# 1            0           0           No              No                No
# 2            0           0           No              No                No
# 3            0           0           No              No                No
# 4            0           0           No              No                No
#
#   PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG  \
# 0               Thunder                       OKC                     1
# 1                    No                        No                     1
# 2                    No                        No                     1
# 3                    No                        No                     1
# 4                    No                        No                     1
#
#   WCTIMESTRING   Season   RK  MINUTE  SECOND  SECONDS  overall_rank  \
# 0      9:17 PM  2022-23  2.0      12       0      720             2
# 1      9:17 PM  2022-23  3.0      11      47      707             3
# 2      9:17 PM  2022-23  4.0      11      45      705             4
# 3      9:17 PM  2022-23  5.0      11      40      700             5
# 4      9:17 PM  2022-23  6.0      11      34      694             6
#
#    SECONDS_Diff  SCOREMARGIN_Diff LEAD_LAG    CLUTCH MARGIN TEAM_ABBREVIATION  \
# 0           0.0               0.0      ALL  6-12 MIN      0               DEN
# 1          13.0               0.0      ALL  6-12 MIN      0               DEN
# 2           2.0               0.0      ALL  6-12 MIN      0               DEN
# 3           5.0               0.0      ALL  6-12 MIN      0               DEN
# 4           6.0               0.0      ALL  6-12 MIN      0               DEN
#
#   WL  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  \
# 0  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 1  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 2  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 3  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 4  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
#
#    REB  AST  STL  BLK  TOV  PF  PTS
# 0   46   33    5    6   18  21  122
# 1   46   33    5    6   18  21  122
# 2   46   33    5    6   18  21  122
# 3   46   33    5    6   18  21  122
# 4   46   33    5    6   18  21  122

# %%
BLOCK_ALL_GAMES=BLOCK_ALL_GAMES.merge(shooting_df, how='left', left_on=['GAME_ID','MINUTE','SECOND','PLAYER1_NAME','PERIOD'], right_on=['GAME','MINUTES_REMAINING','SECONDS_REMAINING','PLAYER_NAME','PERIOD_LOC'])

# %%
BLOCK_ALL_GAMES.head()
# Out:
# Warning: Total number of columns (76) exceeds max_columns (20). Falling back to pandas display.
#       GAME_ID   GAME_DATE    MATCHUP  EVENTNUM  PERIOD PCTIMESTRING  \
# 0  0022200035  2022-10-22  OKC @ DEN         4       1        12:00
# 1  0022200035  2022-10-22  OKC @ DEN         7       1        11:47
# 2  0022200035  2022-10-22  OKC @ DEN         8       1        11:45
# 3  0022200035  2022-10-22  OKC @ DEN         9       1        11:40
# 4  0022200035  2022-10-22  OKC @ DEN        11       1        11:34
#
#    EVENTMSGTYPE  EVENTMSGACTIONTYPE      Event                     Event_Type  \
# 0            10                   0  Jump Ball                      Jump ball
# 1             2                   1  Missed FG        Jump Shot/3PT Jump Shot
# 2             4                   0    Rebound                        Rebound
# 3             5                   1   Turnover             Bad Pass TO: Steal
# 4             2                 103  Missed FG  Running Pull/3PT Running Pull
#
#                                     HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 0  Jump Ball Jokic vs. Robinson-Earl: Tip to Giddey                 No
# 1                                                No                 No
# 2                      Murray REBOUND (Off:0 Def:1)                 No
# 3                  Murray Bad Pass Turnover (P1.T1)                 No
# 4                                                No                 No
#
#                                   VISITORDESCRIPTION SCORE  SCOREMARGIN  \
# 0                                                 No   0-0            0
# 1                        MISS Dort 24' 3PT Jump Shot   0-0            0
# 2                                                 No   0-0            0
# 3                           Pokusevski STEAL (1 STL)   0-0            0
# 4  MISS Gilgeous-Alexander 26' 3PT Running Pull-U...   0-0            0
#
#    PERSON1TYPE  PLAYER1_ID             PLAYER1_NAME PLAYER1_TEAM_ID  \
# 0          4.0      203999             Nikola Jokic    1610612743.0
# 1          5.0     1629652            Luguentz Dort    1610612760.0
# 2          4.0     1627750             Jamal Murray    1610612743.0
# 3          4.0     1627750             Jamal Murray    1610612743.0
# 4          5.0     1628983  Shai Gilgeous-Alexander    1610612760.0
#
#   PLAYER1_TEAM_CITY PLAYER1_TEAM_NICKNAME PLAYER1_TEAM_ABBREVIATION  \
# 0            Denver               Nuggets                       DEN
# 1     Oklahoma City               Thunder                       OKC
# 2            Denver               Nuggets                       DEN
# 3            Denver               Nuggets                       DEN
# 4     Oklahoma City               Thunder                       OKC
#
#    PERSON2TYPE  PLAYER2_ID            PLAYER2_NAME PLAYER2_TEAM_ID  \
# 0            5     1630526  Jeremiah Robinson-Earl    1610612760.0
# 1            0           0                      No              No
# 2            0           0                      No              No
# 3            5     1630197      Aleksej Pokusevski    1610612760.0
# 4            0           0                      No              No
#
#   PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME PLAYER2_TEAM_ABBREVIATION  \
# 0     Oklahoma City               Thunder                       OKC
# 1                No                    No                        No
# 2                No                    No                        No
# 3     Oklahoma City               Thunder                       OKC
# 4                No                    No                        No
#
#    PERSON3TYPE  PLAYER3_ID PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 0            5     1630581  Josh Giddey    1610612760.0     Oklahoma City
# 1            0           0           No              No                No
# 2            0           0           No              No                No
# 3            0           0           No              No                No
# 4            0           0           No              No                No
#
#   PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG  \
# 0               Thunder                       OKC                     1
# 1                    No                        No                     1
# 2                    No                        No                     1
# 3                    No                        No                     1
# 4                    No                        No                     1
#
#   WCTIMESTRING   Season   RK  MINUTE  SECOND  SECONDS  overall_rank  \
# 0      9:17 PM  2022-23  2.0      12       0      720             2
# 1      9:17 PM  2022-23  3.0      11      47      707             3
# 2      9:17 PM  2022-23  4.0      11      45      705             4
# 3      9:17 PM  2022-23  5.0      11      40      700             5
# 4      9:17 PM  2022-23  6.0      11      34      694             6
#
#    SECONDS_Diff  SCOREMARGIN_Diff LEAD_LAG    CLUTCH MARGIN TEAM_ABBREVIATION  \
# 0           0.0               0.0      ALL  6-12 MIN      0               DEN
# 1          13.0               0.0      ALL  6-12 MIN      0               DEN
# 2           2.0               0.0      ALL  6-12 MIN      0               DEN
# 3           5.0               0.0      ALL  6-12 MIN      0               DEN
# 4           6.0               0.0      ALL  6-12 MIN      0               DEN
#
#   WL  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  \
# 0  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 1  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 2  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 3  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
# 4  W   42   85   0.494    20    38    0.526   18   31   0.581     9    37
#
#    REB  AST  STL  BLK  TOV  PF  PTS        GAME              PLAYER_NAME  \
# 0   46   33    5    6   18  21  122         NaN                      NaN
# 1   46   33    5    6   18  21  122  0022200035            Luguentz Dort
# 2   46   33    5    6   18  21  122         NaN                      NaN
# 3   46   33    5    6   18  21  122         NaN                      NaN
# 4   46   33    5    6   18  21  122  0022200035  Shai Gilgeous-Alexander
#
#    PERIOD_LOC  MINUTES_REMAINING  SECONDS_REMAINING       SHOT_TYPE  \
# 0        <NA>               <NA>               <NA>             NaN
# 1           1                 11                 47  3PT Field Goal
# 2        <NA>               <NA>               <NA>             NaN
# 3        <NA>               <NA>               <NA>             NaN
# 4           1                 11                 34  3PT Field Goal
#
#      SHOT_ZONE_BASIC
# 0                NaN
# 1      Left Corner 3
# 2                NaN
# 3                NaN
# 4  Above the Break 3

# %%
TEAM='DEN'

# %%
#SCORING grouped by period, Lead Lag AND CLUTCH TIME. REMOVING GAME LEVEL GROUPING
############################################################## CHnge team abbr too team in analysis************************************
PTS_LEAD_LAG_CLUTCH_MARGIN=BLOCK_ALL_GAMES[((BLOCK_ALL_GAMES.PLAYER1_NAME!="No") & (BLOCK_ALL_GAMES.Event=="Made FG") & (BLOCK_ALL_GAMES.PLAYER1_TEAM_ABBREVIATION==TEAM))]
PTS_LEAD_LAG_CLUTCH_MARGIN=PTS_LEAD_LAG_CLUTCH_MARGIN.groupby(by=["PLAYER1_TEAM_ABBREVIATION","PERIOD","LEAD_LAG","CLUTCH","MARGIN","SHOT_TYPE","PLAYER1_NAME"])["Event"].count()
PTS_LEAD_LAG_CLUTCH_MARGIN=pd.DataFrame(PTS_LEAD_LAG_CLUTCH_MARGIN)
PTS_LEAD_LAG_CLUTCH_MARGIN.reset_index(inplace=True)
PTS_LEAD_LAG_CLUTCH_MARGIN[((PTS_LEAD_LAG_CLUTCH_MARGIN["PERIOD"].isin([1,2,3,4])) & (PTS_LEAD_LAG_CLUTCH_MARGIN["PLAYER1_NAME"]=='Nikola Jokic'))]
# Out:
#     PLAYER1_TEAM_ABBREVIATION  PERIOD      LEAD_LAG           CLUTCH MARGIN  \
# 10                        DEN       1           ALL         6-12 MIN      0
# 30                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 34                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 48                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 71                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 86                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 94                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 104                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 112                       DEN       1     HOME LEAD          2-5 MIN    >20
# 116                       DEN       1     HOME LEAD         6-12 MIN  11-20
# 123                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 129                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 138                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 145                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 160                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 172                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 189                       DEN       2           ALL         6-12 MIN      0
# 193                       DEN       2           ALL  LESS THAN 2 MIN      0
# 203                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 214                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 232                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 248                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 264                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 279                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 297                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 304                       DEN       2     HOME LEAD          2-5 MIN    >20
# 316                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 334                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 353                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 362                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 372                       DEN       2     HOME LEAD         6-12 MIN    >20
# 384                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 392                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 401                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 407                       DEN       2     HOME LEAD  LESS THAN 2 MIN    >20
# 413                       DEN       3           ALL         6-12 MIN      0
# 425                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 433                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 442                       DEN       3  HOME DEFICIT         6-12 MIN   6-10
# 451                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 458                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 461                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 469                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 477                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 485                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 493                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 497                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 499                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 510                       DEN       3     HOME LEAD          2-5 MIN    >20
# 520                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 528                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 535                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 541                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 547                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 553                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 559                       DEN       3     HOME LEAD         6-12 MIN    >20
# 564                       DEN       3     HOME LEAD         6-12 MIN    >20
# 572                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 582                       DEN       3     HOME LEAD  LESS THAN 2 MIN   6-10
# 598                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 602                       DEN       4           ALL          2-5 MIN      0
# 604                       DEN       4           ALL         6-12 MIN      0
# 609                       DEN       4           ALL  LESS THAN 2 MIN      0
# 614                       DEN       4  HOME DEFICIT          2-5 MIN   6-10
# 618                       DEN       4  HOME DEFICIT          2-5 MIN    <=5
# 626                       DEN       4  HOME DEFICIT         6-12 MIN  11-20
# 630                       DEN       4  HOME DEFICIT         6-12 MIN  11-20
# 636                       DEN       4  HOME DEFICIT         6-12 MIN   6-10
# 648                       DEN       4  HOME DEFICIT         6-12 MIN    <=5
# 663                       DEN       4  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 674                       DEN       4     HOME LEAD          2-5 MIN  11-20
# 685                       DEN       4     HOME LEAD          2-5 MIN   6-10
# 688                       DEN       4     HOME LEAD          2-5 MIN   6-10
# 692                       DEN       4     HOME LEAD          2-5 MIN    <=5
# 699                       DEN       4     HOME LEAD          2-5 MIN    >20
# 705                       DEN       4     HOME LEAD          2-5 MIN    >20
# 718                       DEN       4     HOME LEAD         6-12 MIN  11-20
# 742                       DEN       4     HOME LEAD         6-12 MIN   6-10
# 748                       DEN       4     HOME LEAD         6-12 MIN   6-10
# 756                       DEN       4     HOME LEAD         6-12 MIN    <=5
# 772                       DEN       4     HOME LEAD         6-12 MIN    >20
# 788                       DEN       4     HOME LEAD  LESS THAN 2 MIN  11-20
# 794                       DEN       4     HOME LEAD  LESS THAN 2 MIN   6-10
# 799                       DEN       4     HOME LEAD  LESS THAN 2 MIN    <=5
# 803                       DEN       4     HOME LEAD  LESS THAN 2 MIN    <=5
#
#           SHOT_TYPE  PLAYER1_NAME  Event
# 10   2PT Field Goal  Nikola Jokic      7
# 30   2PT Field Goal  Nikola Jokic      6
# 34   3PT Field Goal  Nikola Jokic      1
# 48   2PT Field Goal  Nikola Jokic     12
# 71   2PT Field Goal  Nikola Jokic      1
# 86   2PT Field Goal  Nikola Jokic      5
# 94   3PT Field Goal  Nikola Jokic      1
# 104  2PT Field Goal  Nikola Jokic     17
# 112  2PT Field Goal  Nikola Jokic      1
# 116  2PT Field Goal  Nikola Jokic      1
# 123  2PT Field Goal  Nikola Jokic      9
# 129  3PT Field Goal  Nikola Jokic      1
# 138  2PT Field Goal  Nikola Jokic     33
# 145  3PT Field Goal  Nikola Jokic      2
# 160  2PT Field Goal  Nikola Jokic      1
# 172  2PT Field Goal  Nikola Jokic      1
# 189  2PT Field Goal  Nikola Jokic      3
# 193  2PT Field Goal  Nikola Jokic      1
# 203  2PT Field Goal  Nikola Jokic      5
# 214  2PT Field Goal  Nikola Jokic      5
# 232  2PT Field Goal  Nikola Jokic      8
# 248  2PT Field Goal  Nikola Jokic      7
# 264  2PT Field Goal  Nikola Jokic      4
# 279  2PT Field Goal  Nikola Jokic      7
# 297  2PT Field Goal  Nikola Jokic      6
# 304  2PT Field Goal  Nikola Jokic      2
# 316  2PT Field Goal  Nikola Jokic      4
# 334  2PT Field Goal  Nikola Jokic      1
# 353  2PT Field Goal  Nikola Jokic      4
# 362  3PT Field Goal  Nikola Jokic      1
# 372  2PT Field Goal  Nikola Jokic      3
# 384  2PT Field Goal  Nikola Jokic      6
# 392  2PT Field Goal  Nikola Jokic      3
# 401  2PT Field Goal  Nikola Jokic      2
# 407  2PT Field Goal  Nikola Jokic      2
# 413  2PT Field Goal  Nikola Jokic      1
# 425  2PT Field Goal  Nikola Jokic      2
# 433  2PT Field Goal  Nikola Jokic      2
# 442  2PT Field Goal  Nikola Jokic      5
# 451  2PT Field Goal  Nikola Jokic      5
# 458  3PT Field Goal  Nikola Jokic      1
# 461  2PT Field Goal  Nikola Jokic      2
# 469  3PT Field Goal  Nikola Jokic      2
# 477  2PT Field Goal  Nikola Jokic      5
# 485  3PT Field Goal  Nikola Jokic      2
# 493  2PT Field Goal  Nikola Jokic      4
# 497  3PT Field Goal  Nikola Jokic      1
# 499  2PT Field Goal  Nikola Jokic      1
# 510  2PT Field Goal  Nikola Jokic      2
# 520  2PT Field Goal  Nikola Jokic     13
# 528  3PT Field Goal  Nikola Jokic      1
# 535  2PT Field Goal  Nikola Jokic     17
# 541  3PT Field Goal  Nikola Jokic      3
# 547  2PT Field Goal  Nikola Jokic      9
# 553  3PT Field Goal  Nikola Jokic      1
# 559  2PT Field Goal  Nikola Jokic      7
# 564  3PT Field Goal  Nikola Jokic      2
# 572  2PT Field Goal  Nikola Jokic      3
# 582  2PT Field Goal  Nikola Jokic      3
# 598  2PT Field Goal  Nikola Jokic      1
# 602  2PT Field Goal  Nikola Jokic      3
# 604  2PT Field Goal  Nikola Jokic      1
# 609  2PT Field Goal  Nikola Jokic      1
# 614  2PT Field Goal  Nikola Jokic      2
# 618  2PT Field Goal  Nikola Jokic      4
# 626  2PT Field Goal  Nikola Jokic      1
# 630  3PT Field Goal  Nikola Jokic      2
# 636  2PT Field Goal  Nikola Jokic      4
# 648  2PT Field Goal  Nikola Jokic      2
# 663  2PT Field Goal  Nikola Jokic      4
# 674  2PT Field Goal  Nikola Jokic     10
# 685  2PT Field Goal  Nikola Jokic      1
# 688  3PT Field Goal  Nikola Jokic      1
# 692  3PT Field Goal  Nikola Jokic      1
# 699  2PT Field Goal  Nikola Jokic      2
# 705  3PT Field Goal  Nikola Jokic      1
# 718  2PT Field Goal  Nikola Jokic      8
# 742  2PT Field Goal  Nikola Jokic      2
# 748  3PT Field Goal  Nikola Jokic      2
# 756  2PT Field Goal  Nikola Jokic      1
# 772  2PT Field Goal  Nikola Jokic      1
# 788  2PT Field Goal  Nikola Jokic      1
# 794  2PT Field Goal  Nikola Jokic      1
# 799  2PT Field Goal  Nikola Jokic      1
# 803  3PT Field Goal  Nikola Jokic      1

# %%
for index,row in PTS_LEAD_LAG_CLUTCH_MARGIN.iterrows():
  if (row['CLUTCH']=="6-12 MIN"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'CLUTCH_RK'] = 1
  elif (row['CLUTCH']=="2-5 MIN"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'CLUTCH_RK'] = 2
  elif (row['CLUTCH']=="LESS THAN 2 MIN"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'CLUTCH_RK'] = 3

for index,row in PTS_LEAD_LAG_CLUTCH_MARGIN.iterrows():
  if (row['MARGIN']=="0"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'MARGIN_RK'] = 3
  elif (row['MARGIN']=="<=5"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'MARGIN_RK'] = 3
  elif (row['MARGIN']=="6-10"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'MARGIN_RK'] = 2
  elif (row['MARGIN']=="11-20"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'MARGIN_RK'] = 1
  elif (row['MARGIN']==">20"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'MARGIN_RK'] = 0.5

for index,row in PTS_LEAD_LAG_CLUTCH_MARGIN.iterrows():
  if (row['SHOT_TYPE']=="2PT Field Goal"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'FG_RK'] = 2
  elif (row['SHOT_TYPE']=="3PT Field Goal"):
    PTS_LEAD_LAG_CLUTCH_MARGIN.loc[index,'FG_RK'] = 3
PTS_LEAD_LAG_CLUTCH_MARGIN
# Out:
#     PLAYER1_TEAM_ABBREVIATION  PERIOD      LEAD_LAG           CLUTCH MARGIN  \
# 0                         DEN       1           ALL          2-5 MIN      0
# 1                         DEN       1           ALL          2-5 MIN      0
# 2                         DEN       1           ALL          2-5 MIN      0
# 3                         DEN       1           ALL          2-5 MIN      0
# 4                         DEN       1           ALL         6-12 MIN      0
# 5                         DEN       1           ALL         6-12 MIN      0
# 6                         DEN       1           ALL         6-12 MIN      0
# 7                         DEN       1           ALL         6-12 MIN      0
# 8                         DEN       1           ALL         6-12 MIN      0
# 9                         DEN       1           ALL         6-12 MIN      0
# 10                        DEN       1           ALL         6-12 MIN      0
# 11                        DEN       1           ALL         6-12 MIN      0
# 12                        DEN       1           ALL         6-12 MIN      0
# 13                        DEN       1           ALL         6-12 MIN      0
# 14                        DEN       1           ALL         6-12 MIN      0
# 15                        DEN       1           ALL         6-12 MIN      0
# 16                        DEN       1           ALL  LESS THAN 2 MIN      0
# 17                        DEN       1           ALL  LESS THAN 2 MIN      0
# 18                        DEN       1           ALL  LESS THAN 2 MIN      0
# 19                        DEN       1           ALL  LESS THAN 2 MIN      0
# 20                        DEN       1           ALL  LESS THAN 2 MIN      0
# 21                        DEN       1  HOME DEFICIT          2-5 MIN   6-10
# 22                        DEN       1  HOME DEFICIT          2-5 MIN   6-10
# 23                        DEN       1  HOME DEFICIT          2-5 MIN   6-10
# 24                        DEN       1  HOME DEFICIT          2-5 MIN   6-10
# 25                        DEN       1  HOME DEFICIT          2-5 MIN   6-10
# 26                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 27                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 28                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 29                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 30                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 31                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 32                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 33                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 34                        DEN       1  HOME DEFICIT          2-5 MIN    <=5
# 35                        DEN       1  HOME DEFICIT         6-12 MIN  11-20
# 36                        DEN       1  HOME DEFICIT         6-12 MIN   6-10
# 37                        DEN       1  HOME DEFICIT         6-12 MIN   6-10
# 38                        DEN       1  HOME DEFICIT         6-12 MIN   6-10
# 39                        DEN       1  HOME DEFICIT         6-12 MIN   6-10
# 40                        DEN       1  HOME DEFICIT         6-12 MIN   6-10
# 41                        DEN       1  HOME DEFICIT         6-12 MIN   6-10
# 42                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 43                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 44                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 45                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 46                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 47                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 48                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 49                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 50                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 51                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 52                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 53                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 54                        DEN       1  HOME DEFICIT         6-12 MIN    <=5
# 55                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 56                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 57                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 58                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 59                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 60                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 61                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 62                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 63                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 64                        DEN       1  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 65                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 66                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 67                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 68                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 69                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 70                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 71                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 72                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 73                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 74                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 75                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 76                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 77                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 78                        DEN       1     HOME LEAD          2-5 MIN  11-20
# 79                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 80                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 81                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 82                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 83                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 84                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 85                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 86                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 87                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 88                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 89                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 90                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 91                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 92                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 93                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 94                        DEN       1     HOME LEAD          2-5 MIN   6-10
# 95                        DEN       1     HOME LEAD          2-5 MIN    <=5
# 96                        DEN       1     HOME LEAD          2-5 MIN    <=5
# 97                        DEN       1     HOME LEAD          2-5 MIN    <=5
# 98                        DEN       1     HOME LEAD          2-5 MIN    <=5
# 99                        DEN       1     HOME LEAD          2-5 MIN    <=5
# 100                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 101                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 102                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 103                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 104                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 105                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 106                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 107                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 108                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 109                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 110                       DEN       1     HOME LEAD          2-5 MIN    <=5
# 111                       DEN       1     HOME LEAD          2-5 MIN    >20
# 112                       DEN       1     HOME LEAD          2-5 MIN    >20
# 113                       DEN       1     HOME LEAD         6-12 MIN  11-20
# 114                       DEN       1     HOME LEAD         6-12 MIN  11-20
# 115                       DEN       1     HOME LEAD         6-12 MIN  11-20
# 116                       DEN       1     HOME LEAD         6-12 MIN  11-20
# 117                       DEN       1     HOME LEAD         6-12 MIN  11-20
# 118                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 119                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 120                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 121                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 122                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 123                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 124                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 125                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 126                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 127                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 128                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 129                       DEN       1     HOME LEAD         6-12 MIN   6-10
# 130                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 131                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 132                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 133                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 134                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 135                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 136                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 137                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 138                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 139                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 140                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 141                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 142                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 143                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 144                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 145                       DEN       1     HOME LEAD         6-12 MIN    <=5
# 146                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 147                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 148                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 149                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 150                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 151                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 152                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 153                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 154                       DEN       1     HOME LEAD  LESS THAN 2 MIN  11-20
# 155                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 156                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 157                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 158                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 159                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 160                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 161                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 162                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 163                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 164                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 165                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 166                       DEN       1     HOME LEAD  LESS THAN 2 MIN   6-10
# 167                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 168                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 169                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 170                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 171                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 172                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 173                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 174                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 175                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 176                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 177                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 178                       DEN       1     HOME LEAD  LESS THAN 2 MIN    <=5
# 179                       DEN       1     HOME LEAD  LESS THAN 2 MIN    >20
# 180                       DEN       1     HOME LEAD  LESS THAN 2 MIN    >20
# 181                       DEN       1     HOME LEAD  LESS THAN 2 MIN    >20
# 182                       DEN       1     HOME LEAD  LESS THAN 2 MIN    >20
# 183                       DEN       1     HOME LEAD  LESS THAN 2 MIN    >20
# 184                       DEN       2           ALL          2-5 MIN      0
# 185                       DEN       2           ALL          2-5 MIN      0
# 186                       DEN       2           ALL         6-12 MIN      0
# 187                       DEN       2           ALL         6-12 MIN      0
# 188                       DEN       2           ALL         6-12 MIN      0
# 189                       DEN       2           ALL         6-12 MIN      0
# 190                       DEN       2           ALL         6-12 MIN      0
# 191                       DEN       2           ALL         6-12 MIN      0
# 192                       DEN       2           ALL         6-12 MIN      0
# 193                       DEN       2           ALL  LESS THAN 2 MIN      0
# 194                       DEN       2           ALL  LESS THAN 2 MIN      0
# 195                       DEN       2           ALL  LESS THAN 2 MIN      0
# 196                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 197                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 198                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 199                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 200                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 201                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 202                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 203                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 204                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 205                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 206                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 207                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 208                       DEN       2  HOME DEFICIT          2-5 MIN   6-10
# 209                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 210                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 211                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 212                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 213                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 214                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 215                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 216                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 217                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 218                       DEN       2  HOME DEFICIT          2-5 MIN    <=5
# 219                       DEN       2  HOME DEFICIT         6-12 MIN  11-20
# 220                       DEN       2  HOME DEFICIT         6-12 MIN  11-20
# 221                       DEN       2  HOME DEFICIT         6-12 MIN  11-20
# 222                       DEN       2  HOME DEFICIT         6-12 MIN  11-20
# 223                       DEN       2  HOME DEFICIT         6-12 MIN  11-20
# 224                       DEN       2  HOME DEFICIT         6-12 MIN  11-20
# 225                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 226                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 227                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 228                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 229                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 230                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 231                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 232                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 233                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 234                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 235                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 236                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 237                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 238                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 239                       DEN       2  HOME DEFICIT         6-12 MIN   6-10
# 240                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 241                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 242                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 243                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 244                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 245                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 246                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 247                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 248                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 249                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 250                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 251                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 252                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 253                       DEN       2  HOME DEFICIT         6-12 MIN    <=5
# 254                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 255                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 256                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 257                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 258                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 259                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 260                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 261                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 262                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 263                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 264                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 265                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 266                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 267                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 268                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 269                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 270                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 271                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 272                       DEN       2  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 273                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 274                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 275                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 276                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 277                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 278                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 279                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 280                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 281                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 282                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 283                       DEN       2     HOME LEAD          2-5 MIN  11-20
# 284                       DEN       2     HOME LEAD          2-5 MIN   6-10
# 285                       DEN       2     HOME LEAD          2-5 MIN   6-10
# 286                       DEN       2     HOME LEAD          2-5 MIN   6-10
# 287                       DEN       2     HOME LEAD          2-5 MIN   6-10
# 288                       DEN       2     HOME LEAD          2-5 MIN   6-10
# 289                       DEN       2     HOME LEAD          2-5 MIN   6-10
# 290                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 291                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 292                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 293                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 294                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 295                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 296                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 297                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 298                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 299                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 300                       DEN       2     HOME LEAD          2-5 MIN    <=5
# 301                       DEN       2     HOME LEAD          2-5 MIN    >20
# 302                       DEN       2     HOME LEAD          2-5 MIN    >20
# 303                       DEN       2     HOME LEAD          2-5 MIN    >20
# 304                       DEN       2     HOME LEAD          2-5 MIN    >20
# 305                       DEN       2     HOME LEAD          2-5 MIN    >20
# 306                       DEN       2     HOME LEAD          2-5 MIN    >20
# 307                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 308                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 309                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 310                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 311                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 312                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 313                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 314                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 315                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 316                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 317                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 318                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 319                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 320                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 321                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 322                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 323                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 324                       DEN       2     HOME LEAD         6-12 MIN  11-20
# 325                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 326                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 327                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 328                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 329                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 330                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 331                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 332                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 333                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 334                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 335                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 336                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 337                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 338                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 339                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 340                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 341                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 342                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 343                       DEN       2     HOME LEAD         6-12 MIN   6-10
# 344                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 345                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 346                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 347                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 348                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 349                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 350                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 351                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 352                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 353                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 354                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 355                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 356                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 357                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 358                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 359                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 360                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 361                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 362                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 363                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 364                       DEN       2     HOME LEAD         6-12 MIN    <=5
# 365                       DEN       2     HOME LEAD         6-12 MIN    >20
# 366                       DEN       2     HOME LEAD         6-12 MIN    >20
# 367                       DEN       2     HOME LEAD         6-12 MIN    >20
# 368                       DEN       2     HOME LEAD         6-12 MIN    >20
# 369                       DEN       2     HOME LEAD         6-12 MIN    >20
# 370                       DEN       2     HOME LEAD         6-12 MIN    >20
# 371                       DEN       2     HOME LEAD         6-12 MIN    >20
# 372                       DEN       2     HOME LEAD         6-12 MIN    >20
# 373                       DEN       2     HOME LEAD         6-12 MIN    >20
# 374                       DEN       2     HOME LEAD         6-12 MIN    >20
# 375                       DEN       2     HOME LEAD         6-12 MIN    >20
# 376                       DEN       2     HOME LEAD         6-12 MIN    >20
# 377                       DEN       2     HOME LEAD         6-12 MIN    >20
# 378                       DEN       2     HOME LEAD         6-12 MIN    >20
# 379                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 380                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 381                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 382                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 383                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 384                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 385                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 386                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 387                       DEN       2     HOME LEAD  LESS THAN 2 MIN  11-20
# 388                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 389                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 390                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 391                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 392                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 393                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 394                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 395                       DEN       2     HOME LEAD  LESS THAN 2 MIN   6-10
# 396                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 397                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 398                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 399                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 400                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 401                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 402                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 403                       DEN       2     HOME LEAD  LESS THAN 2 MIN    <=5
# 404                       DEN       2     HOME LEAD  LESS THAN 2 MIN    >20
# 405                       DEN       2     HOME LEAD  LESS THAN 2 MIN    >20
# 406                       DEN       2     HOME LEAD  LESS THAN 2 MIN    >20
# 407                       DEN       2     HOME LEAD  LESS THAN 2 MIN    >20
# 408                       DEN       2     HOME LEAD  LESS THAN 2 MIN    >20
# 409                       DEN       3           ALL          2-5 MIN      0
# 410                       DEN       3           ALL          2-5 MIN      0
# 411                       DEN       3           ALL         6-12 MIN      0
# 412                       DEN       3           ALL         6-12 MIN      0
# 413                       DEN       3           ALL         6-12 MIN      0
# 414                       DEN       3           ALL         6-12 MIN      0
# 415                       DEN       3           ALL         6-12 MIN      0
# 416                       DEN       3           ALL         6-12 MIN      0
# 417                       DEN       3           ALL         6-12 MIN      0
# 418                       DEN       3  HOME DEFICIT          2-5 MIN  11-20
# 419                       DEN       3  HOME DEFICIT          2-5 MIN  11-20
# 420                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 421                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 422                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 423                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 424                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 425                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 426                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 427                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 428                       DEN       3  HOME DEFICIT          2-5 MIN   6-10
# 429                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 430                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 431                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 432                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 433                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 434                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 435                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 436                       DEN       3  HOME DEFICIT          2-5 MIN    <=5
# 437                       DEN       3  HOME DEFICIT         6-12 MIN  11-20
# 438                       DEN       3  HOME DEFICIT         6-12 MIN  11-20
# 439                       DEN       3  HOME DEFICIT         6-12 MIN   6-10
# 440                       DEN       3  HOME DEFICIT         6-12 MIN   6-10
# 441                       DEN       3  HOME DEFICIT         6-12 MIN   6-10
# 442                       DEN       3  HOME DEFICIT         6-12 MIN   6-10
# 443                       DEN       3  HOME DEFICIT         6-12 MIN   6-10
# 444                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 445                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 446                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 447                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 448                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 449                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 450                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 451                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 452                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 453                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 454                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 455                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 456                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 457                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 458                       DEN       3  HOME DEFICIT         6-12 MIN    <=5
# 459                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN  11-20
# 460                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 461                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN   6-10
# 462                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 463                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 464                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 465                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 466                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 467                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 468                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 469                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 470                       DEN       3  HOME DEFICIT  LESS THAN 2 MIN    <=5
# 471                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 472                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 473                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 474                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 475                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 476                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 477                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 478                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 479                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 480                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 481                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 482                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 483                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 484                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 485                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 486                       DEN       3     HOME LEAD          2-5 MIN  11-20
# 487                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 488                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 489                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 490                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 491                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 492                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 493                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 494                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 495                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 496                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 497                       DEN       3     HOME LEAD          2-5 MIN   6-10
# 498                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 499                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 500                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 501                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 502                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 503                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 504                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 505                       DEN       3     HOME LEAD          2-5 MIN    <=5
# 506                       DEN       3     HOME LEAD          2-5 MIN    >20
# 507                       DEN       3     HOME LEAD          2-5 MIN    >20
# 508                       DEN       3     HOME LEAD          2-5 MIN    >20
# 509                       DEN       3     HOME LEAD          2-5 MIN    >20
# 510                       DEN       3     HOME LEAD          2-5 MIN    >20
# 511                       DEN       3     HOME LEAD          2-5 MIN    >20
# 512                       DEN       3     HOME LEAD          2-5 MIN    >20
# 513                       DEN       3     HOME LEAD          2-5 MIN    >20
# 514                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 515                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 516                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 517                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 518                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 519                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 520                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 521                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 522                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 523                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 524                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 525                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 526                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 527                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 528                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 529                       DEN       3     HOME LEAD         6-12 MIN  11-20
# 530                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 531                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 532                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 533                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 534                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 535                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 536                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 537                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 538                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 539                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 540                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 541                       DEN       3     HOME LEAD         6-12 MIN   6-10
# 542                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 543                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 544                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 545                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 546                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 547                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 548                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 549                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 550                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 551                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 552                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 553                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 554                       DEN       3     HOME LEAD         6-12 MIN    <=5
# 555                       DEN       3     HOME LEAD         6-12 MIN    >20
# 556                       DEN       3     HOME LEAD         6-12 MIN    >20
# 557                       DEN       3     HOME LEAD         6-12 MIN    >20
# 558                       DEN       3     HOME LEAD         6-12 MIN    >20
# 559                       DEN       3     HOME LEAD         6-12 MIN    >20
# 560                       DEN       3     HOME LEAD         6-12 MIN    >20
# 561                       DEN       3     HOME LEAD         6-12 MIN    >20
# 562                       DEN       3     HOME LEAD         6-12 MIN    >20
# 563                       DEN       3     HOME LEAD         6-12 MIN    >20
# 564                       DEN       3     HOME LEAD         6-12 MIN    >20
# 565                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 566                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 567                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 568                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 569                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 570                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 571                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 572                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 573                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 574                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 575                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 576                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 577                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 578                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 579                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 580                       DEN       3     HOME LEAD  LESS THAN 2 MIN  11-20
# 581                       DEN       3     HOME LEAD  LESS THAN 2 MIN   6-10
# 582                       DEN       3     HOME LEAD  LESS THAN 2 MIN   6-10
# 583                       DEN       3     HOME LEAD  LESS THAN 2 MIN   6-10
# 584                       DEN       3     HOME LEAD  LESS THAN 2 MIN   6-10
# 585                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 586                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 587                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 588                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 589                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 590                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 591                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 592                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 593                       DEN       3     HOME LEAD  LESS THAN 2 MIN    <=5
# 594                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 595                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 596                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 597                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 598                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 599                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 600                       DEN       3     HOME LEAD  LESS THAN 2 MIN    >20
# 601                       DEN       4           ALL          2-5 MIN      0
# 602                       DEN       4           ALL          2-5 MIN      0
# 603                       DEN       4           ALL          2-5 MIN      0
# 604                       DEN       4           ALL         6-12 MIN      0
# 605                       DEN       4           ALL         6-12 MIN      0
# ...
# 753  2PT Field Goal            DeAndre Jordan      1        1.0        3.0
# 754  2PT Field Goal              Jamal Murray      3        1.0        3.0
# 755  2PT Field Goal        Michael Porter Jr.      2        1.0        3.0
# 756  2PT Field Goal              Nikola Jokic      1        1.0        3.0
# 757  2PT Field Goal             Peyton Watson      1        1.0        3.0
# 758  2PT Field Goal             Thomas Bryant      1        1.0        3.0
# 759  2PT Field Goal                Zeke Nnaji      1        1.0        3.0
# 760  3PT Field Goal               Bruce Brown      1        1.0        3.0
# 761  3PT Field Goal           Christian Braun      1        1.0        3.0
# 762  3PT Field Goal                Jeff Green      1        1.0        3.0
# 763  3PT Field Goal  Kentavious Caldwell-Pope      2        1.0        3.0
# 764  2PT Field Goal              Aaron Gordon      4        1.0        0.5
# 765  2PT Field Goal              Bones Hyland      2        1.0        0.5
# 766  2PT Field Goal               Bruce Brown      2        1.0        0.5
# 767  2PT Field Goal           Christian Braun      5        1.0        0.5
# 768  2PT Field Goal                Davon Reed      2        1.0        0.5
# 769  2PT Field Goal            DeAndre Jordan      5        1.0        0.5
# 770  2PT Field Goal                 Ish Smith      2        1.0        0.5
# 771  2PT Field Goal                Jeff Green      1        1.0        0.5
# 772  2PT Field Goal              Nikola Jokic      1        1.0        0.5
# 773  2PT Field Goal             Peyton Watson      1        1.0        0.5
# 774  2PT Field Goal             Vlatko Cancar      2        1.0        0.5
# 775  2PT Field Goal                Zeke Nnaji      5        1.0        0.5
# 776  3PT Field Goal              Bones Hyland      2        1.0        0.5
# 777  3PT Field Goal               Bruce Brown      1        1.0        0.5
# 778  3PT Field Goal                Davon Reed      3        1.0        0.5
# 779  3PT Field Goal                Jeff Green      2        1.0        0.5
# 780  3PT Field Goal        Michael Porter Jr.      2        1.0        0.5
# 781  3PT Field Goal             Vlatko Cancar      1        1.0        0.5
# 782  3PT Field Goal                Zeke Nnaji      1        1.0        0.5
# 783  2PT Field Goal              Aaron Gordon      1        3.0        1.0
# 784  2PT Field Goal               Bruce Brown      2        3.0        1.0
# 785  2PT Field Goal                Davon Reed      1        3.0        1.0
# 786  2PT Field Goal            DeAndre Jordan      1        3.0        1.0
# 787  2PT Field Goal                 Ish Smith      2        3.0        1.0
# 788  2PT Field Goal              Nikola Jokic      1        3.0        1.0
# 789  2PT Field Goal             Peyton Watson      1        3.0        1.0
# 790  2PT Field Goal                Zeke Nnaji      3        3.0        1.0
# 791  3PT Field Goal        Michael Porter Jr.      1        3.0        1.0
# 792  2PT Field Goal                Jeff Green      1        3.0        2.0
# 793  2PT Field Goal  Kentavious Caldwell-Pope      1        3.0        2.0
# 794  2PT Field Goal              Nikola Jokic      1        3.0        2.0
# 795  3PT Field Goal               Bruce Brown      1        3.0        2.0
# 796  2PT Field Goal              Aaron Gordon      1        3.0        3.0
# 797  2PT Field Goal               Bruce Brown      1        3.0        3.0
# 798  2PT Field Goal              Jamal Murray      2        3.0        3.0
# 799  2PT Field Goal              Nikola Jokic      1        3.0        3.0
# 800  3PT Field Goal               Bruce Brown      1        3.0        3.0
# 801  3PT Field Goal              Jamal Murray      1        3.0        3.0
# 802  3PT Field Goal        Michael Porter Jr.      1        3.0        3.0
# 803  3PT Field Goal              Nikola Jokic      1        3.0        3.0
# 804  2PT Field Goal                Davon Reed      1        3.0        0.5
# 805  2PT Field Goal                 Ish Smith      1        3.0        0.5
# 806  2PT Field Goal                Jack White      1        3.0        0.5
# 807  2PT Field Goal        Michael Porter Jr.      1        3.0        0.5
# 808  2PT Field Goal             Peyton Watson      3        3.0        0.5
# 809  3PT Field Goal                Jack White      1        3.0        0.5
# 810  3PT Field Goal             Peyton Watson      2        3.0        0.5
# 811  3PT Field Goal             Vlatko Cancar      1        3.0        0.5
# 812  2PT Field Goal  Kentavious Caldwell-Pope      1        2.0        3.0
# 813  2PT Field Goal              Nikola Jokic      2        2.0        2.0
# 814  3PT Field Goal        Michael Porter Jr.      1        2.0        2.0
# 815  2PT Field Goal              Aaron Gordon      1        2.0        3.0
# 816  3PT Field Goal              Jamal Murray      1        2.0        3.0
# 817  2PT Field Goal               Bruce Brown      1        3.0        2.0
# 818  2PT Field Goal              Nikola Jokic      1        3.0        2.0
# 819  3PT Field Goal  Kentavious Caldwell-Pope      1        3.0        2.0
# 820  2PT Field Goal              Aaron Gordon      1        3.0        3.0
#
#      FG_RK
# 0      2.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      2.0
# 5      2.0
# 6      2.0
# 7      2.0
# 8      2.0
# 9      2.0
# 10     2.0
# 11     3.0
# 12     3.0
# 13     3.0
# 14     3.0
# 15     3.0
# 16     2.0
# 17     2.0
# 18     2.0
# 19     2.0
# 20     3.0
# 21     2.0
# 22     2.0
# 23     2.0
# 24     2.0
# 25     2.0
# 26     2.0
# 27     2.0
# 28     2.0
# 29     2.0
# 30     2.0
# 31     3.0
# 32     3.0
# 33     3.0
# 34     3.0
# 35     2.0
# 36     2.0
# 37     2.0
# 38     2.0
# 39     2.0
# 40     2.0
# 41     2.0
# 42     2.0
# 43     2.0
# 44     2.0
# 45     2.0
# 46     2.0
# 47     2.0
# 48     2.0
# 49     2.0
# 50     2.0
# 51     3.0
# 52     3.0
# 53     3.0
# 54     3.0
# 55     2.0
# 56     2.0
# 57     2.0
# 58     2.0
# 59     2.0
# 60     2.0
# 61     2.0
# 62     2.0
# 63     3.0
# 64     3.0
# 65     2.0
# 66     2.0
# 67     2.0
# 68     2.0
# 69     2.0
# 70     2.0
# 71     2.0
# 72     2.0
# 73     3.0
# 74     3.0
# 75     3.0
# 76     3.0
# 77     3.0
# 78     3.0
# 79     2.0
# 80     2.0
# 81     2.0
# 82     2.0
# 83     2.0
# 84     2.0
# 85     2.0
# 86     2.0
# 87     2.0
# 88     3.0
# 89     3.0
# 90     3.0
# 91     3.0
# 92     3.0
# 93     3.0
# 94     3.0
# 95     2.0
# 96     2.0
# 97     2.0
# 98     2.0
# 99     2.0
# 100    2.0
# 101    2.0
# 102    2.0
# 103    2.0
# 104    2.0
# 105    2.0
# 106    3.0
# 107    3.0
# 108    3.0
# 109    3.0
# 110    3.0
# 111    2.0
# 112    2.0
# 113    2.0
# 114    2.0
# 115    2.0
# 116    2.0
# 117    3.0
# 118    2.0
# 119    2.0
# 120    2.0
# 121    2.0
# 122    2.0
# 123    2.0
# 124    3.0
# 125    3.0
# 126    3.0
# 127    3.0
# 128    3.0
# 129    3.0
# 130    2.0
# 131    2.0
# 132    2.0
# 133    2.0
# 134    2.0
# 135    2.0
# 136    2.0
# 137    2.0
# 138    2.0
# 139    2.0
# 140    3.0
# 141    3.0
# 142    3.0
# 143    3.0
# 144    3.0
# 145    3.0
# 146    2.0
# 147    2.0
# 148    2.0
# 149    2.0
# 150    2.0
# 151    3.0
# 152    3.0
# 153    3.0
# 154    3.0
# 155    2.0
# 156    2.0
# 157    2.0
# 158    2.0
# 159    2.0
# 160    2.0
# 161    2.0
# 162    3.0
# 163    3.0
# 164    3.0
# 165    3.0
# 166    3.0
# 167    2.0
# 168    2.0
# 169    2.0
# 170    2.0
# 171    2.0
# 172    2.0
# 173    2.0
# 174    2.0
# 175    2.0
# 176    3.0
# 177    3.0
# 178    3.0
# 179    2.0
# 180    2.0
# 181    3.0
# 182    3.0
# 183    3.0
# 184    3.0
# 185    3.0
# 186    2.0
# 187    2.0
# 188    2.0
# 189    2.0
# 190    3.0
# 191    3.0
# 192    3.0
# 193    2.0
# 194    3.0
# 195    3.0
# 196    2.0
# 197    2.0
# 198    2.0
# 199    2.0
# 200    2.0
# 201    2.0
# 202    2.0
# 203    2.0
# 204    3.0
# 205    3.0
# 206    3.0
# 207    3.0
# 208    3.0
# 209    2.0
# 210    2.0
# 211    2.0
# 212    2.0
# 213    2.0
# 214    2.0
# 215    2.0
# 216    3.0
# 217    3.0
# 218    3.0
# 219    2.0
# 220    2.0
# 221    2.0
# 222    2.0
# 223    2.0
# 224    3.0
# 225    2.0
# 226    2.0
# 227    2.0
# 228    2.0
# 229    2.0
# 230    2.0
# 231    2.0
# 232    2.0
# 233    2.0
# 234    2.0
# 235    3.0
# 236    3.0
# 237    3.0
# 238    3.0
# 239    3.0
# 240    2.0
# 241    2.0
# 242    2.0
# 243    2.0
# 244    2.0
# 245    2.0
# 246    2.0
# 247    2.0
# 248    2.0
# 249    2.0
# 250    3.0
# 251    3.0
# 252    3.0
# 253    3.0
# 254    2.0
# 255    2.0
# 256    2.0
# 257    2.0
# 258    3.0
# 259    2.0
# 260    2.0
# 261    2.0
# 262    2.0
# 263    2.0
# 264    2.0
# 265    2.0
# 266    2.0
# 267    3.0
# 268    3.0
# 269    3.0
# 270    3.0
# 271    3.0
# 272    3.0
# 273    2.0
# 274    2.0
# 275    2.0
# 276    2.0
# 277    2.0
# 278    2.0
# 279    2.0
# 280    2.0
# 281    3.0
# 282    3.0
# 283    3.0
# 284    2.0
# 285    2.0
# 286    2.0
# 287    2.0
# 288    3.0
# 289    3.0
# 290    2.0
# 291    2.0
# 292    2.0
# 293    2.0
# 294    2.0
# 295    2.0
# 296    2.0
# 297    2.0
# 298    3.0
# 299    3.0
# 300    3.0
# 301    2.0
# 302    2.0
# 303    2.0
# 304    2.0
# 305    3.0
# 306    3.0
# 307    2.0
# 308    2.0
# 309    2.0
# 310    2.0
# 311    2.0
# 312    2.0
# 313    2.0
# 314    2.0
# 315    2.0
# 316    2.0
# 317    2.0
# 318    2.0
# 319    3.0
# 320    3.0
# 321    3.0
# 322    3.0
# 323    3.0
# 324    3.0
# 325    2.0
# 326    2.0
# 327    2.0
# 328    2.0
# 329    2.0
# 330    2.0
# 331    2.0
# 332    2.0
# 333    2.0
# 334    2.0
# 335    2.0
# 336    3.0
# 337    3.0
# 338    3.0
# 339    3.0
# 340    3.0
# 341    3.0
# 342    3.0
# 343    3.0
# 344    2.0
# 345    2.0
# 346    2.0
# 347    2.0
# 348    2.0
# 349    2.0
# 350    2.0
# 351    2.0
# 352    2.0
# 353    2.0
# 354    2.0
# 355    2.0
# 356    3.0
# 357    3.0
# 358    3.0
# 359    3.0
# 360    3.0
# 361    3.0
# 362    3.0
# 363    3.0
# 364    3.0
# 365    2.0
# 366    2.0
# 367    2.0
# 368    2.0
# 369    2.0
# 370    2.0
# 371    2.0
# 372    2.0
# 373    2.0
# 374    3.0
# 375    3.0
# 376    3.0
# 377    3.0
# 378    3.0
# 379    2.0
# 380    2.0
# 381    2.0
# 382    2.0
# 383    2.0
# 384    2.0
# 385    3.0
# 386    3.0
# 387    3.0
# 388    2.0
# 389    2.0
# 390    2.0
# 391    2.0
# 392    2.0
# 393    3.0
# 394    3.0
# 395    3.0
# 396    2.0
# 397    2.0
# 398    2.0
# 399    2.0
# 400    2.0
# 401    2.0
# 402    2.0
# 403    3.0
# 404    2.0
# 405    2.0
# 406    2.0
# 407    2.0
# 408    3.0
# 409    2.0
# 410    2.0
# 411    2.0
# 412    2.0
# 413    2.0
# 414    3.0
# 415    3.0
# 416    3.0
# 417    3.0
# 418    2.0
# 419    2.0
# 420    2.0
# 421    2.0
# 422    2.0
# 423    2.0
# 424    2.0
# 425    2.0
# 426    3.0
# 427    3.0
# 428    3.0
# 429    2.0
# 430    2.0
# 431    2.0
# 432    2.0
# 433    2.0
# 434    2.0
# 435    3.0
# 436    3.0
# 437    2.0
# 438    3.0
# 439    2.0
# 440    2.0
# 441    2.0
# 442    2.0
# 443    3.0
# 444    2.0
# 445    2.0
# 446    2.0
# 447    2.0
# 448    2.0
# 449    2.0
# 450    2.0
# 451    2.0
# 452    2.0
# 453    3.0
# 454    3.0
# 455    3.0
# 456    3.0
# 457    3.0
# 458    3.0
# 459    2.0
# 460    2.0
# 461    2.0
# 462    2.0
# 463    2.0
# 464    2.0
# 465    2.0
# 466    2.0
# 467    3.0
# 468    3.0
# 469    3.0
# 470    3.0
# 471    2.0
# 472    2.0
# 473    2.0
# 474    2.0
# 475    2.0
# 476    2.0
# 477    2.0
# 478    2.0
# 479    3.0
# 480    3.0
# 481    3.0
# 482    3.0
# 483    3.0
# 484    3.0
# 485    3.0
# 486    3.0
# 487    2.0
# 488    2.0
# 489    2.0
# 490    2.0
# 491    2.0
# 492    2.0
# 493    2.0
# 494    3.0
# 495    3.0
# 496    3.0
# 497    3.0
# 498    2.0
# 499    2.0
# 500    2.0
# 501    2.0
# 502    2.0
# 503    3.0
# 504    3.0
# 505    3.0
# 506    2.0
# 507    2.0
# 508    2.0
# 509    2.0
# 510    2.0
# 511    2.0
# 512    3.0
# 513    3.0
# 514    2.0
# 515    2.0
# 516    2.0
# 517    2.0
# 518    2.0
# 519    2.0
# 520    2.0
# 521    2.0
# 522    3.0
# 523    3.0
# 524    3.0
# 525    3.0
# 526    3.0
# 527    3.0
# 528    3.0
# 529    3.0
# 530    2.0
# 531    2.0
# 532    2.0
# 533    2.0
# 534    2.0
# 535    2.0
# 536    3.0
# 537    3.0
# 538    3.0
# 539    3.0
# 540    3.0
# 541    3.0
# 542    2.0
# 543    2.0
# 544    2.0
# 545    2.0
# 546    2.0
# 547    2.0
# 548    3.0
# 549    3.0
# 550    3.0
# 551    3.0
# 552    3.0
# 553    3.0
# 554    3.0
# 555    2.0
# 556    2.0
# 557    2.0
# 558    2.0
# 559    2.0
# 560    3.0
# 561    3.0
# 562    3.0
# 563    3.0
# 564    3.0
# 565    2.0
# 566    2.0
# 567    2.0
# 568    2.0
# 569    2.0
# 570    2.0
# 571    2.0
# 572    2.0
# 573    2.0
# 574    2.0
# 575    3.0
# 576    3.0
# 577    3.0
# 578    3.0
# 579    3.0
# 580    3.0
# 581    2.0
# 582    2.0
# 583    3.0
# 584    3.0
# 585    2.0
# 586    2.0
# 587    2.0
# 588    2.0
# 589    2.0
# 590    2.0
# 591    2.0
# 592    3.0
# 593    3.0
# 594    2.0
# 595    2.0
# 596    2.0
# 597    2.0
# 598    2.0
# 599    2.0
# 600    3.0
# 601    2.0
# 602    2.0
# 603    3.0
# 604    2.0
# 605    3.0
# 606    3.0
# 607    2.0
# 608    2.0
# 609    2.0
# 610    2.0
# 611    3.0
# 612    2.0
# 613    2.0
# 614    2.0
# 615    3.0
# 616    2.0
# 617    2.0
# 618    2.0
# 619    3.0
# 620    3.0
# 621    3.0
# 622    3.0
# 623    2.0
# 624    2.0
# 625    2.0
# 626    2.0
# 627    2.0
# 628    2.0
# 629    3.0
# 630    3.0
# 631    2.0
# 632    2.0
# 633    2.0
# 634    2.0
# 635    2.0
# 636    2.0
# 637    2.0
# 638    3.0
# 639    3.0
# 640    2.0
# 641    2.0
# 642    2.0
# 643    2.0
# 644    2.0
# 645    2.0
# 646    2.0
# 647    2.0
# 648    2.0
# 649    2.0
# 650    3.0
# 651    3.0
# 652    3.0
# 653    3.0
# 654    3.0
# 655    3.0
# 656    3.0
# 657    3.0
# 658    2.0
# 659    2.0
# 660    2.0
# 661    2.0
# 662    2.0
# 663    2.0
# 664    3.0
# 665    3.0
# 666    3.0
# 667    2.0
# 668    2.0
# 669    2.0
# 670    2.0
# 671    2.0
# 672    2.0
# 673    2.0
# 674    2.0
# 675    2.0
# 676    2.0
# 677    2.0
# 678    3.0
# 679    3.0
# 680    3.0
# 681    3.0
# 682    3.0
# 683    3.0
# 684    2.0
# 685    2.0
# 686    3.0
# 687    3.0
# 688    3.0
# 689    2.0
# 690    2.0
# 691    3.0
# 692    3.0
# 693    2.0
# 694    2.0
# 695    2.0
# 696    2.0
# 697    2.0
# 698    2.0
# 699    2.0
# 700    2.0
# 701    2.0
# 702    3.0
# 703    3.0
# 704    3.0
# 705    3.0
# 706    3.0
# 707    3.0
# 708    2.0
# 709    2.0
# 710    2.0
# 711    2.0
# 712    2.0
# 713    2.0
# 714    2.0
# 715    2.0
# 716    2.0
# 717    2.0
# 718    2.0
# 719    2.0
# 720    2.0
# 721    2.0
# 722    2.0
# 723    3.0
# 724    3.0
# 725    3.0
# 726    3.0
# 727    3.0
# 728    3.0
# 729    3.0
# 730    3.0
# 731    3.0
# 732    3.0
# 733    3.0
# 734    2.0
# 735    2.0
# 736    2.0
# 737    2.0
# 738    2.0
# 739    2.0
# 740    2.0
# 741    2.0
# 742    2.0
# 743    2.0
# 744    2.0
# 745    3.0
# 746    3.0
# 747    3.0
# 748    3.0
# 749    3.0
# 750    2.0
# 751    2.0
# 752    2.0
# 753    2.0
# 754    2.0
# 755    2.0
# 756    2.0
# 757    2.0
# 758    2.0
# 759    2.0
# 760    3.0
# 761    3.0
# 762    3.0
# 763    3.0
# 764    2.0
# 765    2.0
# 766    2.0
# 767    2.0
# 768    2.0
# 769    2.0
# 770    2.0
# 771    2.0
# 772    2.0
# 773    2.0
# 774    2.0
# 775    2.0
# 776    3.0
# 777    3.0
# 778    3.0
# 779    3.0
# 780    3.0
# 781    3.0
# 782    3.0
# 783    2.0
# 784    2.0
# 785    2.0
# 786    2.0
# 787    2.0
# 788    2.0
# 789    2.0
# 790    2.0
# 791    3.0
# 792    2.0
# 793    2.0
# 794    2.0
# 795    3.0
# 796    2.0
# 797    2.0
# 798    2.0
# 799    2.0
# 800    3.0
# 801    3.0
# 802    3.0
# 803    3.0
# 804    2.0
# 805    2.0
# 806    2.0
# 807    2.0
# 808    2.0
# 809    3.0
# 810    3.0
# 811    3.0
# 812    2.0
# 813    2.0
# 814    3.0
# 815    2.0
# 816    3.0
# 817    2.0
# 818    2.0
# 819    3.0
# 820    2.0

# %%
#Rebounds grouped by Period
SHOTS_PERCENT=BLOCK_ALL_GAMES[((BLOCK_ALL_GAMES.PLAYER1_NAME!="No") & (BLOCK_ALL_GAMES.Event=="Made FG") & (BLOCK_ALL_GAMES.PLAYER1_TEAM_ABBREVIATION==TEAM))]
SHOTS_PERCENT=SHOTS_PERCENT.groupby(by=["PLAYER1_TEAM_ABBREVIATION","PERIOD","PLAYER1_NAME"])["Event"].count()
SHOTS_PERCENT=pd.DataFrame(SHOTS_PERCENT)
SHOTS_PERCENT.reset_index(inplace=True)
SHOTS_PERCENT['CATEGORY_PERCENT']=SHOTS_PERCENT['Event'] / SHOTS_PERCENT.groupby(['PLAYER1_NAME'])['Event'].transform('sum')*100
SHOTS_PERCENT=SHOTS_PERCENT.round({'CATEGORY_PERCENT': 1})
SHOTS_PERCENT["WEIGHTED"]=SHOTS_PERCENT["Event"]*2*(SHOTS_PERCENT["CATEGORY_PERCENT"]/100)*SHOTS_PERCENT["PERIOD"]
SHOTS_PERCENT["TOTALS"]=SHOTS_PERCENT.groupby(['PLAYER1_NAME'])['WEIGHTED'].transform('sum')
SHOTS_PERCENT["TOTALS1"]=SHOTS_PERCENT["TOTALS"]*SHOTS_PERCENT["PERIOD"]

SHOTS_PERCENT["EVENT_TOTALS"]=SHOTS_PERCENT.groupby(['PLAYER1_NAME'])['TOTALS1'].transform('sum')
# SHOTS_PERCENT["WEIGHTED"].groupby(by=["PLAYER1_NAME"]).sum() / SHOTS_PERCENT["Event"].groupby(by=["PLAYER1_NAME"]).sum()
# SHOTS_PERCENT=SHOTS_PERCENT.groupby(by=["PLAYER1_NAME"])(["WEIGHTED"]/["Event"])
SHOTS_PERCENT
# Out:
#    PLAYER1_TEAM_ABBREVIATION  PERIOD              PLAYER1_NAME  Event  \
# 0                        DEN       1              Aaron Gordon     72
# 1                        DEN       1              Bones Hyland     16
# 2                        DEN       1               Bruce Brown     53
# 3                        DEN       1           Christian Braun     13
# 4                        DEN       1                Davon Reed      2
# 5                        DEN       1            DeAndre Jordan      6
# 6                        DEN       1                 Ish Smith      4
# 7                        DEN       1              Jamal Murray     77
# 8                        DEN       1                Jeff Green     25
# 9                        DEN       1  Kentavious Caldwell-Pope     53
# 10                       DEN       1        Michael Porter Jr.     62
# 11                       DEN       1              Nikola Jokic     99
# 12                       DEN       1             Peyton Watson      3
# 13                       DEN       1            Reggie Jackson      1
# 14                       DEN       1             Thomas Bryant      3
# 15                       DEN       1             Vlatko Cancar     13
# 16                       DEN       1                Zeke Nnaji      7
# 17                       DEN       2              Aaron Gordon     51
# 18                       DEN       2              Bones Hyland     34
# 19                       DEN       2               Bruce Brown     53
# 20                       DEN       2           Christian Braun     11
# 21                       DEN       2            DeAndre Jordan     13
# 22                       DEN       2                 Ish Smith      4
# 23                       DEN       2              Jamal Murray     68
# 24                       DEN       2                Jeff Green     16
# 25                       DEN       2  Kentavious Caldwell-Pope     41
# 26                       DEN       2        Michael Porter Jr.     49
# 27                       DEN       2              Nikola Jokic     74
# 28                       DEN       2             Peyton Watson      1
# 29                       DEN       2            Reggie Jackson      7
# 30                       DEN       2             Thomas Bryant      2
# 31                       DEN       2             Vlatko Cancar     14
# 32                       DEN       2                Zeke Nnaji     23
# 33                       DEN       3              Aaron Gordon     49
# 34                       DEN       3              Bones Hyland     16
# 35                       DEN       3               Bruce Brown     43
# 36                       DEN       3           Christian Braun     22
# 37                       DEN       3                Davon Reed      1
# 38                       DEN       3            DeAndre Jordan      5
# 39                       DEN       3                 Ish Smith      2
# 40                       DEN       3              Jamal Murray     76
# 41                       DEN       3                Jeff Green     14
# 42                       DEN       3  Kentavious Caldwell-Pope     37
# 43                       DEN       3        Michael Porter Jr.     67
# 44                       DEN       3              Nikola Jokic     95
# 45                       DEN       3             Peyton Watson      1
# 46                       DEN       3            Reggie Jackson      3
# 47                       DEN       3             Thomas Bryant      2
# 48                       DEN       3             Vlatko Cancar     12
# 49                       DEN       3                Zeke Nnaji      8
# 50                       DEN       4              Aaron Gordon     37
# 51                       DEN       4              Bones Hyland     30
# 52                       DEN       4               Bruce Brown     44
# 53                       DEN       4           Christian Braun     25
# 54                       DEN       4                Davon Reed      9
# 55                       DEN       4            DeAndre Jordan     11
# 56                       DEN       4                 Ish Smith     10
# 57                       DEN       4                Jack White      5
# 58                       DEN       4              Jamal Murray     44
# 59                       DEN       4                Jeff Green     22
# 60                       DEN       4  Kentavious Caldwell-Pope     21
# 61                       DEN       4        Michael Porter Jr.     21
# 62                       DEN       4              Nikola Jokic     58
# 63                       DEN       4             Peyton Watson     11
# 64                       DEN       4            Reggie Jackson      7
# 65                       DEN       4             Thomas Bryant     11
# 66                       DEN       4             Vlatko Cancar     10
# 67                       DEN       4                Zeke Nnaji     29
# 68                       DEN       5              Aaron Gordon      2
# 69                       DEN       5               Bruce Brown      1
# 70                       DEN       5              Jamal Murray      1
# 71                       DEN       5  Kentavious Caldwell-Pope      2
# 72                       DEN       5        Michael Porter Jr.      1
# 73                       DEN       5              Nikola Jokic      3
#
#     CATEGORY_PERCENT  WEIGHTED   TOTALS   TOTALS1  EVENT_TOTALS
# 0               34.1    49.104   218.66    218.66        3279.9
# 1               16.7     5.344    144.4     144.4        1444.0
# 2               27.3    28.938  224.044   224.044       3360.66
# 3               18.3     4.758  122.898   122.898       1228.98
# 4               16.7     0.668   55.166    55.166       441.328
# 5               17.1     2.052   53.266    53.266        532.66
# 6               20.0       1.6     46.0      46.0         460.0
# 7               28.9    44.506  302.674   302.674       4540.11
# 8               32.5     16.25   95.186    95.186        951.86
# 9               34.4    36.464  156.476   156.476       2347.14
# 10              31.0     38.44   238.82    238.82        3582.3
# 11              30.1    59.598  372.862   372.862       5592.93
# 12              18.8     1.128   62.292    62.292        622.92
# 13               5.6     0.112   35.794    35.794        357.94
# 14              16.7     1.002    56.99     56.99         569.9
# 15              26.5      6.89   56.866    56.866        568.66
# 16              10.4     1.456   139.18    139.18        1391.8
# 17              24.2    49.368   218.66    437.32        3279.9
# 18              35.4    48.144    144.4     288.8        1444.0
# 19              27.3    57.876  224.044   448.088       3360.66
# 20              15.5      6.82  122.898   245.796       1228.98
# 21              37.1    19.292   53.266   106.532        532.66
# 22              20.0       3.2     46.0      92.0         460.0
# 23              25.6    69.632  302.674   605.348       4540.11
# 24              20.8    13.312   95.186   190.372        951.86
# 25              26.6    43.624  156.476   312.952       2347.14
# 26              24.5     48.02   238.82    477.64        3582.3
# 27              22.5      66.6  372.862   745.724       5592.93
# 28               6.2     0.248   62.292   124.584        622.92
# 29              38.9    10.892   35.794    71.588        357.94
# 30              11.1     0.888    56.99    113.98         569.9
# 31              28.6    16.016   56.866   113.732        568.66
# 32              34.3    31.556   139.18    278.36        1391.8
# 33              23.2    68.208   218.66    655.98        3279.9
# 34              16.7    16.032    144.4     433.2        1444.0
# 35              22.2    57.276  224.044   672.132       3360.66
# 36              31.0     40.92  122.898   368.694       1228.98
# 37               8.3     0.498   55.166   165.498       441.328
# 38              14.3      4.29   53.266   159.798        532.66
# 39              10.0       1.2     46.0     138.0         460.0
# 40              28.6   130.416  302.674   908.022       4540.11
# 41              18.2    15.288   95.186   285.558        951.86
# 42              24.0     53.28  156.476   469.428       2347.14
# 43              33.5    134.67   238.82    716.46        3582.3
# 44              28.9    164.73  372.862  1118.586       5592.93
# 45               6.2     0.372   62.292   186.876        622.92
# 46              16.7     3.006   35.794   107.382        357.94
# 47              11.1     1.332    56.99    170.97         569.9
# 48              24.5     17.64   56.866   170.598        568.66
# 49              11.9     5.712   139.18    417.54        1391.8
# 50              17.5      51.8   218.66    874.64        3279.9
# 51              31.2     74.88    144.4     577.6        1444.0
# 52              22.7    79.904  224.044   896.176       3360.66
# 53              35.2      70.4  122.898   491.592       1228.98
# 54              75.0      54.0   55.166   220.664       441.328
# 55              31.4    27.632   53.266   213.064        532.66
# 56              50.0      40.0     46.0     184.0         460.0
# 57             100.0      40.0     40.0     160.0         160.0
# 58              16.5     58.08  302.674  1210.696       4540.11
# 59              28.6    50.336   95.186   380.744        951.86
# 60              13.6    22.848  156.476   625.904       2347.14
# 61              10.5     17.64   238.82    955.28        3582.3
# 62              17.6    81.664  372.862  1491.448       5592.93
# 63              68.8    60.544   62.292   249.168        622.92
# 64              38.9    21.784   35.794   143.176        357.94
# 65              61.1    53.768    56.99    227.96         569.9
# 66              20.4     16.32   56.866   227.464        568.66
# 67              43.3   100.456   139.18    556.72        1391.8
# 68               0.9      0.18   218.66    1093.3        3279.9
# 69               0.5      0.05  224.044   1120.22       3360.66
# 70               0.4      0.04  302.674   1513.37       4540.11
# 71               1.3      0.26  156.476    782.38       2347.14
# 72               0.5      0.05   238.82    1194.1        3582.3
# 73               0.9      0.27  372.862   1864.31       5592.93

# %%
#Rebounds grouped by Period
SHOTS_PERCENT=BLOCK_ALL_GAMES[((BLOCK_ALL_GAMES.PLAYER1_NAME!="No") & (BLOCK_ALL_GAMES.Event=="Made FG") & (BLOCK_ALL_GAMES.PLAYER1_TEAM_ABBREVIATION==TEAM))]
SHOTS_PERCENT=SHOTS_PERCENT.groupby(by=["PLAYER1_TEAM_ABBREVIATION","PERIOD","PLAYER1_NAME"])["Event"].count()
SHOTS_PERCENT=pd.DataFrame(SHOTS_PERCENT)
SHOTS_PERCENT.reset_index(inplace=True)
SHOTS_PERCENT['CATEGORY_PERCENT']=SHOTS_PERCENT['Event'] / SHOTS_PERCENT.groupby(['PLAYER1_NAME'])['Event'].transform('sum')*100
SHOTS_PERCENT=SHOTS_PERCENT.round({'CATEGORY_PERCENT': 1})
# SHOTS_PERCENT["WEIGHTED"].groupby(by=["PLAYER1_NAME"]).sum() / SHOTS_PERCENT["Event"].groupby(by=["PLAYER1_NAME"]).sum()
# SHOTS_PERCENT=SHOTS_PERCENT.groupby(by=["PLAYER1_NAME"])(["WEIGHTED"]/["Event"])
SHOTS_PERCENT
# Out:
#    PLAYER1_TEAM_ABBREVIATION  PERIOD              PLAYER1_NAME  Event  \
# 0                        DEN       1              Aaron Gordon     72
# 1                        DEN       1              Bones Hyland     16
# 2                        DEN       1               Bruce Brown     53
# 3                        DEN       1           Christian Braun     13
# 4                        DEN       1                Davon Reed      2
# 5                        DEN       1            DeAndre Jordan      6
# 6                        DEN       1                 Ish Smith      4
# 7                        DEN       1              Jamal Murray     77
# 8                        DEN       1                Jeff Green     25
# 9                        DEN       1  Kentavious Caldwell-Pope     53
# 10                       DEN       1        Michael Porter Jr.     62
# 11                       DEN       1              Nikola Jokic     99
# 12                       DEN       1             Peyton Watson      3
# 13                       DEN       1            Reggie Jackson      1
# 14                       DEN       1             Thomas Bryant      3
# 15                       DEN       1             Vlatko Cancar     13
# 16                       DEN       1                Zeke Nnaji      7
# 17                       DEN       2              Aaron Gordon     51
# 18                       DEN       2              Bones Hyland     34
# 19                       DEN       2               Bruce Brown     53
# 20                       DEN       2           Christian Braun     11
# 21                       DEN       2            DeAndre Jordan     13
# 22                       DEN       2                 Ish Smith      4
# 23                       DEN       2              Jamal Murray     68
# 24                       DEN       2                Jeff Green     16
# 25                       DEN       2  Kentavious Caldwell-Pope     41
# 26                       DEN       2        Michael Porter Jr.     49
# 27                       DEN       2              Nikola Jokic     74
# 28                       DEN       2             Peyton Watson      1
# 29                       DEN       2            Reggie Jackson      7
# 30                       DEN       2             Thomas Bryant      2
# 31                       DEN       2             Vlatko Cancar     14
# 32                       DEN       2                Zeke Nnaji     23
# 33                       DEN       3              Aaron Gordon     49
# 34                       DEN       3              Bones Hyland     16
# 35                       DEN       3               Bruce Brown     43
# 36                       DEN       3           Christian Braun     22
# 37                       DEN       3                Davon Reed      1
# 38                       DEN       3            DeAndre Jordan      5
# 39                       DEN       3                 Ish Smith      2
# 40                       DEN       3              Jamal Murray     76
# 41                       DEN       3                Jeff Green     14
# 42                       DEN       3  Kentavious Caldwell-Pope     37
# 43                       DEN       3        Michael Porter Jr.     67
# 44                       DEN       3              Nikola Jokic     95
# 45                       DEN       3             Peyton Watson      1
# 46                       DEN       3            Reggie Jackson      3
# 47                       DEN       3             Thomas Bryant      2
# 48                       DEN       3             Vlatko Cancar     12
# 49                       DEN       3                Zeke Nnaji      8
# 50                       DEN       4              Aaron Gordon     37
# 51                       DEN       4              Bones Hyland     30
# 52                       DEN       4               Bruce Brown     44
# 53                       DEN       4           Christian Braun     25
# 54                       DEN       4                Davon Reed      9
# 55                       DEN       4            DeAndre Jordan     11
# 56                       DEN       4                 Ish Smith     10
# 57                       DEN       4                Jack White      5
# 58                       DEN       4              Jamal Murray     44
# 59                       DEN       4                Jeff Green     22
# 60                       DEN       4  Kentavious Caldwell-Pope     21
# 61                       DEN       4        Michael Porter Jr.     21
# 62                       DEN       4              Nikola Jokic     58
# 63                       DEN       4             Peyton Watson     11
# 64                       DEN       4            Reggie Jackson      7
# 65                       DEN       4             Thomas Bryant     11
# 66                       DEN       4             Vlatko Cancar     10
# 67                       DEN       4                Zeke Nnaji     29
# 68                       DEN       5              Aaron Gordon      2
# 69                       DEN       5               Bruce Brown      1
# 70                       DEN       5              Jamal Murray      1
# 71                       DEN       5  Kentavious Caldwell-Pope      2
# 72                       DEN       5        Michael Porter Jr.      1
# 73                       DEN       5              Nikola Jokic      3
#
#     CATEGORY_PERCENT
# 0               34.1
# 1               16.7
# 2               27.3
# 3               18.3
# 4               16.7
# 5               17.1
# 6               20.0
# 7               28.9
# 8               32.5
# 9               34.4
# 10              31.0
# 11              30.1
# 12              18.8
# 13               5.6
# 14              16.7
# 15              26.5
# 16              10.4
# 17              24.2
# 18              35.4
# 19              27.3
# 20              15.5
# 21              37.1
# 22              20.0
# 23              25.6
# 24              20.8
# 25              26.6
# 26              24.5
# 27              22.5
# 28               6.2
# 29              38.9
# 30              11.1
# 31              28.6
# 32              34.3
# 33              23.2
# 34              16.7
# 35              22.2
# 36              31.0
# 37               8.3
# 38              14.3
# 39              10.0
# 40              28.6
# 41              18.2
# 42              24.0
# 43              33.5
# 44              28.9
# 45               6.2
# 46              16.7
# 47              11.1
# 48              24.5
# 49              11.9
# 50              17.5
# 51              31.2
# 52              22.7
# 53              35.2
# 54              75.0
# 55              31.4
# 56              50.0
# 57             100.0
# 58              16.5
# 59              28.6
# 60              13.6
# 61              10.5
# 62              17.6
# 63              68.8
# 64              38.9
# 65              61.1
# 66              20.4
# 67              43.3
# 68               0.9
# 69               0.5
# 70               0.4
# 71               1.3
# 72               0.5
# 73               0.9

# %%
#Rebounds grouped by Period
SHOTS_PERCENT2=BLOCK_ALL_GAMES[((BLOCK_ALL_GAMES.PLAYER1_NAME!="No") & (BLOCK_ALL_GAMES.Event=="Made FG") & (BLOCK_ALL_GAMES.PLAYER1_TEAM_ABBREVIATION==TEAM))]
SHOTS_PERCENT2=SHOTS_PERCENT2.groupby(by=["PLAYER1_TEAM_ABBREVIATION","MARGIN","PLAYER1_NAME"])["Event"].count()
SHOTS_PERCENT2=pd.DataFrame(SHOTS_PERCENT2)
SHOTS_PERCENT2.reset_index(inplace=True)
SHOTS_PERCENT2['CATEGORY_PERCENT']=SHOTS_PERCENT2['Event'] / SHOTS_PERCENT2.groupby(['PLAYER1_NAME'])['Event'].transform('sum')*100
SHOTS_PERCENT2=SHOTS_PERCENT2.round({'CATEGORY_PERCENT': 1})
# SHOTS_PERCENT["WEIGHTED"].groupby(by=["PLAYER1_NAME"]).sum() / SHOTS_PERCENT["Event"].groupby(by=["PLAYER1_NAME"]).sum()
# SHOTS_PERCENT=SHOTS_PERCENT.groupby(by=["PLAYER1_NAME"])(["WEIGHTED"]/["Event"])
SHOTS_PERCENT2
# Out:
#    PLAYER1_TEAM_ABBREVIATION MARGIN              PLAYER1_NAME  Event  \
# 0                        DEN      0              Aaron Gordon     15
# 1                        DEN      0              Bones Hyland      2
# 2                        DEN      0               Bruce Brown      9
# 3                        DEN      0           Christian Braun      1
# 4                        DEN      0            DeAndre Jordan      2
# 5                        DEN      0                 Ish Smith      1
# 6                        DEN      0              Jamal Murray     14
# 7                        DEN      0                Jeff Green      1
# 8                        DEN      0  Kentavious Caldwell-Pope     11
# 9                        DEN      0        Michael Porter Jr.     12
# 10                       DEN      0              Nikola Jokic     17
# 11                       DEN      0                Zeke Nnaji      2
# 12                       DEN  11-20              Aaron Gordon     39
# 13                       DEN  11-20              Bones Hyland     33
# 14                       DEN  11-20               Bruce Brown     53
# 15                       DEN  11-20           Christian Braun     31
# 16                       DEN  11-20                Davon Reed      1
# 17                       DEN  11-20            DeAndre Jordan     10
# 18                       DEN  11-20                 Ish Smith      7
# 19                       DEN  11-20              Jamal Murray     48
# 20                       DEN  11-20                Jeff Green     23
# 21                       DEN  11-20  Kentavious Caldwell-Pope     32
# 22                       DEN  11-20        Michael Porter Jr.     48
# 23                       DEN  11-20              Nikola Jokic     65
# 24                       DEN  11-20             Peyton Watson      4
# 25                       DEN  11-20            Reggie Jackson      5
# 26                       DEN  11-20             Thomas Bryant     10
# 27                       DEN  11-20             Vlatko Cancar     13
# 28                       DEN  11-20                Zeke Nnaji     23
# 29                       DEN   6-10              Aaron Gordon     58
# 30                       DEN   6-10              Bones Hyland     15
# 31                       DEN   6-10               Bruce Brown     55
# 32                       DEN   6-10           Christian Braun     14
# 33                       DEN   6-10            DeAndre Jordan      7
# 34                       DEN   6-10                Jack White      1
# 35                       DEN   6-10              Jamal Murray     70
# 36                       DEN   6-10                Jeff Green     21
# 37                       DEN   6-10  Kentavious Caldwell-Pope     37
# 38                       DEN   6-10        Michael Porter Jr.     40
# 39                       DEN   6-10              Nikola Jokic     87
# 40                       DEN   6-10             Peyton Watson      3
# 41                       DEN   6-10            Reggie Jackson      7
# 42                       DEN   6-10             Thomas Bryant      3
# 43                       DEN   6-10             Vlatko Cancar      5
# 44                       DEN   6-10                Zeke Nnaji     16
# 45                       DEN    <=5              Aaron Gordon     84
# 46                       DEN    <=5              Bones Hyland     32
# 47                       DEN    <=5               Bruce Brown     64
# 48                       DEN    <=5           Christian Braun     17
# 49                       DEN    <=5                Davon Reed      3
# 50                       DEN    <=5            DeAndre Jordan      9
# 51                       DEN    <=5                 Ish Smith      4
# 52                       DEN    <=5              Jamal Murray    121
# 53                       DEN    <=5                Jeff Green     25
# 54                       DEN    <=5  Kentavious Caldwell-Pope     68
# 55                       DEN    <=5        Michael Porter Jr.     82
# 56                       DEN    <=5              Nikola Jokic    136
# 57                       DEN    <=5             Peyton Watson      2
# 58                       DEN    <=5            Reggie Jackson      6
# 59                       DEN    <=5             Thomas Bryant      3
# 60                       DEN    <=5             Vlatko Cancar     17
# 61                       DEN    <=5                Zeke Nnaji     18
# 62                       DEN    >20              Aaron Gordon     15
# 63                       DEN    >20              Bones Hyland     14
# 64                       DEN    >20               Bruce Brown     13
# 65                       DEN    >20           Christian Braun      8
# 66                       DEN    >20                Davon Reed      8
# 67                       DEN    >20            DeAndre Jordan      7
# 68                       DEN    >20                 Ish Smith      8
# 69                       DEN    >20                Jack White      4
# 70                       DEN    >20              Jamal Murray     13
# 71                       DEN    >20                Jeff Green      7
# 72                       DEN    >20  Kentavious Caldwell-Pope      6
# 73                       DEN    >20        Michael Porter Jr.     18
# 74                       DEN    >20              Nikola Jokic     24
# 75                       DEN    >20             Peyton Watson      7
# 76                       DEN    >20             Thomas Bryant      2
# 77                       DEN    >20             Vlatko Cancar     14
# 78                       DEN    >20                Zeke Nnaji      8
#
#     CATEGORY_PERCENT
# 0                7.1
# 1                2.1
# 2                4.6
# 3                1.4
# 4                5.7
# 5                5.0
# 6                5.3
# 7                1.3
# 8                7.1
# 9                6.0
# 10               5.2
# 11               3.0
# 12              18.5
# 13              34.4
# 14              27.3
# 15              43.7
# 16               8.3
# 17              28.6
# 18              35.0
# 19              18.0
# 20              29.9
# 21              20.8
# 22              24.0
# 23              19.8
# 24              25.0
# 25              27.8
# 26              55.6
# 27              26.5
# 28              34.3
# 29              27.5
# 30              15.6
# 31              28.4
# 32              19.7
# 33              20.0
# 34              20.0
# 35              26.3
# 36              27.3
# 37              24.0
# 38              20.0
# 39              26.4
# 40              18.8
# 41              38.9
# 42              16.7
# 43              10.2
# 44              23.9
# 45              39.8
# 46              33.3
# 47              33.0
# 48              23.9
# 49              25.0
# 50              25.7
# 51              20.0
# 52              45.5
# 53              32.5
# 54              44.2
# 55              41.0
# 56              41.3
# 57              12.5
# 58              33.3
# 59              16.7
# 60              34.7
# 61              26.9
# 62               7.1
# 63              14.6
# 64               6.7
# 65              11.3
# 66              66.7
# 67              20.0
# 68              40.0
# 69              80.0
# 70               4.9
# 71               9.1
# 72               3.9
# 73               9.0
# 74               7.3
# 75              43.8
# 76              11.1
# 77              28.6
# 78              11.9

# %%
#Rebounds grouped by Period
SHOTS_PERCENT3=BLOCK_ALL_GAMES[((BLOCK_ALL_GAMES.PLAYER1_NAME!="No") & (BLOCK_ALL_GAMES.Event=="Made FG") & (BLOCK_ALL_GAMES.PLAYER1_TEAM_ABBREVIATION==TEAM))]
SHOTS_PERCENT3=SHOTS_PERCENT3.groupby(by=["PLAYER1_TEAM_ABBREVIATION","CLUTCH","PLAYER1_NAME"])["Event"].count()
SHOTS_PERCENT3=pd.DataFrame(SHOTS_PERCENT3)
SHOTS_PERCENT3.reset_index(inplace=True)
SHOTS_PERCENT3['CATEGORY_PERCENT']=SHOTS_PERCENT3['Event'] / SHOTS_PERCENT3.groupby(['PLAYER1_NAME'])['Event'].transform('sum')*100
SHOTS_PERCENT3=SHOTS_PERCENT3.round({'CATEGORY_PERCENT': 1})
# SHOTS_PERCENT["WEIGHTED"].groupby(by=["PLAYER1_NAME"]).sum() / SHOTS_PERCENT["Event"].groupby(by=["PLAYER1_NAME"]).sum()
# SHOTS_PERCENT=SHOTS_PERCENT.groupby(by=["PLAYER1_NAME"])(["WEIGHTED"]/["Event"])
SHOTS_PERCENT3
# Out:
#    PLAYER1_TEAM_ABBREVIATION           CLUTCH              PLAYER1_NAME  \
# 0                        DEN          2-5 MIN              Aaron Gordon
# 1                        DEN          2-5 MIN              Bones Hyland
# 2                        DEN          2-5 MIN               Bruce Brown
# 3                        DEN          2-5 MIN           Christian Braun
# 4                        DEN          2-5 MIN                Davon Reed
# 5                        DEN          2-5 MIN            DeAndre Jordan
# 6                        DEN          2-5 MIN                 Ish Smith
# 7                        DEN          2-5 MIN                Jack White
# 8                        DEN          2-5 MIN              Jamal Murray
# 9                        DEN          2-5 MIN                Jeff Green
# 10                       DEN          2-5 MIN  Kentavious Caldwell-Pope
# 11                       DEN          2-5 MIN        Michael Porter Jr.
# 12                       DEN          2-5 MIN              Nikola Jokic
# 13                       DEN          2-5 MIN             Peyton Watson
# 14                       DEN          2-5 MIN            Reggie Jackson
# 15                       DEN          2-5 MIN             Thomas Bryant
# 16                       DEN          2-5 MIN             Vlatko Cancar
# 17                       DEN          2-5 MIN                Zeke Nnaji
# 18                       DEN         6-12 MIN              Aaron Gordon
# 19                       DEN         6-12 MIN              Bones Hyland
# 20                       DEN         6-12 MIN               Bruce Brown
# 21                       DEN         6-12 MIN           Christian Braun
# 22                       DEN         6-12 MIN                Davon Reed
# 23                       DEN         6-12 MIN            DeAndre Jordan
# 24                       DEN         6-12 MIN                 Ish Smith
# 25                       DEN         6-12 MIN                Jack White
# 26                       DEN         6-12 MIN              Jamal Murray
# 27                       DEN         6-12 MIN                Jeff Green
# 28                       DEN         6-12 MIN  Kentavious Caldwell-Pope
# 29                       DEN         6-12 MIN        Michael Porter Jr.
# 30                       DEN         6-12 MIN              Nikola Jokic
# 31                       DEN         6-12 MIN             Peyton Watson
# 32                       DEN         6-12 MIN            Reggie Jackson
# 33                       DEN         6-12 MIN             Thomas Bryant
# 34                       DEN         6-12 MIN             Vlatko Cancar
# 35                       DEN         6-12 MIN                Zeke Nnaji
# 36                       DEN  LESS THAN 2 MIN              Aaron Gordon
# 37                       DEN  LESS THAN 2 MIN              Bones Hyland
# 38                       DEN  LESS THAN 2 MIN               Bruce Brown
# 39                       DEN  LESS THAN 2 MIN           Christian Braun
# 40                       DEN  LESS THAN 2 MIN                Davon Reed
# 41                       DEN  LESS THAN 2 MIN            DeAndre Jordan
# 42                       DEN  LESS THAN 2 MIN                 Ish Smith
# 43                       DEN  LESS THAN 2 MIN                Jack White
# 44                       DEN  LESS THAN 2 MIN              Jamal Murray
# 45                       DEN  LESS THAN 2 MIN                Jeff Green
# 46                       DEN  LESS THAN 2 MIN  Kentavious Caldwell-Pope
# 47                       DEN  LESS THAN 2 MIN        Michael Porter Jr.
# 48                       DEN  LESS THAN 2 MIN              Nikola Jokic
# 49                       DEN  LESS THAN 2 MIN             Peyton Watson
# 50                       DEN  LESS THAN 2 MIN            Reggie Jackson
# 51                       DEN  LESS THAN 2 MIN             Thomas Bryant
# 52                       DEN  LESS THAN 2 MIN             Vlatko Cancar
# 53                       DEN  LESS THAN 2 MIN                Zeke Nnaji
#
#     Event  CATEGORY_PERCENT
# 0      49              23.2
# 1      14              14.6
# 2      53              27.3
# 3      24              33.8
# 4       2              16.7
# 5       3               8.6
# 6       4              20.0
# 7       2              40.0
# 8      61              22.9
# 9      26              33.8
# 10     37              24.0
# 11     59              29.5
# 12    103              31.3
# 13      5              31.2
# 14      4              22.2
# 15      3              16.7
# 16     15              30.6
# 17     10              14.9
# 18    141              66.8
# 19     58              60.4
# 20    103              53.1
# 21     38              53.5
# 22      6              50.0
# 23     24              68.6
# 24      8              40.0
# 25      1              20.0
# 26    160              60.2
# 27     35              45.5
# 28    104              67.5
# 29    121              60.5
# 30    185              56.2
# 31      5              31.2
# 32     13              72.2
# 33      9              50.0
# 34     21              42.9
# 35     43              64.2
# 36     21              10.0
# 37     24              25.0
# 38     38              19.6
# 39      9              12.7
# 40      4              33.3
# 41      8              22.9
# 42      8              40.0
# 43      2              40.0
# 44     45              16.9
# 45     16              20.8
# 46     13               8.4
# 47     20              10.0
# 48     41              12.5
# 49      6              37.5
# 50      1               5.6
# 51      6              33.3
# 52     13              26.5
# 53     14              20.9
