# %%
import pandas as pd
import pandas_gbq
import plotly.express as px
import sys, requests
from pathlib import Path
from zipfile import ZipFile
import urllib
from PIL import Image

# %%
query = """
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, SHOT_DIST_RANGE, Season, "Reg Season" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.shot_dist_range`
GROUP BY 1,2,3,4,5,6
UNION ALL
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, SHOT_DIST_RANGE, Season, "Playoffs" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.playoffs_shot_dist_range`
GROUP BY 1,2,3,4,5,6
"""
project_id = "perceptive-ivy-290216"
shot_dist = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
query = """
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, REB_DIST_RANGE, Season, "Reg Season" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.reb_dist`
GROUP BY 1,2,3,4,5,6
UNION ALL
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, REB_DIST_RANGE, Season, "Playoffs" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.playoffs_reb_dist`
GROUP BY 1,2,3,4,5,6
"""
project_id = "perceptive-ivy-290216"
reb_dist = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
query = """
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, SHOT_TYPE_RANGE, Season, "Reg Season" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.shot_miss_type`
GROUP BY 1,2,3,4,5,6
UNION ALL
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, SHOT_TYPE_RANGE, Season, "Playoffs" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.playoffs_shot_miss_type`
GROUP BY 1,2,3,4,5,6
"""
project_id = "perceptive-ivy-290216"
shot_type = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
query = """
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, REB_NUM_CONTESTING_RANGE, Season, "Reg Season" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.num_contesting_reb`
GROUP BY 1,2,3,4,5,6
UNION ALL
SELECT 
PLAYER_ID, PLAYER_NAME_LAST_FIRST, SORT_ORDER, REB_NUM_CONTESTING_RANGE, Season, "Playoffs" as Category,
SUM(G) G, AVG(REB_FREQUENCY) REB_FREQUENCY, SUM(OREB) OREB, SUM(DREB) DREB, SUM(REB) REB, SUM(C_OREB) C_OREB, SUM(C_DREB) C_DREB, SUM(C_REB) C_REB, AVG(C_REB_PCT) C_REB_PCT, SUM(UC_OREB) UC_OREB, SUM(UC_DREB) UC_DREB, SUM(UC_REB) UC_REB, AVG(UC_REB_PCT) UC_REB_PCT,
FROM `perceptive-ivy-290216.nba_api_player_reb.num_contesting_reb`
GROUP BY 1,2,3,4,5,6
"""
project_id = "perceptive-ivy-290216"
reb_num = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
query = """
SELECT PLAYER_ID, TEAM_ABBREVIATION, SEASON FROM `perceptive-ivy-290216.player_team_info.player_bios_regs_totals`
# WHERE season='2023-24'
"""
project_id = "perceptive-ivy-290216"
player_team = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
def team_color(team):
    if team =="ATL":
        return "#C8102E"
    elif team =="DAL":
        return '#0050B5'
    elif team =="MEM":
        return '#0C2340'
    elif team =="MIA":
        return '#862633'
    elif team =="DEN":
        return '#1d428a'
    elif team =="DET":
        return '#1D4289'
    elif team =="GSW":
        return '#1D4289'
    elif team =="HOU":
        return '#BA0C2F'
    elif team =="IND":
        return '#041E42'
    elif team =="LAC":
        return '#0C2340'
    elif team =="LAL":
        return '#6a00ed'
    elif team =="POR":
        return '#C8102E'
    elif team =="PHX":
        return '#e56020'
    elif team =="PHI":
        return '#1D4289'
    elif team =="ORL":
        return '#0057B7'
    elif team =="OKC":
        return '#0072CE'
    elif team =="NYK":
        return '#FF8200'
    elif team =="NOP":
        return '#85714d'
    elif team =="MIN":
        return '#236192'
    elif team =="MIL":
        return '#2C5234'
    elif team =="BKN":
        return '#707372'
    elif team =="BOS":
        return '#007A33'
    elif team =="SEA":
        return '#00653A'
    elif team =="CHA":
        return '#00778B'
    elif team =="BUF":
        return '#418FDE'
    elif team =="CHI":
        return '#BA0C2F'       
    elif team =="CLE":
        return '#6F263D'
    elif team =="WAS":
        return '#C8102E'
    elif team =="UTA":
        return '#0C2340' 
    elif team =="TOR":
        return '#C8102E'
    elif team =="SAS":
        return '#9EA2A2'
    elif team =="SAC":
        return '#965ddd'                  
    
player_team['color'] = player_team['TEAM_ABBREVIATION'].apply(team_color)

# %%
#REGULAR SEASON

# %%
#SHOT DIST

# %%
year="2023-24"

# %%
#Combine player team data with player aggregated data so that we can color based on team
shot_dist_year=shot_dist[shot_dist["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to regular season
shot_dist_season=shot_dist_year[(shot_dist_year["Category"]=='Reg Season')]
#Create a player and team dict for color for future coloring
player_color_dict_shot_dist=dict(zip(shot_dist_season['PLAYER_NAME_LAST_FIRST'], shot_dist_season['color']))
team_color_dict_shot_dist=dict(zip(shot_dist_season['TEAM_ABBREVIATION'], shot_dist_season['color']))

# %%
fig_shot_dist_season = px.bar(
  shot_dist_season[(shot_dist_season["REB"]>100)&(shot_dist_season["SHOT_DIST_RANGE"]=="0-6 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Season</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season

# %%
fig_shot_dist_season.write_html("Player Rebounds by Shooting Distance=0-6 Feet For The {} Season".format(year))

# %%
fig_shot_dist_season2 = px.bar(
  shot_dist_season[(shot_dist_season["REB"]>75)&(shot_dist_season["SHOT_DIST_RANGE"]=="7-13 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Season</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season2.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season2

# %%
fig_shot_dist_season2.write_html("Player Rebounds by Shooting Distance=7-13 Feet For The {} Season".format(year))

# %%
fig_shot_dist_season3 = px.bar(
  shot_dist_season[(shot_dist_season["REB"]>40)&(shot_dist_season["SHOT_DIST_RANGE"]=="13-19 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Season</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season3.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season3

# %%
fig_shot_dist_season3.write_html("Player Rebounds by Shooting Distance=13-19 Feet For The {} Season".format(year))

# %%
fig_shot_dist_season4 = px.bar(
  shot_dist_season[(shot_dist_season["REB"]>200)&(shot_dist_season["SHOT_DIST_RANGE"]=="19+ Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Season</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season4.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season4

# %%
fig_shot_dist_season4.write_html("Player Rebounds by Shooting Distance=19+ Feet For The {} Season".format(year))

# %%
#REB DIST

# %%
#Combine player team data with player aggregated data so that we can color based on team
reb_dist_year=reb_dist[reb_dist["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to regular season
reb_dist_season=reb_dist_year[(reb_dist_year["Category"]=='Reg Season')]
#Create a player and team dict for color for future coloring
player_color_dict_reb_dist=dict(zip(reb_dist_season['PLAYER_NAME_LAST_FIRST'], reb_dist_season['color']))
team_color_dict_reb_dist=dict(zip(reb_dist_season['TEAM_ABBREVIATION'], reb_dist_season['color']))

# %%
reb_dist_season.head()
# Out:
#      PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER REB_DIST_RANGE   Season  \
# 688     203991          Capela, Clint           1       0-3 Feet  2023-24
# 689    1630552         Johnson, Jalen           1       0-3 Feet  2023-24
# 690    1627749       Murray, Dejounte           1       0-3 Feet  2023-24
# 691    1630180            Bey, Saddiq           1       0-3 Feet  2023-24
# 692    1630168        Okongwu, Onyeka           1       0-3 Feet  2023-24
#
#        Category    G  REB_FREQUENCY  OREB  DREB  ...  C_DREB  C_REB  \
# 688  Reg Season  164          0.035   131   128  ...      64    177
# 689  Reg Season   82          0.037    23   113  ...      41     57
# 690  Reg Season   82          0.018     8    57  ...      13     19
# 691  Reg Season   82          0.019    37    32  ...       9     41
# 692  Reg Season   82          0.028    43    61  ...      26     58
#
#      C_REB_PCT  UC_OREB  UC_DREB  UC_REB  UC_REB_PCT  TEAM_ABBREVIATION  \
# ...

# %%
fig_reb_dist_season = px.bar(
  reb_dist_season[(reb_dist_season["REB"]>100)&(reb_dist_season["REB_DIST_RANGE"]=="0-3 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=0-3 Feet For The {} Season</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season

# %%
fig_reb_dist_season.write_html("Player Rebounds by Rebounding Distance=0-3 Feet For The {} Season".format(year))

# %%
fig_reb_dist_season2 = px.bar(
  reb_dist_season[(reb_dist_season["REB"]>150)&(reb_dist_season["REB_DIST_RANGE"]=="3-6 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=3-6 Feet For The {} Season</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season2.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season2

# %%
fig_reb_dist_season2.write_html("Player Rebounds by Rebounding Distance=3-6 Feet For The {} Season".format(year))

# %%
fig_reb_dist_season3 = px.bar(
  reb_dist_season[(reb_dist_season["REB"]>100)&(reb_dist_season["REB_DIST_RANGE"]=="6-10 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=6-10 Feet For The {} Season</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season3.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season3

# %%
fig_reb_dist_season3.write_html("Player Rebounds by Rebounding Distance=6-10 Feet For The {} Season".format(year))

# %%
fig_reb_dist_season4 = px.bar(
  reb_dist_season[(reb_dist_season["REB"]>90)&(reb_dist_season["REB_DIST_RANGE"]=="10+ Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=10+ Feet For The {} Season</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season4.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season4

# %%
fig_reb_dist_season4.write_html("Player Rebounds by Rebounding Distance=10+ Feet For The {} Season".format(year))

# %%
#SHOT TYPE

# %%
#Combine player team data with player aggregated data so that we can color based on team
shot_type_year=shot_type[shot_type["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to regular season
shot_type_season=shot_type_year[(shot_type_year["Category"]=='Reg Season')]
#Create a player and team dict for color for future coloring
player_color_dict_shot_type=dict(zip(shot_type_season['PLAYER_NAME_LAST_FIRST'], shot_type_season['color']))
team_color_dict_shot_type=dict(zip(shot_type_season['TEAM_ABBREVIATION'], shot_type_season['color']))

# %%
fig_shot_type_season = px.bar(
  shot_type_season[(shot_type_season["REB"]>200)&(shot_type_season["SHOT_TYPE_RANGE"]=="Miss 2FG")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds By Shot Type=Missed 2FG For The {} Season</b>".format(year),
  hover_data=['G','SHOT_TYPE_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_type_season.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_type_season

# %%
fig_shot_type_season.write_html("Player Rebounds Shot Type=Missed 2FG For The {} Season".format(year))

# %%
fig_shot_type_season2 = px.bar(
  shot_type_season[(shot_type_season["REB"]>200)&(shot_type_season["SHOT_TYPE_RANGE"]=="Miss 3FG")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds By Shot Type=Missed 3FG For The {} Season</b>".format(year),
  hover_data=['G','SHOT_TYPE_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_type_season2.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_type_season2

# %%
fig_shot_type_season2.write_html("Player Rebounds Shot Type=Missed 3FG For The {} Season".format(year))

# %%
#NUM CONTESTING REB

# %%
#Combine player team data with player aggregated data so that we can color based on team
reb_num_year=reb_num[reb_num["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to regular season
reb_num_season=reb_num_year[(reb_num_year["Category"]=='Reg Season')]
#Create a player and team dict for color for future coloring
player_color_dict_shot_type=dict(zip(reb_num_season['PLAYER_NAME_LAST_FIRST'], reb_num_season['color']))
player_color_dict_reb_num=dict(zip(reb_num_season['TEAM_ABBREVIATION'], reb_num_season['color']))

# %%
fig_reb_num_season = px.bar(
  reb_num_season[(reb_num_season["REB"]>300)&(reb_num_season["REB_NUM_CONTESTING_RANGE"]=="0 Contesting Rebounders")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds With 0 Contesting Rebounders For The {} Season</b>".format(year),
  hover_data=['G','REB_NUM_CONTESTING_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_num_season.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_num_season

# %%
fig_reb_num_season.write_html("Player Rebounds With 0 Contesting Rebounders For The {} Season".format(year))

# %%
fig_reb_num_season2 = px.bar(
  reb_num_season[(reb_num_season["REB"]>150)&(reb_num_season["REB_NUM_CONTESTING_RANGE"]=="1 Contesting Rebounder")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds With 1 Contesting Rebounders For The {} Season</b>".format(year),
  hover_data=['G','REB_NUM_CONTESTING_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_num_season2.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_num_season2

# %%
fig_reb_num_season2.write_html("Player Rebounds With 1 Contesting Rebounders For The {} Season".format(year))

# %%
fig_reb_num_season3 = px.bar(
  reb_num_season[(reb_num_season["REB"]>25)&(reb_num_season["REB_NUM_CONTESTING_RANGE"]=="2+ Contesting Rebounders")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist,     
  template='plotly_white',
  title="<b>Player Rebounds With 2+ Contesting Rebounders For The {} Season</b>".format(year),
  hover_data=['G','REB_NUM_CONTESTING_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_num_season3.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_num_season3

# %%
fig_reb_num_season3.write_html("Player Rebounds With 2+ Contesting Rebounders For The {} Season".format(year))

# %%
#PLAYOFFS

# %%
#SHOT DIST

# %%
year="2023-24"

# %%
#Combine player team data with player aggregated data so that we can color based on team
shot_dist_year_playoffs=shot_dist[shot_dist["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to plfs
shot_dist_season_playoffs=shot_dist_year_playoffs[(shot_dist_year_playoffs["Category"]=='Playoffs')]
#Create a player and team dict for color for future coloring
player_color_dict_shot_dist_playoffs=dict(zip(shot_dist_season_playoffs['PLAYER_NAME_LAST_FIRST'], shot_dist_season_playoffs['color']))
team_color_dict_shot_dist_playoffs=dict(zip(shot_dist_season_playoffs['TEAM_ABBREVIATION'], shot_dist_season_playoffs['color']))

# %%
fig_shot_dist_season_playoffs = px.bar(
  shot_dist_season_playoffs[(shot_dist_season_playoffs["REB"]>100)&(shot_dist_season_playoffs["SHOT_DIST_RANGE"]=="0-6 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season_playoffs

# %%
fig_shot_dist_season_playoffs.write_html("Player Rebounds by Shooting Distance=0-6 Feet For The {} Playoffs".format(year))

# %%
fig_shot_dist_season2_playoffs = px.bar(
  shot_dist_season_playoffs[(shot_dist_season_playoffs["REB"]>75)&(shot_dist_season_playoffs["SHOT_DIST_RANGE"]=="7-13 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season2_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season2_playoffs

# %%
fig_shot_dist_season2_playoffs.write_html("Player Rebounds by Shooting Distance=7-13 Feet For The {} Playoffs".format(year))

# %%
fig_shot_dist_season3_playoffs = px.bar(
  shot_dist_season_playoffs[(shot_dist_season_playoffs["REB"]>40)&(shot_dist_season_playoffs["SHOT_DIST_RANGE"]=="13-19 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season3_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season3_playoffs

# %%
fig_shot_dist_season3_playoffs.write_html("Player Rebounds by Shooting Distance=13-19 Feet For The {} Playoffs".format(year))

# %%
fig_shot_dist_season4_playoffs = px.bar(
  shot_dist_season_playoffs[(shot_dist_season_playoffs["REB"]>200)&(shot_dist_season_playoffs["SHOT_DIST_RANGE"]=="19+ Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Shooting Distance=0-6 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','SHOT_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_dist_season4_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_dist_season4_playoffs

# %%
fig_shot_dist_season4_playoffs.write_html("Player Rebounds by Shooting Distance=19+ Feet For The {} Playoffs".format(year))

# %%
#REB DIST

# %%
#Combine player team data with player aggregated data so that we can color based on team
reb_dist_year_playoffs=reb_dist[reb_dist["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to plfs
reb_dist_season_playoffs=reb_dist_year_playoffs[(reb_dist_year_playoffs["Category"]=='Playoffs')]
#Create a player and team dict for color for future coloring
player_color_dict_reb_dist_playoffs=dict(zip(reb_dist_season_playoffs['PLAYER_NAME_LAST_FIRST'], reb_dist_season_playoffs['color']))
team_color_dict_reb_dist_playoffs=dict(zip(reb_dist_season_playoffs['TEAM_ABBREVIATION'], reb_dist_season_playoffs['color']))

# %%
fig_reb_dist_season_playoffs = px.bar(
  reb_dist_season_playoffs[(reb_dist_season_playoffs["REB"]>100)&(reb_dist_season_playoffs["REB_DIST_RANGE"]=="0-3 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=0-3 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season_playoffs

# %%
fig_reb_dist_season_playoffs.write_html("Player Rebounds by Rebounding Distance=0-3 Feet For The {} Playoffs".format(year))

# %%
fig_reb_dist_season2_playoffs = px.bar(
  reb_dist_season_playoffs[(reb_dist_season_playoffs["REB"]>150)&(reb_dist_season_playoffs["REB_DIST_RANGE"]=="3-6 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=3-6 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season2_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season2_playoffs

# %%
fig_reb_dist_season2_playoffs.write_html("Player Rebounds by Rebounding Distance=3-6 Feet For The {} Playoffs".format(year))

# %%
fig_reb_dist_season3_playoffs = px.bar(
  reb_dist_season_playoffs[(reb_dist_season_playoffs["REB"]>100)&(reb_dist_season_playoffs["REB_DIST_RANGE"]=="6-10 Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=6-10 Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season3_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season3_playoffs

# %%
fig_reb_dist_season3_playoffs.write_html("Player Rebounds by Rebounding Distance=6-10 Feet For The {} Playoffs".format(year))

# %%
fig_reb_dist_season4_playoffs = px.bar(
  reb_dist_season_playoffs[(reb_dist_season_playoffs["REB"]>90)&(reb_dist_season_playoffs["REB_DIST_RANGE"]=="10+ Feet")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds by Rebounding Distance=10+ Feet For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_DIST_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_dist_season4_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_dist_season4_playoffs

# %%
fig_reb_dist_season4_playoffs.write_html("Player Rebounds by Rebounding Distance=10+ Feet For The {} Playoffs".format(year))

# %%
#SHOT TYPE

# %%
#Combine player team data with player aggregated data so that we can color based on team
shot_type_year_playoffs=shot_type[shot_type["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to plfs
shot_type_season_playoffs=shot_type_year_playoffs[(shot_type_year_playoffs["Category"]=='Playoffs')]
#Create a player and team dict for color for future coloring
player_color_dict_shot_type_playoffs=dict(zip(shot_type_season_playoffs['PLAYER_NAME_LAST_FIRST'], shot_type_season_playoffs['color']))
team_color_dict_shot_type_playoffs=dict(zip(shot_type_season_playoffs['TEAM_ABBREVIATION'], shot_type_season_playoffs['color']))

# %%
fig_shot_type_season_playoffs = px.bar(
  shot_type_season_playoffs[(shot_type_season_playoffs["REB"]>200)&(shot_type_season_playoffs["SHOT_TYPE_RANGE"]=="Miss 2FG")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds By Shot Type=Missed 2FG For The {} Playoffs</b>".format(year),
  hover_data=['G','SHOT_TYPE_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_type_season_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_type_season_playoffs

# %%
fig_shot_type_season_playoffs.write_html("Player Rebounds Shot Type=Missed 2FG For The {} Playoffs".format(year))

# %%
fig_shot_type_season2_playoffs = px.bar(
  shot_type_season_playoffs[(shot_type_season_playoffs["REB"]>200)&(shot_type_season_playoffs["SHOT_TYPE_RANGE"]=="Miss 3FG")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds By Shot Type=Missed 3FG For The {} Playoffs</b>".format(year),
  hover_data=['G','SHOT_TYPE_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_shot_type_season2_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_shot_type_season2_playoffs

# %%
fig_shot_type_season2_playoffs.write_html("Player Rebounds Shot Type=Missed 3FG For The {} Playoffs".format(year))

# %%
#NUM CONTESTING REB

# %%
#Combine player team data with player aggregated data so that we can color based on team
reb_num_year_playoffs=reb_num[reb_num["Season"]==year].merge(player_team[player_team["SEASON"]==year], left_on=["PLAYER_ID","Season"], right_on=["PLAYER_ID","SEASON"])
#Filter to plfs
reb_num_season_playoffs=reb_num_year_playoffs[(reb_num_year_playoffs["Category"]=='Playoffs')]
#Create a player and team dict for color for future coloring
player_color_dict_shot_type_playoffs=dict(zip(reb_num_season_playoffs['PLAYER_NAME_LAST_FIRST'], reb_num_season_playoffs['color']))
player_color_dict_reb_num_playoffs=dict(zip(reb_num_season_playoffs['TEAM_ABBREVIATION'], reb_num_season_playoffs['color']))

# %%
fig_reb_num_season_playoffs = px.bar(
  reb_num_season_playoffs[(reb_num_season_playoffs["REB"]>300)&(reb_num_season_playoffs["REB_NUM_CONTESTING_RANGE"]=="0 Contesting Rebounders")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds With 0 Contesting Rebounders For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_NUM_CONTESTING_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_num_season_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_num_season_playoffs

# %%
fig_reb_num_season_playoffs.write_html("Player Rebounds With 0 Contesting Rebounders For The {} Playoffs".format(year))

# %%
fig_reb_num_season2_playoffs = px.bar(
  reb_num_season_playoffs[(reb_num_season_playoffs["REB"]>150)&(reb_num_season_playoffs["REB_NUM_CONTESTING_RANGE"]=="1 Contesting Rebounder")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds With 1 Contesting Rebounders For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_NUM_CONTESTING_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_num_season2_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_num_season2_playoffs

# %%
fig_reb_num_season2_playoffs.write_html("Player Rebounds With 1 Contesting Rebounders For The {} Playoffs".format(year))

# %%
fig_reb_num_season3_playoffs = px.bar(
  reb_num_season_playoffs[(reb_num_season_playoffs["REB"]>25)&(reb_num_season_playoffs["REB_NUM_CONTESTING_RANGE"]=="2+ Contesting Rebounders")].sort_values(by="REB",ascending=False), 
  x="PLAYER_NAME_LAST_FIRST", 
  y="REB",
#   y="OREB",
#   y="DREB",
  color="PLAYER_NAME_LAST_FIRST",
  color_discrete_map=player_color_dict_shot_dist_playoffs,     
  template='plotly_white',
  title="<b>Player Rebounds With 2+ Contesting Rebounders For The {} Playoffs</b>".format(year),
  hover_data=['G','REB_NUM_CONTESTING_RANGE', 'REB_FREQUENCY', 'OREB', 'DREB', 'REB', 'C_OREB','C_DREB', 'C_REB', 'C_REB_PCT', 'UC_OREB', 'UC_DREB', 'UC_REB',
              'UC_REB_PCT', 'Season', 'Category', 'TEAM_ABBREVIATION','color'], 
  height=800, 
  width=1200,
  )
fig_reb_num_season3_playoffs.update_layout(
    margin=dict(l=5, r=5, t=40, b=5),
    showlegend=False,
    title_x=0.5,
    hoverlabel=dict(
        bgcolor="white",
        font_size=16,
        font_family="PT Sans Narrow"
    ),
    # yaxis_range=[0,85],
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
)
fig_reb_num_season3_playoffs

# %%
fig_reb_num_season3_playoffs.write_html("Player Rebounds With 2+ Contesting Rebounders For The {} Playoffs".format(year))

# %%
# #Create DFs for All time Data
# df_player_all_time=pd.DataFrame(df_bq2[df_bq2["Category"]=='Player Totals Reg Season'].groupby(by=['PLAYER_NAME','Category'])[['GP','CATCH_SHOOT_FGM', 'CATCH_SHOOT_FGA','CATCH_SHOOT_PTS', 'CATCH_SHOOT_FG3M', 'CATCH_SHOOT_FG3A']].sum()).reset_index()
# df_team_all_time=pd.DataFrame(df_bq2_team[df_bq2_team["Category"]=='Team Totals Reg Season'].groupby(by=['TEAM_ABBREVIATION','Category'])[['GP','CATCH_SHOOT_FGM', 'CATCH_SHOOT_FGA','CATCH_SHOOT_PTS', 'CATCH_SHOOT_FG3M', 'CATCH_SHOOT_FG3A']].sum()).reset_index()

# df_player_all_time_playoffs=pd.DataFrame(df_bq2[df_bq2["Category"]=='Player Totals Playoffs'].groupby(by=['PLAYER_NAME','Category'])[['GP','CATCH_SHOOT_FGM', 'CATCH_SHOOT_FGA','CATCH_SHOOT_PTS', 'CATCH_SHOOT_FG3M', 'CATCH_SHOOT_FG3A']].sum()).reset_index()
# df_team_all_time_playoffs=pd.DataFrame(df_bq2_team[df_bq2_team["Category"]=='Team Totals Playoffs'].groupby(by=['TEAM_ABBREVIATION','Category'])[['GP','CATCH_SHOOT_FGM', 'CATCH_SHOOT_FGA','CATCH_SHOOT_PTS', 'CATCH_SHOOT_FG3M', 'CATCH_SHOOT_FG3A']].sum()).reset_index()


# #Add in % columns
# df_player_all_time["CATCH_SHOOT_FG_PCT"]=df_player_all_time["CATCH_SHOOT_FGM"]/df_player_all_time["CATCH_SHOOT_FGA"]
# df_player_all_time["CATCH_SHOOT_FG3_PCT"]=df_player_all_time["CATCH_SHOOT_FG3M"]/df_player_all_time["CATCH_SHOOT_FG3A"]

# df_team_all_time["CATCH_SHOOT_FG_PCT"]=df_team_all_time["CATCH_SHOOT_FGM"]/df_team_all_time["CATCH_SHOOT_FGA"]
# df_team_all_time["CATCH_SHOOT_FG3_PCT"]=df_team_all_time["CATCH_SHOOT_FG3M"]/df_team_all_time["CATCH_SHOOT_FG3A"]

# df_player_all_time_playoffs["CATCH_SHOOT_FG_PCT"]=df_player_all_time_playoffs["CATCH_SHOOT_FGM"]/df_player_all_time_playoffs["CATCH_SHOOT_FGA"]
# df_player_all_time_playoffs["CATCH_SHOOT_FG3_PCT"]=df_player_all_time_playoffs["CATCH_SHOOT_FG3M"]/df_player_all_time_playoffs["CATCH_SHOOT_FG3A"]

# df_team_all_time_playoffs["CATCH_SHOOT_FG_PCT"]=df_team_all_time_playoffs["CATCH_SHOOT_FGM"]/df_team_all_time_playoffs["CATCH_SHOOT_FGA"]
# df_team_all_time_playoffs["CATCH_SHOOT_FG3_PCT"]=df_team_all_time_playoffs["CATCH_SHOOT_FG3M"]/df_team_all_time_playoffs["CATCH_SHOOT_FG3A"]
