# %%
import pandas as pd
import numpy as np
import pandas_gbq
import time
import itertools
import datetime
import matplotlib.pyplot as plt
from datetime import *
from datetime import datetime, timedelta, date
from pathlib import Path
from zipfile import ZipFile
import urllib
from PIL import Image
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Standard plotly imports
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import requests
import json
import plotly.graph_objects as go
project_id = "perceptive-ivy-290216"

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp1_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp1 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp2_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp2 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       2 query = """
#       3 SELECT
#       4 *
#       5 FROM
#       6 `perceptive-ivy-290216.f1_api.fp2_lap_time`
#       7 """
#       8 project_id = "perceptive-ivy-290216"
# ----> 9 df_bq2_fp2 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas_gbq/gbq.py:896, in read_gbq(query_or_table, project_id, index_col, columns, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes, auth_redirect_uri, client_id, client_secret, col_order)
#     881 connector = GbqConnector(
#     882     project_id,
#     883     reauth=reauth,
#    (...)
#     892     client_secret=client_secret,
#     893 )
#     895 if _is_query(query_or_table):
# --> 896     final_df = connector.run_query(
#     897         query_or_table,
#     898         configuration=configuration,
#     899         max_results=max_results,
#     900         progress_bar_type=progress_bar_type,
#     901         dtypes=dtypes,
#     902     )
#     903 else:
#     904     final_df = connector.download_table(
#     905         query_or_table,
#     906         max_results=max_results,
#     907         progress_bar_type=progress_bar_type,
#     908         dtypes=dtypes,
#     909     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas_gbq/gbq.py:435, in GbqConnector.run_query(self, query, max_results, progress_bar_type, **kwargs)
#     432 job_config = bigquery.QueryJobConfig.from_api_repr(job_config_dict)
#     434 if FEATURES.bigquery_has_query_and_wait:
# --> 435     rows_iter = pandas_gbq.query.query_and_wait_via_client_library(
#     436         self,
#     437         self.client,
#     438         query,
#     439         location=self.location,
#     440         project_id=self.project_id,
#     441         job_config=job_config,
#     442         max_results=max_results,
#     443         timeout_ms=timeout_ms,
#     444     )
#     445 else:
#     446     rows_iter = pandas_gbq.query.query_and_wait(
#     447         self,
#     448         self.client,
#    (...)
#     454         timeout_ms=timeout_ms,
#     455     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas_gbq/query.py:198, in query_and_wait_via_client_library(connector, client, query, job_config, location, project_id, max_results, timeout_ms)
#     187 def query_and_wait_via_client_library(
#     188     connector,
#     189     client: bigquery.Client,
#    (...)
#     196     timeout_ms: Optional[int],
#     197 ):
# --> 198     rows_iter = try_query(
#     199         connector,
#     200         functools.partial(
#     201             client.query_and_wait,
#     202             query,
#     203             job_config=job_config,
#     204             location=location,
#     205             project=project_id,
#     206             max_results=max_results,
#     207             wait_timeout=timeout_ms / 1000.0 if timeout_ms else None,
#     208         ),
#     209     )
#     210     logger.debug("Query done.\n")
#     211     return rows_iter
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas_gbq/query.py:85, in try_query(connector, query_fn)
#      83 try:
#      84     logger.debug("Requesting query... ")
# ---> 85     return query_fn()
#      86 except concurrent.futures.TimeoutError as ex:
#      87     raise pandas_gbq.exceptions.QueryTimeout("Reason: {0}".format(ex))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/bigquery/client.py:3601, in Client.query_and_wait(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#    3595     _verify_job_config_type(job_config, QueryJobConfig)
#    3597 job_config = _job_helpers.job_config_with_defaults(
#    3598     job_config, self._default_query_job_config
#    3599 )
# -> 3601 return _job_helpers.query_and_wait(
#    3602     self,
#    3603     query,
#    3604     job_config=job_config,
#    3605     location=location,
#    3606     project=project,
#    3607     api_timeout=api_timeout,
#    3608     wait_timeout=wait_timeout,
#    3609     retry=retry,
#    3610     job_retry=job_retry,
#    3611     page_size=page_size,
#    3612     max_results=max_results,
#    3613 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/bigquery/_job_helpers.py:509, in query_and_wait(client, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#     492     return table.RowIterator(
#     493         client=client,
#     494         api_request=functools.partial(client._call_api, retry, timeout=api_timeout),
#    (...)
#     505         num_dml_affected_rows=query_results.num_dml_affected_rows,
#     506     )
#     508 if job_retry is not None:
# --> 509     return job_retry(do_query)()
#     510 else:
#     511     return do_query()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/bigquery/_job_helpers.py:450, in query_and_wait.<locals>.do_query()
#     448 # For easier testing, handle the retries ourselves.
#     449 if retry is not None:
# --> 450     response = retry(client._call_api)(
#     451         retry=None,  # We're calling the retry decorator ourselves.
#     452         span_name="BigQuery.query",
#     453         span_attributes=span_attributes,
#     454         method="POST",
#     455         path=path,
#     456         data=request_body,
#     457         timeout=api_timeout,
#     458     )
#     459 else:
#     460     response = client._call_api(
#     461         retry=None,
#     462         span_name="BigQuery.query",
#    (...)
#     467         timeout=api_timeout,
#     468     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/bigquery/client.py:833, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     829 if span_name is not None:
#     830     with create_span(
#     831         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     832     ):
# --> 833         return call()
#     835 return call()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/auth/transport/requests.py:538, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535 remaining_time = guard.remaining_timeout
#     537 with TimeoutGuard(remaining_time) as guard:
# --> 538     response = super(AuthorizedSession, self).request(
#     539         method,
#     540         url,
#     541         data=data,
#     542         headers=request_headers,
#     543         timeout=timeout,
#     544         **kwargs
#     545     )
#     546 remaining_time = guard.remaining_timeout
#     548 # If the response indicated that the credentials needed to be
#     549 # refreshed, then refresh the credentials and re-attempt the
#     550 # request.
#     551 # A stored token may expire between the time it is retrieved and
#     552 # the time the request is made, so we may need to try twice.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp3_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp3 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
race="Las Vegas Grand Prix"

# %%
# FP1

# %%
df_bq_fp1=df_bq2_fp1[(df_bq2_fp1["GP"]==race)&(df_bq2_fp1["Year"]==2025)]
GP_fp1=df_bq_fp1
GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
GP_fp1=GP_fp1.sort_values(['Driver','LapNumber'])
GP_fp1["DriverNumber"]=GP_fp1["DriverNumber"].astype(int)
year=GP_fp1['Year'].iloc[0]
gp=GP_fp1['GP'].iloc[0]
GP_fp1.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_39916/1916111373.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
#                        Time Driver  DriverNumber                 LapTime  \
# 184  0 days 00:18:38.189000    ALB            23                     NaT
# 185  0 days 00:20:20.287000    ALB            23  0 days 00:01:42.098000
# 186  0 days 00:22:10.930000    ALB            23  0 days 00:01:50.643000
# 187  0 days 00:33:41.270000    ALB            23                     NaT
# 188  0 days 00:35:18.885000    ALB            23  0 days 00:01:37.615000
#
#      LapNumber  Stint              PitOutTime               PitInTime  \
# 184          1    1.0  0 days 00:16:54.083000                     NaT
# 185          2    1.0                     NaT                     NaT
# 186          3    1.0                     NaT  0 days 00:22:08.065000
# 187          4    2.0  0 days 00:31:59.482000                     NaT
# 188          5    2.0                     NaT                     NaT
#
#                 Sector1Time             Sector2Time             Sector3Time  \
# 184                     NaT  0 days 00:00:36.135000  0 days 00:00:39.757000
# 185  0 days 00:00:29.466000  0 days 00:00:34.240000  0 days 00:00:38.392000
# 186  0 days 00:00:28.302000  0 days 00:00:33.526000  0 days 00:00:48.815000
# 187                     NaT  0 days 00:00:34.545000  0 days 00:00:40.528000
# 188  0 days 00:00:27.637000  0 days 00:00:32.383000  0 days 00:00:37.068000
#
#          Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 184                     NaT  0 days 00:17:58.679000  0 days 00:18:38.315000
# 185  0 days 00:19:07.655000  0 days 00:19:41.895000  0 days 00:20:20.287000
# 186  0 days 00:20:48.589000  0 days 00:21:22.115000  0 days 00:22:10.930000
# 187                     NaT  0 days 00:33:01.178000  0 days 00:33:41.669000
# 188  0 days 00:34:08.907000  0 days 00:34:41.290000  0 days 00:35:18.358000
#
#      SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest Compound  TyreLife  \
# 184    167.0    196.0    289.0    285.0          False   MEDIUM       1.0
# 185    177.0    200.0    310.0    311.0           True   MEDIUM       2.0
# 186    180.0    203.0      NaN    255.0          False   MEDIUM       3.0
# 187    173.0      NaN    314.0    219.0          False   MEDIUM       4.0
# 188    183.0    204.0    317.0    335.0           True   MEDIUM       5.0
#
#     FreshTyre      Team            LapStartTime             LapStartDate  \
# 184      True  Williams  0 days 00:16:54.083000  2025-11-21 00:31:54.091
# 185      True  Williams  0 days 00:18:38.189000  2025-11-21 00:33:38.197
# 186      True  Williams  0 days 00:20:20.287000  2025-11-21 00:35:20.295
# 187     False  Williams  0 days 00:22:10.930000  2025-11-21 00:37:10.938
# 188     False  Williams  0 days 00:33:41.270000  2025-11-21 00:48:41.278
#
#     TrackStatus  Position  Deleted DeletedReason  FastF1Generated IsAccurate  \
# 184           1       NaN    False                          False      False
# 185           1       NaN    False                          False       True
# 186           1       NaN    False                          False      False
# 187          12       NaN    False                          False      False
# 188           1       NaN    False                          False      False
#
#      Year                    GP
# 184  2025  Las Vegas Grand Prix
# 185  2025  Las Vegas Grand Prix
# 186  2025  Las Vegas Grand Prix
# 187  2025  Las Vegas Grand Prix
# 188  2025  Las Vegas Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp1['LapTime_TD']= pd.to_timedelta(GP_fp1["LapTime"])
GP_fp1["LapTime"]=GP_fp1['LapTime'].str.split('days ').str[1]
GP_fp1.loc[:, "LapTime (s)"] = GP_fp1["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp1['s1_TD']= pd.to_timedelta(GP_fp1["Sector1Time"])
GP_fp1['s2_TD']= pd.to_timedelta(GP_fp1["Sector2Time"])
GP_fp1['s3_TD']= pd.to_timedelta(GP_fp1["Sector3Time"])

GP_fp1.loc[:, "Time S1 (s)"] = GP_fp1["s1_TD"].dt.total_seconds()
GP_fp1.loc[:, "Time S2 (s)"] = GP_fp1["s2_TD"].dt.total_seconds()
GP_fp1.loc[:, "Time S3 (s)"] = GP_fp1["s3_TD"].dt.total_seconds()

# %%
GP_fp1_Rk=GP_fp1[GP_fp1["LapTime"]!="NaT"]
GP_fp1_Rk["LAP_RK"] = GP_fp1_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S1_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S2_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S3_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["Race_RK"] = GP_fp1_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp1_Sectors=GP_fp1_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp1_Sectors=GP_fp1_Sectors.fillna(0)
GP_fp1_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#     Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s) LapTime  \
# 184    ALB          1          0.0       36.135       39.757       0
# 80     ALO          1          0.0       37.870       40.338       0
# 50     ANT          1          0.0       40.036       44.562       0
# 507    BEA          1          0.0       42.067       42.231       0
# 369    BOR          1          0.0       41.657       42.016       0
#
#      LapTime (s) Compound  Year                    GP  LAP_RK  S1_RK  S2_RK  \
# 184          0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0    2.0
# 80           0.0     SOFT  2025  Las Vegas Grand Prix     0.0    0.0    8.0
# 50           0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0   12.0
# 507          0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0   19.0
# 369          0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0   18.0
#
#      S3_RK
# 184    1.0
# 80     4.0
# 50    17.0
# 507   12.0
# 369   10.0

# %%
#2025
def driver_color(driver):
    #RED BULL
    if driver =="VER":
        return "#3860C6"
    elif driver =="TSU":
        return "#3860C6"       
    #MCLAREN
    elif driver =="NOR":
        return '#FF8000'
    elif driver =="PIA":
        return '#FF8000'
    #FERRARI
    elif driver =="LEC":
        return '#E80020'
    elif driver =="HAM":
        return '#E80020'
    elif driver =="ZHO":
        return '#E80020'    
    #MERCEDES
    elif driver =="ANT":
        return '#27F4D2'
    elif driver =="RUS":
        return '#27F4D2'
    elif driver =="BOT":
        return '#27F4D2'    
    #ASTON
    elif driver =="ALO":
        return '#229971'
    elif driver =="STR":
        return '#229971'
    #ALPINE
    elif driver =="GAS":
        return '#0093cc'
    elif driver =="DOO":
        return '#0093cc'
    elif driver =="COL":
        return '#0093cc'
    #HAAS
    elif driver =="BEA":
        return '#B6BABD'
    elif driver =="OCO":
        return '#B6BABD'
    #SAUBER
    elif driver =="HUL":
        return '#52e252'
    elif driver =="BOR":
        return '#52e252'
    #WILLIAMS
    elif driver =="ALB":
        return '#64C4FF'
    elif driver =="SAI":
        return '#64C4FF'
    #RACING BULLS   
    elif driver =="LAW":
        return '#6692FF'
    elif driver =="HAD":
        return '#6692FF'   
    else:
        return '#3860C6'

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp1=GP_fp1_Sectors[GP_fp1_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp1.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp1.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp1.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp1.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp1=Fastest_Lap_fp1.merge(Fastest_sector1_fp1,on=['LapNumber']).merge(Fastest_sector2_fp1,on=['LapNumber']).merge(Fastest_sector3_fp1,on=['LapNumber'])
Fast_Laps_fp1=Fast_Laps_fp1[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp1=Fast_Laps_fp1.reset_index(drop=True)
Fast_Laps_fp1.head()
# Out:
#                      GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Las Vegas Grand Prix  2025          2  00:01:38.686000       98.686
# 1  Las Vegas Grand Prix  2025          3  00:01:38.011000       98.011
# 2  Las Vegas Grand Prix  2025          4  00:01:37.685000       97.685
# 3  Las Vegas Grand Prix  2025          5  00:01:36.493000       96.493
# 4  Las Vegas Grand Prix  2025          6  00:01:36.758000       96.758
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         PIA       MEDIUM       28.475        PIA      MEDIUM       33.008
# 1         VER       MEDIUM       27.912        NOR      MEDIUM       33.061
# 2         PIA       MEDIUM       27.903        PIA      MEDIUM       32.894
# 3         VER       MEDIUM       27.287        VER      MEDIUM       32.383
# 4         NOR       MEDIUM       27.325        ALO        SOFT       31.833
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        PIA      MEDIUM       37.203        PIA      MEDIUM
# 1        RUS      MEDIUM       37.005        VER      MEDIUM
# 2        PIA      MEDIUM       36.888        PIA      MEDIUM
# 3        ALB      MEDIUM       36.737        VER      MEDIUM
# 4        NOR      MEDIUM       36.719        PIA      MEDIUM

# %%
Fast_Laps_fp1['color'] = Fast_Laps_fp1['Fastest Lap'].apply(driver_color)
Fast_Laps_fp1.head()
# Out:
#                      GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Las Vegas Grand Prix  2025          2  00:01:38.686000       98.686
# 1  Las Vegas Grand Prix  2025          3  00:01:38.011000       98.011
# 2  Las Vegas Grand Prix  2025          4  00:01:37.685000       97.685
# 3  Las Vegas Grand Prix  2025          5  00:01:36.493000       96.493
# 4  Las Vegas Grand Prix  2025          6  00:01:36.758000       96.758
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         PIA       MEDIUM       28.475        PIA      MEDIUM       33.008
# 1         VER       MEDIUM       27.912        NOR      MEDIUM       33.061
# 2         PIA       MEDIUM       27.903        PIA      MEDIUM       32.894
# 3         VER       MEDIUM       27.287        VER      MEDIUM       32.383
# 4         NOR       MEDIUM       27.325        ALO        SOFT       31.833
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        PIA      MEDIUM       37.203        PIA      MEDIUM  #FF8000
# 1        RUS      MEDIUM       37.005        VER      MEDIUM  #3860C6
# 2        PIA      MEDIUM       36.888        PIA      MEDIUM  #FF8000
# 3        ALB      MEDIUM       36.737        VER      MEDIUM  #3860C6
# 4        NOR      MEDIUM       36.719        PIA      MEDIUM  #FF8000

# %%
LapTime_fp1_ordered=Fast_Laps_fp1.sort_values(by=['LapTime (s)'])
LapTime_fp1_ordered.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 19  Las Vegas Grand Prix  2025         21  00:01:34.802000       94.802
# 14  Las Vegas Grand Prix  2025         16  00:01:34.968000       94.968
# 17  Las Vegas Grand Prix  2025         19  00:01:35.071000       95.071
# 12  Las Vegas Grand Prix  2025         14  00:01:35.109000       95.109
# 21  Las Vegas Grand Prix  2025         23  00:01:35.117000       95.117
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 19         LEC         SOFT       26.748        ALB        SOFT       31.724
# 14         ALB         SOFT       26.711        HAM        SOFT       31.761
# 17         TSU         SOFT       26.704        HAM        SOFT       31.748
# 12         VER         SOFT       26.705        VER        SOFT       32.068
# 21         TSU         SOFT       26.707        TSU        SOFT       31.860
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 19        LEC        SOFT       36.287        LEC        SOFT  #E80020
# 14        ALB        SOFT       36.295        ALB        SOFT  #64C4FF
# 17        LEC        SOFT       36.256        TSU        SOFT  #3860C6
# 12        VER        SOFT       36.336        VER        SOFT  #3860C6
# 21        LAW        SOFT       36.536        TSU        SOFT  #3860C6

# %%
LapTime_fp1_ordered.sort_values(by=['Time S1 (s)'])
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 17  Las Vegas Grand Prix  2025         19  00:01:35.071000       95.071
# 12  Las Vegas Grand Prix  2025         14  00:01:35.109000       95.109
# 21  Las Vegas Grand Prix  2025         23  00:01:35.117000       95.117
# 14  Las Vegas Grand Prix  2025         16  00:01:34.968000       94.968
# 18  Las Vegas Grand Prix  2025         20  00:01:35.460000       95.460
# 13  Las Vegas Grand Prix  2025         15  00:01:35.281000       95.281
# 19  Las Vegas Grand Prix  2025         21  00:01:34.802000       94.802
# 15  Las Vegas Grand Prix  2025         17  00:01:35.121000       95.121
# 25  Las Vegas Grand Prix  2025         27  00:01:38.020000       98.020
# 16  Las Vegas Grand Prix  2025         18  00:01:35.568000       95.568
# 26  Las Vegas Grand Prix  2025         28  00:01:35.299000       95.299
# 10  Las Vegas Grand Prix  2025         12  00:01:35.561000       95.561
# 20  Las Vegas Grand Prix  2025         22  00:01:35.450000       95.450
# 23  Las Vegas Grand Prix  2025         25  00:01:35.179000       95.179
# 27  Las Vegas Grand Prix  2025         29  00:01:53.657000      113.657
# 9   Las Vegas Grand Prix  2025         11  00:01:35.954000       95.954
# 11  Las Vegas Grand Prix  2025         13  00:01:35.699000       95.699
# 5   Las Vegas Grand Prix  2025          7  00:01:36.043000       96.043
# 7   Las Vegas Grand Prix  2025          9  00:01:35.776000       95.776
# 8   Las Vegas Grand Prix  2025         10  00:01:36.083000       96.083
# 3   Las Vegas Grand Prix  2025          5  00:01:36.493000       96.493
# 4   Las Vegas Grand Prix  2025          6  00:01:36.758000       96.758
# 6   Las Vegas Grand Prix  2025          8  00:01:36.250000       96.250
# 22  Las Vegas Grand Prix  2025         24  00:01:37.886000       97.886
# 24  Las Vegas Grand Prix  2025         26  00:01:37.732000       97.732
# 2   Las Vegas Grand Prix  2025          4  00:01:37.685000       97.685
# 1   Las Vegas Grand Prix  2025          3  00:01:38.011000       98.011
# 0   Las Vegas Grand Prix  2025          2  00:01:38.686000       98.686
# 28  Las Vegas Grand Prix  2025         30  00:01:50.150000      110.150
# 29  Las Vegas Grand Prix  2025         31  00:02:10.312000      130.312
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 17         TSU         SOFT       26.704        HAM        SOFT       31.748
# 12         VER         SOFT       26.705        VER        SOFT       32.068
# 21         TSU         SOFT       26.707        TSU        SOFT       31.860
# 14         ALB         SOFT       26.711        HAM        SOFT       31.761
# 18         PIA         SOFT       26.729        HAM        SOFT       31.340
# 13         LEC         SOFT       26.747        HAM        SOFT       31.858
# 19         LEC         SOFT       26.748        ALB        SOFT       31.724
# 15         LEC         SOFT       26.770        LEC        SOFT       31.942
# 25         LEC       MEDIUM       26.793        SAI        SOFT       32.726
# 16         ANT         SOFT       26.828        HAM        SOFT       31.886
# 26         HAD         SOFT       26.859        HAD        SOFT       31.493
# 10         HAM         SOFT       26.912        HAM        SOFT       31.670
# 20         PIA         SOFT       26.927        PIA        SOFT       32.156
# 23         SAI         SOFT       26.928        SAI        SOFT       31.816
# 27         SAI         SOFT       26.956        SAI        SOFT       34.259
# 9          LEC       MEDIUM       26.988        LEC      MEDIUM       32.098
# 11         RUS         SOFT       27.048        RUS        SOFT       31.833
# 5          VER       MEDIUM       27.058        VER      MEDIUM       32.297
# 7          VER       MEDIUM       27.149        VER      MEDIUM       31.996
# 8          RUS       MEDIUM       27.211        SAI      MEDIUM       31.684
# 3          VER       MEDIUM       27.287        VER      MEDIUM       32.383
# 4          NOR       MEDIUM       27.325        ALO        SOFT       31.833
# 6          PIA       MEDIUM       27.335        PIA      MEDIUM       31.718
# 22         PIA         SOFT       27.615        PIA        SOFT       32.562
# 24         LEC       MEDIUM       27.814        LEC      MEDIUM       32.727
# 2          PIA       MEDIUM       27.903        PIA      MEDIUM       32.894
# 1          VER       MEDIUM       27.912        NOR      MEDIUM       33.061
# 0          PIA       MEDIUM       28.475        PIA      MEDIUM       33.008
# 28         HAD         SOFT       31.815        HAD        SOFT       33.145
# 29         SAI         SOFT       54.743        SAI        SOFT       32.567
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 17        LEC        SOFT       36.256        TSU        SOFT  #3860C6
# 12        VER        SOFT       36.336        VER        SOFT  #3860C6
# 21        LAW        SOFT       36.536        TSU        SOFT  #3860C6
# 14        ALB        SOFT       36.295        ALB        SOFT  #64C4FF
# 18        ANT        SOFT       36.395        PIA        SOFT  #FF8000
# 13        LEC        SOFT       36.430        RUS        SOFT  #E80020
# 19        LEC        SOFT       36.287        LEC        SOFT  #E80020
# 15        LEC        SOFT       36.409        LEC        SOFT  #E80020
# 25        LEC      MEDIUM       37.204        LEC      MEDIUM  #E80020
# 16        ANT        SOFT       36.598        ANT        SOFT  #27F4D2
# 26        HAD        SOFT       36.420        HAD        SOFT  #6692FF
# 10        SAI      MEDIUM       36.624        HAM        SOFT  #E80020
# 20        PIA        SOFT       36.367        PIA        SOFT  #FF8000
# 23        SAI        SOFT       36.435        SAI        SOFT  #64C4FF
# 27        SAI        SOFT       48.421        LEC      MEDIUM  #64C4FF
# 9         LEC      MEDIUM       36.594        ANT      MEDIUM  #E80020
# 11        GAS      MEDIUM       36.452        RUS        SOFT  #27F4D2
# 5         HAD      MEDIUM       36.605        VER      MEDIUM  #3860C6
# 7         ALO        SOFT       36.466        VER      MEDIUM  #3860C6
# 8         RUS      MEDIUM       36.645        RUS      MEDIUM  #27F4D2
# 3         ALB      MEDIUM       36.737        VER      MEDIUM  #3860C6
# 4         NOR      MEDIUM       36.719        PIA      MEDIUM  #FF8000
# 6         STR      MEDIUM       36.581        RUS      MEDIUM  #FF8000
# 22        OCO        SOFT       36.950        PIA        SOFT  #FF8000
# 24        LEC      MEDIUM       37.191        LEC      MEDIUM  #E80020
# 2         PIA      MEDIUM       36.888        PIA      MEDIUM  #FF8000
# 1         RUS      MEDIUM       37.005        VER      MEDIUM  #3860C6
# 0         PIA      MEDIUM       37.203        PIA      MEDIUM  #FF8000
# 28        HAD        SOFT       44.633        ANT      MEDIUM  #6692FF
# 29        SAI        SOFT       42.484        SAI        SOFT  #64C4FF

# %%
LapTime_fp1_ordered.sort_values(by=['Time S2 (s)'])
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 18  Las Vegas Grand Prix  2025         20  00:01:35.460000       95.460
# 26  Las Vegas Grand Prix  2025         28  00:01:35.299000       95.299
# 10  Las Vegas Grand Prix  2025         12  00:01:35.561000       95.561
# 8   Las Vegas Grand Prix  2025         10  00:01:36.083000       96.083
# 6   Las Vegas Grand Prix  2025          8  00:01:36.250000       96.250
# 19  Las Vegas Grand Prix  2025         21  00:01:34.802000       94.802
# 17  Las Vegas Grand Prix  2025         19  00:01:35.071000       95.071
# 14  Las Vegas Grand Prix  2025         16  00:01:34.968000       94.968
# 23  Las Vegas Grand Prix  2025         25  00:01:35.179000       95.179
# 4   Las Vegas Grand Prix  2025          6  00:01:36.758000       96.758
# 11  Las Vegas Grand Prix  2025         13  00:01:35.699000       95.699
# 13  Las Vegas Grand Prix  2025         15  00:01:35.281000       95.281
# 21  Las Vegas Grand Prix  2025         23  00:01:35.117000       95.117
# 16  Las Vegas Grand Prix  2025         18  00:01:35.568000       95.568
# 15  Las Vegas Grand Prix  2025         17  00:01:35.121000       95.121
# 7   Las Vegas Grand Prix  2025          9  00:01:35.776000       95.776
# 12  Las Vegas Grand Prix  2025         14  00:01:35.109000       95.109
# 9   Las Vegas Grand Prix  2025         11  00:01:35.954000       95.954
# 20  Las Vegas Grand Prix  2025         22  00:01:35.450000       95.450
# 5   Las Vegas Grand Prix  2025          7  00:01:36.043000       96.043
# 3   Las Vegas Grand Prix  2025          5  00:01:36.493000       96.493
# 22  Las Vegas Grand Prix  2025         24  00:01:37.886000       97.886
# 29  Las Vegas Grand Prix  2025         31  00:02:10.312000      130.312
# 25  Las Vegas Grand Prix  2025         27  00:01:38.020000       98.020
# 24  Las Vegas Grand Prix  2025         26  00:01:37.732000       97.732
# 2   Las Vegas Grand Prix  2025          4  00:01:37.685000       97.685
# 0   Las Vegas Grand Prix  2025          2  00:01:38.686000       98.686
# 1   Las Vegas Grand Prix  2025          3  00:01:38.011000       98.011
# 28  Las Vegas Grand Prix  2025         30  00:01:50.150000      110.150
# 27  Las Vegas Grand Prix  2025         29  00:01:53.657000      113.657
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 18         PIA         SOFT       26.729        HAM        SOFT       31.340
# 26         HAD         SOFT       26.859        HAD        SOFT       31.493
# 10         HAM         SOFT       26.912        HAM        SOFT       31.670
# 8          RUS       MEDIUM       27.211        SAI      MEDIUM       31.684
# 6          PIA       MEDIUM       27.335        PIA      MEDIUM       31.718
# 19         LEC         SOFT       26.748        ALB        SOFT       31.724
# 17         TSU         SOFT       26.704        HAM        SOFT       31.748
# 14         ALB         SOFT       26.711        HAM        SOFT       31.761
# 23         SAI         SOFT       26.928        SAI        SOFT       31.816
# 4          NOR       MEDIUM       27.325        ALO        SOFT       31.833
# 11         RUS         SOFT       27.048        RUS        SOFT       31.833
# 13         LEC         SOFT       26.747        HAM        SOFT       31.858
# 21         TSU         SOFT       26.707        TSU        SOFT       31.860
# 16         ANT         SOFT       26.828        HAM        SOFT       31.886
# 15         LEC         SOFT       26.770        LEC        SOFT       31.942
# 7          VER       MEDIUM       27.149        VER      MEDIUM       31.996
# 12         VER         SOFT       26.705        VER        SOFT       32.068
# 9          LEC       MEDIUM       26.988        LEC      MEDIUM       32.098
# 20         PIA         SOFT       26.927        PIA        SOFT       32.156
# 5          VER       MEDIUM       27.058        VER      MEDIUM       32.297
# 3          VER       MEDIUM       27.287        VER      MEDIUM       32.383
# 22         PIA         SOFT       27.615        PIA        SOFT       32.562
# 29         SAI         SOFT       54.743        SAI        SOFT       32.567
# 25         LEC       MEDIUM       26.793        SAI        SOFT       32.726
# 24         LEC       MEDIUM       27.814        LEC      MEDIUM       32.727
# 2          PIA       MEDIUM       27.903        PIA      MEDIUM       32.894
# 0          PIA       MEDIUM       28.475        PIA      MEDIUM       33.008
# 1          VER       MEDIUM       27.912        NOR      MEDIUM       33.061
# 28         HAD         SOFT       31.815        HAD        SOFT       33.145
# 27         SAI         SOFT       26.956        SAI        SOFT       34.259
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 18        ANT        SOFT       36.395        PIA        SOFT  #FF8000
# 26        HAD        SOFT       36.420        HAD        SOFT  #6692FF
# 10        SAI      MEDIUM       36.624        HAM        SOFT  #E80020
# 8         RUS      MEDIUM       36.645        RUS      MEDIUM  #27F4D2
# 6         STR      MEDIUM       36.581        RUS      MEDIUM  #FF8000
# 19        LEC        SOFT       36.287        LEC        SOFT  #E80020
# 17        LEC        SOFT       36.256        TSU        SOFT  #3860C6
# 14        ALB        SOFT       36.295        ALB        SOFT  #64C4FF
# 23        SAI        SOFT       36.435        SAI        SOFT  #64C4FF
# 4         NOR      MEDIUM       36.719        PIA      MEDIUM  #FF8000
# 11        GAS      MEDIUM       36.452        RUS        SOFT  #27F4D2
# 13        LEC        SOFT       36.430        RUS        SOFT  #E80020
# 21        LAW        SOFT       36.536        TSU        SOFT  #3860C6
# 16        ANT        SOFT       36.598        ANT        SOFT  #27F4D2
# 15        LEC        SOFT       36.409        LEC        SOFT  #E80020
# 7         ALO        SOFT       36.466        VER      MEDIUM  #3860C6
# 12        VER        SOFT       36.336        VER        SOFT  #3860C6
# 9         LEC      MEDIUM       36.594        ANT      MEDIUM  #E80020
# 20        PIA        SOFT       36.367        PIA        SOFT  #FF8000
# 5         HAD      MEDIUM       36.605        VER      MEDIUM  #3860C6
# 3         ALB      MEDIUM       36.737        VER      MEDIUM  #3860C6
# 22        OCO        SOFT       36.950        PIA        SOFT  #FF8000
# 29        SAI        SOFT       42.484        SAI        SOFT  #64C4FF
# 25        LEC      MEDIUM       37.204        LEC      MEDIUM  #E80020
# 24        LEC      MEDIUM       37.191        LEC      MEDIUM  #E80020
# 2         PIA      MEDIUM       36.888        PIA      MEDIUM  #FF8000
# 0         PIA      MEDIUM       37.203        PIA      MEDIUM  #FF8000
# 1         RUS      MEDIUM       37.005        VER      MEDIUM  #3860C6
# 28        HAD        SOFT       44.633        ANT      MEDIUM  #6692FF
# 27        SAI        SOFT       48.421        LEC      MEDIUM  #64C4FF

# %%
LapTime_fp1_ordered.sort_values(by=['Time S3 (s)'])
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 17  Las Vegas Grand Prix  2025         19  00:01:35.071000       95.071
# 19  Las Vegas Grand Prix  2025         21  00:01:34.802000       94.802
# 14  Las Vegas Grand Prix  2025         16  00:01:34.968000       94.968
# 12  Las Vegas Grand Prix  2025         14  00:01:35.109000       95.109
# 20  Las Vegas Grand Prix  2025         22  00:01:35.450000       95.450
# 18  Las Vegas Grand Prix  2025         20  00:01:35.460000       95.460
# 15  Las Vegas Grand Prix  2025         17  00:01:35.121000       95.121
# 26  Las Vegas Grand Prix  2025         28  00:01:35.299000       95.299
# 13  Las Vegas Grand Prix  2025         15  00:01:35.281000       95.281
# 23  Las Vegas Grand Prix  2025         25  00:01:35.179000       95.179
# 11  Las Vegas Grand Prix  2025         13  00:01:35.699000       95.699
# 7   Las Vegas Grand Prix  2025          9  00:01:35.776000       95.776
# 21  Las Vegas Grand Prix  2025         23  00:01:35.117000       95.117
# 6   Las Vegas Grand Prix  2025          8  00:01:36.250000       96.250
# 9   Las Vegas Grand Prix  2025         11  00:01:35.954000       95.954
# 16  Las Vegas Grand Prix  2025         18  00:01:35.568000       95.568
# 5   Las Vegas Grand Prix  2025          7  00:01:36.043000       96.043
# 10  Las Vegas Grand Prix  2025         12  00:01:35.561000       95.561
# 8   Las Vegas Grand Prix  2025         10  00:01:36.083000       96.083
# 4   Las Vegas Grand Prix  2025          6  00:01:36.758000       96.758
# 3   Las Vegas Grand Prix  2025          5  00:01:36.493000       96.493
# 2   Las Vegas Grand Prix  2025          4  00:01:37.685000       97.685
# 22  Las Vegas Grand Prix  2025         24  00:01:37.886000       97.886
# 1   Las Vegas Grand Prix  2025          3  00:01:38.011000       98.011
# 24  Las Vegas Grand Prix  2025         26  00:01:37.732000       97.732
# 0   Las Vegas Grand Prix  2025          2  00:01:38.686000       98.686
# 25  Las Vegas Grand Prix  2025         27  00:01:38.020000       98.020
# 29  Las Vegas Grand Prix  2025         31  00:02:10.312000      130.312
# 28  Las Vegas Grand Prix  2025         30  00:01:50.150000      110.150
# 27  Las Vegas Grand Prix  2025         29  00:01:53.657000      113.657
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 17         TSU         SOFT       26.704        HAM        SOFT       31.748
# 19         LEC         SOFT       26.748        ALB        SOFT       31.724
# 14         ALB         SOFT       26.711        HAM        SOFT       31.761
# 12         VER         SOFT       26.705        VER        SOFT       32.068
# 20         PIA         SOFT       26.927        PIA        SOFT       32.156
# 18         PIA         SOFT       26.729        HAM        SOFT       31.340
# 15         LEC         SOFT       26.770        LEC        SOFT       31.942
# 26         HAD         SOFT       26.859        HAD        SOFT       31.493
# 13         LEC         SOFT       26.747        HAM        SOFT       31.858
# 23         SAI         SOFT       26.928        SAI        SOFT       31.816
# 11         RUS         SOFT       27.048        RUS        SOFT       31.833
# 7          VER       MEDIUM       27.149        VER      MEDIUM       31.996
# 21         TSU         SOFT       26.707        TSU        SOFT       31.860
# 6          PIA       MEDIUM       27.335        PIA      MEDIUM       31.718
# 9          LEC       MEDIUM       26.988        LEC      MEDIUM       32.098
# 16         ANT         SOFT       26.828        HAM        SOFT       31.886
# 5          VER       MEDIUM       27.058        VER      MEDIUM       32.297
# 10         HAM         SOFT       26.912        HAM        SOFT       31.670
# 8          RUS       MEDIUM       27.211        SAI      MEDIUM       31.684
# 4          NOR       MEDIUM       27.325        ALO        SOFT       31.833
# 3          VER       MEDIUM       27.287        VER      MEDIUM       32.383
# 2          PIA       MEDIUM       27.903        PIA      MEDIUM       32.894
# 22         PIA         SOFT       27.615        PIA        SOFT       32.562
# 1          VER       MEDIUM       27.912        NOR      MEDIUM       33.061
# 24         LEC       MEDIUM       27.814        LEC      MEDIUM       32.727
# 0          PIA       MEDIUM       28.475        PIA      MEDIUM       33.008
# 25         LEC       MEDIUM       26.793        SAI        SOFT       32.726
# 29         SAI         SOFT       54.743        SAI        SOFT       32.567
# 28         HAD         SOFT       31.815        HAD        SOFT       33.145
# 27         SAI         SOFT       26.956        SAI        SOFT       34.259
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 17        LEC        SOFT       36.256        TSU        SOFT  #3860C6
# 19        LEC        SOFT       36.287        LEC        SOFT  #E80020
# 14        ALB        SOFT       36.295        ALB        SOFT  #64C4FF
# 12        VER        SOFT       36.336        VER        SOFT  #3860C6
# 20        PIA        SOFT       36.367        PIA        SOFT  #FF8000
# 18        ANT        SOFT       36.395        PIA        SOFT  #FF8000
# 15        LEC        SOFT       36.409        LEC        SOFT  #E80020
# 26        HAD        SOFT       36.420        HAD        SOFT  #6692FF
# 13        LEC        SOFT       36.430        RUS        SOFT  #E80020
# 23        SAI        SOFT       36.435        SAI        SOFT  #64C4FF
# 11        GAS      MEDIUM       36.452        RUS        SOFT  #27F4D2
# 7         ALO        SOFT       36.466        VER      MEDIUM  #3860C6
# 21        LAW        SOFT       36.536        TSU        SOFT  #3860C6
# 6         STR      MEDIUM       36.581        RUS      MEDIUM  #FF8000
# 9         LEC      MEDIUM       36.594        ANT      MEDIUM  #E80020
# 16        ANT        SOFT       36.598        ANT        SOFT  #27F4D2
# 5         HAD      MEDIUM       36.605        VER      MEDIUM  #3860C6
# 10        SAI      MEDIUM       36.624        HAM        SOFT  #E80020
# 8         RUS      MEDIUM       36.645        RUS      MEDIUM  #27F4D2
# 4         NOR      MEDIUM       36.719        PIA      MEDIUM  #FF8000
# 3         ALB      MEDIUM       36.737        VER      MEDIUM  #3860C6
# 2         PIA      MEDIUM       36.888        PIA      MEDIUM  #FF8000
# 22        OCO        SOFT       36.950        PIA        SOFT  #FF8000
# 1         RUS      MEDIUM       37.005        VER      MEDIUM  #3860C6
# 24        LEC      MEDIUM       37.191        LEC      MEDIUM  #E80020
# 0         PIA      MEDIUM       37.203        PIA      MEDIUM  #FF8000
# 25        LEC      MEDIUM       37.204        LEC      MEDIUM  #E80020
# 29        SAI        SOFT       42.484        SAI        SOFT  #64C4FF
# 28        HAD        SOFT       44.633        ANT      MEDIUM  #6692FF
# 27        SAI        SOFT       48.421        LEC      MEDIUM  #64C4FF

# %%
import plotly.graph_objects as go

fig_fp1 = go.Figure(go.Table
 (header={"values": LapTime_fp1_ordered.columns},
  cells=dict(
    values=LapTime_fp1_ordered.T.values,
    fill_color=[LapTime_fp1_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp1.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp1_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp1_ordered.loc[LapTime_fp1_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp1_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp1.update_layout(
    title="FP1 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp1.show()

# %%
save_year=2025

# %%
fig_fp1.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP1/{}/{} {} FP1 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year,year,gp),full_html=False, include_plotlyjs='cdn')

# %%
# FP2

# %%
df_bq_fp2=df_bq2_fp2[(df_bq2_fp2["GP"]==race)&(df_bq2_fp2["Year"]==2025)]
GP_fp2=df_bq_fp2
GP_fp2["LapNumber"]=GP_fp2["LapNumber"].astype(int)
GP_fp2=GP_fp2.sort_values(['Driver','LapNumber'])
GP_fp2["DriverNumber"]=GP_fp2["DriverNumber"].astype(int)
year=GP_fp2['Year'].iloc[0]
gp=GP_fp2['GP'].iloc[0]
GP_fp2.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_37770/2277067741.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Time Driver  DriverNumber                 LapTime  \
# 111  0 days 00:23:16.295000    ALB            23                     NaT
# 112  0 days 00:25:07.751000    ALB            23  0 days 00:01:51.456000
# 113  0 days 00:26:44.808000    ALB            23  0 days 00:01:37.057000
# 114  0 days 00:28:44.293000    ALB            23  0 days 00:01:59.485000
# 115  0 days 00:30:19.722000    ALB            23  0 days 00:01:35.429000
#
#      LapNumber  Stint              PitOutTime PitInTime  \
# 111          1    1.0  0 days 00:21:28.222000       NaT
# 112          2    1.0                     NaT       NaT
# 113          3    1.0                     NaT       NaT
# 114          4    1.0                     NaT       NaT
# 115          5    1.0                     NaT       NaT
#
#                 Sector1Time             Sector2Time             Sector3Time  \
# 111                     NaT  0 days 00:00:39.510000  0 days 00:00:40.588000
# 112  0 days 00:00:29.988000  0 days 00:00:36.684000  0 days 00:00:44.784000
# 113  0 days 00:00:27.331000  0 days 00:00:32.826000  0 days 00:00:36.900000
# 114  0 days 00:00:39.456000  0 days 00:00:41.989000  0 days 00:00:38.040000
# 115  0 days 00:00:27.022000  0 days 00:00:32.027000  0 days 00:00:36.380000
#
#          Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 111                     NaT  0 days 00:22:35.961000  0 days 00:23:16.478000
# 112  0 days 00:23:46.283000  0 days 00:24:22.967000  0 days 00:25:07.751000
# 113  0 days 00:25:35.082000  0 days 00:26:07.908000  0 days 00:26:44.808000
# 114  0 days 00:27:24.264000  0 days 00:28:06.253000  0 days 00:28:44.293000
# 115  0 days 00:29:11.315000  0 days 00:29:43.342000  0 days 00:30:19.722000
#
#      SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest Compound  TyreLife  \
# 111    163.0    186.0    305.0    281.0          False   MEDIUM       1.0
# 112    166.0    200.0    314.0    227.0           True   MEDIUM       2.0
# 113    186.0    207.0    320.0    317.0           True   MEDIUM       3.0
# 114    115.0    193.0    320.0    306.0          False   MEDIUM       4.0
# 115    186.0    213.0    320.0    339.0           True   MEDIUM       5.0
#
#     FreshTyre      Team            LapStartTime             LapStartDate  \
# 111      True  Williams  0 days 00:21:28.222000  2025-11-21 04:07:34.733
# 112      True  Williams  0 days 00:23:16.295000  2025-11-21 04:09:22.806
# 113      True  Williams  0 days 00:25:07.751000  2025-11-21 04:11:14.262
# 114      True  Williams  0 days 00:26:44.808000  2025-11-21 04:12:51.319
# 115      True  Williams  0 days 00:28:44.293000  2025-11-21 04:14:50.804
#
#     TrackStatus  Position  Deleted DeletedReason  FastF1Generated IsAccurate  \
# 111           1       NaN    False                          False      False
# 112           1       NaN    False                          False       True
# 113           1       NaN    False                          False       True
# 114           1       NaN    False                          False       True
# 115          12       NaN    False                          False       True
#
#      Year                    GP
# 111  2025  Las Vegas Grand Prix
# 112  2025  Las Vegas Grand Prix
# 113  2025  Las Vegas Grand Prix
# 114  2025  Las Vegas Grand Prix
# 115  2025  Las Vegas Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp2['LapTime_TD']= pd.to_timedelta(GP_fp2["LapTime"])
GP_fp2["LapTime"]=GP_fp2['LapTime'].str.split('days ').str[1]
GP_fp2.loc[:, "LapTime (s)"] = GP_fp2["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp2['s1_TD']= pd.to_timedelta(GP_fp2["Sector1Time"])
GP_fp2['s2_TD']= pd.to_timedelta(GP_fp2["Sector2Time"])
GP_fp2['s3_TD']= pd.to_timedelta(GP_fp2["Sector3Time"])

GP_fp2.loc[:, "Time S1 (s)"] = GP_fp2["s1_TD"].dt.total_seconds()
GP_fp2.loc[:, "Time S2 (s)"] = GP_fp2["s2_TD"].dt.total_seconds()
GP_fp2.loc[:, "Time S3 (s)"] = GP_fp2["s3_TD"].dt.total_seconds()

# %%
GP_fp2_Rk=GP_fp2[GP_fp2["LapTime"]!="NaT"]
GP_fp2_Rk["LAP_RK"] = GP_fp2_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S1_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S2_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S3_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["Race_RK"] = GP_fp2_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp2_Sectors=GP_fp2_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp2_Sectors=GP_fp2_Sectors.fillna(0)
GP_fp2_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#     Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s) LapTime  \
# 111    ALB          1          0.0       39.510       40.588       0
# 51     ALO          1          0.0       35.987       39.360       0
# 34     ANT          1          0.0       40.361       42.554       0
# 297    BEA          1          0.0       39.508       41.523       0
# 221    BOR          1          0.0       41.410       40.265       0
#
#      LapTime (s) Compound  Year                    GP  LAP_RK  S1_RK  S2_RK  \
# 111          0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0   14.0
# 51           0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0    2.0
# 34           0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0   15.0
# 297          0.0   MEDIUM  2025  Las Vegas Grand Prix     0.0    0.0   13.0
# 221          0.0     HARD  2025  Las Vegas Grand Prix     0.0    0.0   17.0
#
#      S3_RK
# 111   10.0
# 51     2.0
# 34    16.0
# 297   13.0
# 221    9.0

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp2=GP_fp2_Sectors[GP_fp2_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp2.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp2.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp2.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp2.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp2=Fastest_Lap_fp2.merge(Fastest_sector1_fp2,on=['LapNumber']).merge(Fastest_sector2_fp2,on=['LapNumber']).merge(Fastest_sector3_fp2,on=['LapNumber'])
Fast_Laps_fp2=Fast_Laps_fp2[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp2=Fast_Laps_fp2.reset_index(drop=True)
Fast_Laps_fp2.head()
# Out:
#                      GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Las Vegas Grand Prix  2025          2  00:01:36.288000       96.288
# 1  Las Vegas Grand Prix  2025          3  00:01:34.713000       94.713
# 2  Las Vegas Grand Prix  2025          4  00:01:34.740000       94.740
# 3  Las Vegas Grand Prix  2025          5  00:01:33.943000       93.943
# 4  Las Vegas Grand Prix  2025          6  00:01:34.493000       94.493
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         PIA       MEDIUM       27.513        NOR      MEDIUM       32.239
# 1         NOR       MEDIUM       26.714        NOR      MEDIUM       31.632
# 2         PIA       MEDIUM       26.869        ALO      MEDIUM       31.699
# 3         NOR       MEDIUM       26.527        NOR      MEDIUM       31.470
# 4         PIA       MEDIUM       26.757        PIA      MEDIUM       31.659
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        NOR      MEDIUM       36.123        PIA      MEDIUM
# 1        NOR      MEDIUM       36.367        NOR      MEDIUM
# 2        PIA      MEDIUM       36.095        PIA      MEDIUM
# 3        NOR      MEDIUM       35.946        NOR      MEDIUM
# 4        PIA      MEDIUM       36.077        PIA      MEDIUM

# %%
Fast_Laps_fp2['color'] = Fast_Laps_fp2['Fastest Lap'].apply(driver_color)
Fast_Laps_fp2.head()
# Out:
#                      GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Las Vegas Grand Prix  2025          2  00:01:36.288000       96.288
# 1  Las Vegas Grand Prix  2025          3  00:01:34.713000       94.713
# 2  Las Vegas Grand Prix  2025          4  00:01:34.740000       94.740
# 3  Las Vegas Grand Prix  2025          5  00:01:33.943000       93.943
# 4  Las Vegas Grand Prix  2025          6  00:01:34.493000       94.493
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         PIA       MEDIUM       27.513        NOR      MEDIUM       32.239
# 1         NOR       MEDIUM       26.714        NOR      MEDIUM       31.632
# 2         PIA       MEDIUM       26.869        ALO      MEDIUM       31.699
# 3         NOR       MEDIUM       26.527        NOR      MEDIUM       31.470
# 4         PIA       MEDIUM       26.757        PIA      MEDIUM       31.659
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        NOR      MEDIUM       36.123        PIA      MEDIUM  #FF8000
# 1        NOR      MEDIUM       36.367        NOR      MEDIUM  #FF8000
# 2        PIA      MEDIUM       36.095        PIA      MEDIUM  #FF8000
# 3        NOR      MEDIUM       35.946        NOR      MEDIUM  #FF8000
# 4        PIA      MEDIUM       36.077        PIA      MEDIUM  #FF8000

# %%
LapTime_fp2_ordered=Fast_Laps_fp2.sort_values(by=['LapTime (s)'])
LapTime_fp2_ordered.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 8   Las Vegas Grand Prix  2025         10  00:01:33.602000       93.602
# 13  Las Vegas Grand Prix  2025         15  00:01:33.631000       93.631
# 12  Las Vegas Grand Prix  2025         14  00:01:33.815000       93.815
# 9   Las Vegas Grand Prix  2025         11  00:01:33.879000       93.879
# 11  Las Vegas Grand Prix  2025         13  00:01:33.893000       93.893
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 8          NOR         SOFT       26.332        NOR        SOFT       31.225
# 13         ANT         SOFT       26.273        HAM        SOFT       31.298
# 12         LEC         SOFT       26.390        TSU        SOFT       31.431
# 9          HUL         SOFT       26.468        RUS      MEDIUM       31.395
# 11         HAD         SOFT       26.340        SAI        SOFT       31.354
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 8         NOR        SOFT       35.911        LEC      MEDIUM  #FF8000
# 13        ANT        SOFT       35.908        ANT        SOFT  #27F4D2
# 12        LEC        SOFT       35.938        LEC        SOFT  #E80020
# 9         HUL        SOFT       35.817        HUL        SOFT  #52e252
# 11        HAD        SOFT       36.029        HAD        SOFT  #6692FF

# %%
import plotly.graph_objects as go
# colors = n_colors('rgb(255, 200, 200)', 'rgb(200, 0, 0)', 9, colortype='rgb')

fig_fp2 = go.Figure(go.Table
 (header={"values": LapTime_fp2_ordered.columns},
  cells=dict(
    values=LapTime_fp2_ordered.T.values,
    fill_color=[LapTime_fp2_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp2.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp2_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp2_ordered.loc[LapTime_fp2_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp2_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp2.update_layout(
    title="FP2 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp2.show()

# %%
fig_fp2.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP2/{}/{} {} FP2 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year,year,gp),full_html=False, include_plotlyjs='cdn')

# %%
# FP3

# %%
df_bq_fp3=df_bq2_fp3[(df_bq2_fp3["GP"]==race)&(df_bq2_fp3["Year"]==2025)]
GP_fp3=df_bq_fp3
GP_fp3["LapNumber"]=GP_fp3["LapNumber"].astype(int)
GP_fp3=GP_fp3.sort_values(['Driver','LapNumber'])
GP_fp3["DriverNumber"]=GP_fp3["DriverNumber"].astype(int)
year=GP_fp3['Year'].iloc[0]
gp=GP_fp3['GP'].iloc[0]
GP_fp3.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_37770/2774860751.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Time Driver  DriverNumber                 LapTime  \
# 138  0 days 00:24:31.383000    ALB            23                     NaT
# 139  0 days 00:26:39.718000    ALB            23  0 days 00:02:08.335000
# 140  0 days 00:28:26.191000    ALB            23  0 days 00:01:46.473000
# 141  0 days 00:30:43.449000    ALB            23  0 days 00:02:17.258000
# 142  0 days 00:32:28.477000    ALB            23  0 days 00:01:45.028000
#
#      LapNumber  Stint              PitOutTime PitInTime  \
# 138          1    1.0  0 days 00:22:44.841000       NaT
# 139          2    1.0                     NaT       NaT
# 140          3    1.0                     NaT       NaT
# 141          4    1.0                     NaT       NaT
# 142          5    1.0                     NaT       NaT
#
#                 Sector1Time             Sector2Time             Sector3Time  \
# 138                     NaT  0 days 00:00:37.842000  0 days 00:00:39.870000
# 139  0 days 00:00:51.299000  0 days 00:00:38.198000  0 days 00:00:38.838000
# 140  0 days 00:00:31.199000  0 days 00:00:36.403000  0 days 00:00:38.871000
# 141  0 days 00:00:47.842000  0 days 00:00:47.450000  0 days 00:00:41.966000
# 142  0 days 00:00:30.298000  0 days 00:00:36.241000  0 days 00:00:38.489000
#
#          Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 138                     NaT  0 days 00:23:51.753000  0 days 00:24:31.565000
# 139  0 days 00:25:22.682000  0 days 00:26:00.880000  0 days 00:26:39.718000
# 140  0 days 00:27:10.917000  0 days 00:27:47.320000  0 days 00:28:26.191000
# 141  0 days 00:29:14.033000  0 days 00:30:01.483000  0 days 00:30:43.449000
# 142  0 days 00:31:13.747000  0 days 00:31:49.988000  0 days 00:32:28.477000
#
#      SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest      Compound  \
# 138    157.0    193.0    284.0    268.0          False  INTERMEDIATE
# 139    140.0    197.0    307.0    282.0           True  INTERMEDIATE
# 140    154.0    195.0    306.0    311.0           True  INTERMEDIATE
# 141    130.0    147.0    312.0    254.0          False  INTERMEDIATE
# 142    160.0    197.0    309.0    316.0           True  INTERMEDIATE
#
#      TyreLife FreshTyre      Team            LapStartTime  \
# 138       1.0      True  Williams  0 days 00:22:44.841000
# 139       2.0      True  Williams  0 days 00:24:31.383000
# 140       3.0      True  Williams  0 days 00:26:39.718000
# 141       4.0      True  Williams  0 days 00:28:26.191000
# 142       5.0      True  Williams  0 days 00:30:43.449000
#
#                 LapStartDate TrackStatus  Position  Deleted DeletedReason  \
# 138  2025-11-22 00:38:26.168           1       NaN    False
# 139  2025-11-22 00:40:12.710          12       NaN    False
# 140  2025-11-22 00:42:21.045           1       NaN    False
# 141  2025-11-22 00:44:07.518           1       NaN    False
# 142  2025-11-22 00:46:24.776           1       NaN    False
#
#      FastF1Generated IsAccurate  Year                    GP
# 138            False      False  2025  Las Vegas Grand Prix
# 139            False       True  2025  Las Vegas Grand Prix
# 140            False       True  2025  Las Vegas Grand Prix
# 141            False       True  2025  Las Vegas Grand Prix
# 142            False       True  2025  Las Vegas Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp3['LapTime_TD']= pd.to_timedelta(GP_fp3["LapTime"])
GP_fp3["LapTime"]=GP_fp3['LapTime'].str.split('days ').str[1]
GP_fp3.loc[:, "LapTime (s)"] = GP_fp3["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp3['s1_TD']= pd.to_timedelta(GP_fp3["Sector1Time"])
GP_fp3['s2_TD']= pd.to_timedelta(GP_fp3["Sector2Time"])
GP_fp3['s3_TD']= pd.to_timedelta(GP_fp3["Sector3Time"])

GP_fp3.loc[:, "Time S1 (s)"] = GP_fp3["s1_TD"].dt.total_seconds()
GP_fp3.loc[:, "Time S2 (s)"] = GP_fp3["s2_TD"].dt.total_seconds()
GP_fp3.loc[:, "Time S3 (s)"] = GP_fp3["s3_TD"].dt.total_seconds()

# %%
GP_fp3_Rk=GP_fp3[GP_fp3["LapTime"]!="NaT"]
GP_fp3_Rk["LAP_RK"] = GP_fp3_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S1_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S2_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S3_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["Race_RK"] = GP_fp3_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp3_Sectors=GP_fp3_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp3_Sectors=GP_fp3_Sectors.fillna(0)
GP_fp3_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#     Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s) LapTime  \
# 138    ALB          1          0.0       37.842       39.870       0
# 64     ALO          1          0.0       42.620       42.905       0
# 41     ANT          1          0.0       42.808       46.175       0
# 388    BEA          1          0.0       45.356       51.917       0
# 283    BOR          1          0.0       47.627       45.328       0
#
#      LapTime (s)      Compound  Year                    GP  LAP_RK  S1_RK  \
# 138          0.0  INTERMEDIATE  2025  Las Vegas Grand Prix     0.0    0.0
# 64           0.0  INTERMEDIATE  2025  Las Vegas Grand Prix     0.0    0.0
# 41           0.0  INTERMEDIATE  2025  Las Vegas Grand Prix     0.0    0.0
# 388          0.0  INTERMEDIATE  2025  Las Vegas Grand Prix     0.0    0.0
# 283          0.0          SOFT  2025  Las Vegas Grand Prix     0.0    0.0
#
#      S2_RK  S3_RK
# 138    1.0    2.0
# 64    15.0   13.0
# 41    17.0   16.0
# 388   19.0   19.0
# 283   20.0   15.0

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp3=GP_fp3_Sectors[GP_fp3_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp3.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp3.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp3.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp3.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp3=Fastest_Lap_fp3.merge(Fastest_sector1_fp3,on=['LapNumber']).merge(Fastest_sector2_fp3,on=['LapNumber']).merge(Fastest_sector3_fp3,on=['LapNumber'])
Fast_Laps_fp3=Fast_Laps_fp3[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp3=Fast_Laps_fp3.reset_index(drop=True)
Fast_Laps_fp3.head()
# Out:
#                      GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Las Vegas Grand Prix  2025          2  00:01:43.254000      103.254
# 1  Las Vegas Grand Prix  2025          3  00:01:39.163000       99.163
# 2  Las Vegas Grand Prix  2025          4  00:01:37.437000       97.437
# 3  Las Vegas Grand Prix  2025          5  00:01:37.483000       97.483
# 4  Las Vegas Grand Prix  2025          6  00:01:36.650000       96.650
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1   S1 Compound  Time S2 (s)  \
# 0         GAS         SOFT       30.231        RUS  INTERMEDIATE       35.027
# 1         GAS         SOFT       28.619        GAS          SOFT       33.349
# 2         GAS         SOFT       27.832        GAS          SOFT       32.796
# 3         STR         SOFT       27.894        STR          SOFT       32.847
# 4         HUL         SOFT       27.492        GAS          SOFT       32.461
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        GAS        SOFT       37.671        GAS        SOFT
# 1        GAS        SOFT       37.133        HUL        SOFT
# 2        GAS        SOFT       36.773        HUL        SOFT
# 3        STR        SOFT       36.742        STR        SOFT
# 4        HUL        SOFT       36.226        HUL        SOFT

# %%
Fast_Laps_fp3['color'] = Fast_Laps_fp3['Fastest Lap'].apply(driver_color)
Fast_Laps_fp3.head()
# Out:
#                      GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Las Vegas Grand Prix  2025          2  00:01:43.254000      103.254
# 1  Las Vegas Grand Prix  2025          3  00:01:39.163000       99.163
# 2  Las Vegas Grand Prix  2025          4  00:01:37.437000       97.437
# 3  Las Vegas Grand Prix  2025          5  00:01:37.483000       97.483
# 4  Las Vegas Grand Prix  2025          6  00:01:36.650000       96.650
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1   S1 Compound  Time S2 (s)  \
# 0         GAS         SOFT       30.231        RUS  INTERMEDIATE       35.027
# 1         GAS         SOFT       28.619        GAS          SOFT       33.349
# 2         GAS         SOFT       27.832        GAS          SOFT       32.796
# 3         STR         SOFT       27.894        STR          SOFT       32.847
# 4         HUL         SOFT       27.492        GAS          SOFT       32.461
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        GAS        SOFT       37.671        GAS        SOFT  #0093cc
# 1        GAS        SOFT       37.133        HUL        SOFT  #0093cc
# 2        GAS        SOFT       36.773        HUL        SOFT  #0093cc
# 3        STR        SOFT       36.742        STR        SOFT  #229971
# 4        HUL        SOFT       36.226        HUL        SOFT  #52e252

# %%
LapTime_fp3_ordered=Fast_Laps_fp3.sort_values(by=['LapTime (s)'])
LapTime_fp3_ordered.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 17  Las Vegas Grand Prix  2025         19  00:01:34.054000       94.054
# 22  Las Vegas Grand Prix  2025         24  00:01:34.281000       94.281
# 15  Las Vegas Grand Prix  2025         17  00:01:34.875000       94.875
# 21  Las Vegas Grand Prix  2025         23  00:01:35.169000       95.169
# 23  Las Vegas Grand Prix  2025         25  00:01:35.269000       95.269
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 17         RUS         SOFT       26.816        RUS        SOFT       31.579
# 22         VER         SOFT       26.828        VER        SOFT       31.785
# 15         ALB         SOFT       26.954        ALB        SOFT       31.861
# 21         HAD         SOFT       27.065        HAD        SOFT       32.225
# 23         HAM         SOFT       27.308        HAM        SOFT       32.191
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 17        RUS        SOFT       35.659        RUS        SOFT  #27F4D2
# 22        VER        SOFT       35.668        VER        SOFT  #3860C6
# 15        RUS        SOFT       35.882        RUS        SOFT  #64C4FF
# 21        HAD        SOFT       35.879        HAD        SOFT  #6692FF
# 23        HAM        SOFT       35.770        HAM        SOFT  #E80020

# %%
import plotly.graph_objects as go
# colors = n_colors('rgb(255, 200, 200)', 'rgb(200, 0, 0)', 9, colortype='rgb')

fig_fp3 = go.Figure(go.Table
 (header={"values": LapTime_fp3_ordered.columns},
  cells=dict(
    values=LapTime_fp3_ordered.T.values,
    fill_color=[LapTime_fp3_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp3.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp3_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp3_ordered.loc[LapTime_fp3_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp3_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp3.update_layout(
    title="FP3 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp3.show()

# %%
fig_fp3.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP3/{}/{} {} FP3 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year,year,gp),full_html=False, include_plotlyjs='cdn')

# %%
#Multi GP Plot FP1

# %%
#2025
def driver_color(driver):
    #RED BULL
    if driver =="VER":
        return "#3860C6"
    elif driver =="TSU":
        return "#3860C6"       
    #MCLAREN
    elif driver =="NOR":
        return '#FF8000'
    elif driver =="PIA":
        return '#FF8000'
    #FERRARI
    elif driver =="LEC":
        return '#E80020'
    elif driver =="HAM":
        return '#E80020'
    elif driver =="ZHO":
        return '#E80020'    
    #MERCEDES
    elif driver =="ANT":
        return '#27F4D2'
    elif driver =="RUS":
        return '#27F4D2'
    elif driver =="BOT":
        return '#27F4D2'    
    #ASTON
    elif driver =="ALO":
        return '#229971'
    elif driver =="STR":
        return '#229971'
    #ALPINE
    elif driver =="GAS":
        return '#0093cc'
    elif driver =="DOO":
        return '#0093cc'
    elif driver =="COL":
        return '#0093cc'
    #HAAS
    elif driver =="BEA":
        return '#B6BABD'
    elif driver =="OCO":
        return '#B6BABD'
    #SAUBER
    elif driver =="HUL":
        return '#52e252'
    elif driver =="BOR":
        return '#52e252'
    #WILLIAMS
    elif driver =="ALB":
        return '#64C4FF'
    elif driver =="SAI":
        return '#64C4FF'
    #RACING BULLS   
    elif driver =="LAW":
        return '#6692FF'
    elif driver =="HAD":
        return '#6692FF'   
    else:
        return '#3860C6'

# %%
save_year_multi=2025

# %%
#2025
race_multi=["Japanese Grand Prix","Bahrain Grand Prix","Saudi Arabian Grand Prix","Miami Grand Prix","Emilia Romagna Grand Prix","Monaco Grand Prix","Spanish Grand Prix","Canadian Grand Prix","Austrian Grand Prix","British Grand Prix","Belgian Grand Prix","Hungarian Grand Prix","Dutch Grand Prix","Italian Grand Prix","Azerbaijan Grand Prix","Singapore Grand Prix","United States Grand Prix","Mexico City Grand Prix","São Paulo Grand Prix"]
#2024
# race_multi=["Bahrain Grand Prix", "Saudi Arabian Grand Prix", "Australian Grand Prix", "Japanese Grand Prix","Chinese Grand Prix","Miami Grand Prix","Emilia Romagna Grand Prix","Monaco Grand Prix","Canadian Grand Prix","Spanish Grand Prix","Austrian Grand Prix","British Grand Prix","Hungarian Grand Prix","Belgian Grand Prix"]
#2023
# race_multi=["Abu Dhabi Grand Prix","Australian Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Canadian Grand Prix","Dutch Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Japanese Grand Prix","Las Vegas Grand Prix","Mexico City Grand Prix","Miami Grand Prix","Monaco Grand Prix","Pre-Season Testing","Qatar Grand Prix","Saudi Arabian Grand Prix","Singapore Grand Prix","Spanish Grand Prix","São Paulo Grand Prix","United States Grand Prix"]
# 2022
# race_multi=["Abu Dhabi Grand Prix","Australian Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Canadian Grand Prix","Dutch Grand Prix","Emilia Romagna Grand Prix","French Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Japanese Grand Prix","Mexico City Grand Prix","Miami Grand Prix","Monaco Grand Prix","Saudi Arabian Grand Prix","Singapore Grand Prix","Spanish Grand Prix","São Paulo Grand Prix","United States Grand Prix"]
#2021
# race_multi=["Abu Dhabi Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Dutch Grand Prix","Emilia Romagna Grand Prix","French Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Mexico City Grand Prix","Monaco Grand Prix","Portuguese Grand Prix","Qatar Grand Prix","Russian Grand Prix","Saudi Arabian Grand Prix","Spanish Grand Prix","Styrian Grand Prix","São Paulo Grand Prix","Turkish Grand Prix","United States Grand Prix"]
#2020
# race_multi=["70th Anniversary Grand Prix","Abu Dhabi Grand Prix","Austrian Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Eifel Grand Prix","Emilia Romagna Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Portuguese Grand Prix","Russian Grand Prix","Sakhir Grand Prix","Spanish Grand Prix","Styrian Grand Prix","Turkish Grand Prix","Tuscan Grand Prix"]

year_multi=2025
for i in race_multi:
    df_bq_fp1=df_bq2_fp1[(df_bq2_fp1["GP"]==i)&(df_bq2_fp1["Year"]==year_multi)]
    GP_fp1=df_bq_fp1
    GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
    GP_fp1=GP_fp1.sort_values(['Driver','LapNumber'])
    GP_fp1["DriverNumber"]=GP_fp1["DriverNumber"].astype(int)
    # year=GP_fp1['Year'].iloc[0]
    # gp=GP_fp1['GP'].iloc[0]
    GP_fp1['LapTime_TD']= pd.to_timedelta(GP_fp1["LapTime"])
    GP_fp1["LapTime"]=GP_fp1['LapTime'].str.split('days ').str[1]
    GP_fp1.loc[:, "LapTime (s)"] = GP_fp1["LapTime_TD"].dt.total_seconds()
    GP_fp1['s1_TD']= pd.to_timedelta(GP_fp1["Sector1Time"])
    GP_fp1['s2_TD']= pd.to_timedelta(GP_fp1["Sector2Time"])
    GP_fp1['s3_TD']= pd.to_timedelta(GP_fp1["Sector3Time"])

    GP_fp1.loc[:, "Time S1 (s)"] = GP_fp1["s1_TD"].dt.total_seconds()
    GP_fp1.loc[:, "Time S2 (s)"] = GP_fp1["s2_TD"].dt.total_seconds()
    GP_fp1.loc[:, "Time S3 (s)"] = GP_fp1["s3_TD"].dt.total_seconds()
    GP_fp1_Rk=GP_fp1[GP_fp1["LapTime"]!="NaT"]
    GP_fp1_Rk["LAP_RK"] = GP_fp1_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S1_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S2_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S3_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["Race_RK"] = GP_fp1_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)
    GP_fp1_Sectors=GP_fp1_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
    GP_fp1_Sectors=GP_fp1_Sectors.fillna(0)
    Fastest_Lap_fp1=GP_fp1_Sectors[GP_fp1_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_Lap_fp1.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
    Fastest_sector1_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector1_fp1.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
    Fastest_sector2_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector2_fp1.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
    Fastest_sector3_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector3_fp1.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
    Fast_Laps_fp1=Fastest_Lap_fp1.merge(Fastest_sector1_fp1,on=['LapNumber']).merge(Fastest_sector2_fp1,on=['LapNumber']).merge(Fastest_sector3_fp1,on=['LapNumber'])
    Fast_Laps_fp1=Fast_Laps_fp1[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
    Fast_Laps_fp1=Fast_Laps_fp1.reset_index(drop=True)
    Fast_Laps_fp1['color'] = Fast_Laps_fp1['Fastest Lap'].apply(driver_color)
    LapTime_fp1_ordered=Fast_Laps_fp1.sort_values(by=['LapTime (s)'])
    fig_fp1 = go.Figure(go.Table
    (header={"values": LapTime_fp1_ordered.columns},
    cells=dict(
        values=LapTime_fp1_ordered.T.values,
        fill_color=[LapTime_fp1_ordered.color],
        align='center', font=dict(color='white', size=11)
        ))
    )
    fig_fp1.update_layout(
        title="FP1 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi, i),
            title_x=0.5,
        yaxis = dict(tickfont = dict(size=15)),
        xaxis = dict(tickfont = dict(size=15)),
        font=dict(
            family="PT Sans Narrow",
            size=13,
            color="Black"
        ),
        height=780,
        width=1200,
        title_font_family="PT Sans Narrow",
        margin=dict(l=5, r=5, t=35, b=5),
    )
    fig_fp1.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP1/{}/{} {} FP1 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year_multi,year_multi, i),include_plotlyjs='cdn')
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/807502903.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Multi GP Plot FP2

# %%
for i in race_multi:
    try:
        df_bq_fp2=df_bq2_fp2[(df_bq2_fp2["GP"]==i)&(df_bq2_fp2["Year"]==year_multi)]
        GP_fp2=df_bq_fp2
        GP_fp2["LapNumber"]=GP_fp2["LapNumber"].astype(int)
        GP_fp2=GP_fp2.sort_values(['Driver','LapNumber'])
        GP_fp2["DriverNumber"]=GP_fp2["DriverNumber"].astype(int)
        year=GP_fp2['Year'].iloc[0]
        gp=GP_fp2['GP'].iloc[0]
        #Convert LapTime to Time Delta for plotting on Y Axis
        GP_fp2['LapTime_TD']= pd.to_timedelta(GP_fp2["LapTime"])
        GP_fp2["LapTime"]=GP_fp2['LapTime'].str.split('days ').str[1]
        GP_fp2.loc[:, "LapTime (s)"] = GP_fp2["LapTime_TD"].dt.total_seconds()
        # Fastest Driver in each lap
        GP_fp2['s1_TD']= pd.to_timedelta(GP_fp2["Sector1Time"])
        GP_fp2['s2_TD']= pd.to_timedelta(GP_fp2["Sector2Time"])
        GP_fp2['s3_TD']= pd.to_timedelta(GP_fp2["Sector3Time"])

        GP_fp2.loc[:, "Time S1 (s)"] = GP_fp2["s1_TD"].dt.total_seconds()
        GP_fp2.loc[:, "Time S2 (s)"] = GP_fp2["s2_TD"].dt.total_seconds()
        GP_fp2.loc[:, "Time S3 (s)"] = GP_fp2["s3_TD"].dt.total_seconds()
        GP_fp2_Rk=GP_fp2[GP_fp2["LapTime"]!="NaT"]
        GP_fp2_Rk["LAP_RK"] = GP_fp2_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S1_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S2_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S3_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["Race_RK"] = GP_fp2_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

        GP_fp2_Sectors=GP_fp2_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
        GP_fp2_Sectors=GP_fp2_Sectors.fillna(0)
        GP_fp2_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
        #get a combined view for fastest drivers in the entire lap, S1, S2, and S3
        Fastest_Lap_fp2=GP_fp2_Sectors[GP_fp2_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_Lap_fp2.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
        Fastest_sector1_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector1_fp2.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
        Fastest_sector2_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector2_fp2.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
        Fastest_sector3_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector3_fp2.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
        Fast_Laps_fp2=Fastest_Lap_fp2.merge(Fastest_sector1_fp2,on=['LapNumber']).merge(Fastest_sector2_fp2,on=['LapNumber']).merge(Fastest_sector3_fp2,on=['LapNumber'])
        Fast_Laps_fp2=Fast_Laps_fp2[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
        Fast_Laps_fp2=Fast_Laps_fp2.reset_index(drop=True)
        Fast_Laps_fp2['color'] = Fast_Laps_fp2['Fastest Lap'].apply(driver_color)
        LapTime_fp2_ordered=Fast_Laps_fp2.sort_values(by=['LapTime (s)'])
        fig_fp2 = go.Figure(go.Table
        (header={"values": LapTime_fp2_ordered.columns},
        cells=dict(
            values=LapTime_fp2_ordered.T.values,
            fill_color=[LapTime_fp2_ordered.color],
            align='center', font=dict(color='white', size=11)
            ))
        )
        fig_fp2.update_layout(
            title="FP2 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi,i),
                title_x=0.5,
            yaxis = dict(tickfont = dict(size=15)),
            xaxis = dict(tickfont = dict(size=15)),
            font=dict(
                family="PT Sans Narrow",
                size=13,
                color="Black"
            ),
            height=780,
            width=1200,
            title_font_family="PT Sans Narrow",
            margin=dict(l=5, r=5, t=35, b=5),
        )
        fig_fp2.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP2/{}/{} {} FP2 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year_multi,year_multi,i),include_plotlyjs='cdn')
    except:
        continue
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/3494421142.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Multi GP Plot FP3

# %%
for i in race_multi:
    try:
        df_bq_fp3=df_bq2_fp3[(df_bq2_fp3["GP"]==i)&(df_bq2_fp3["Year"]==year_multi)]
        GP_fp3=df_bq_fp3
        GP_fp3["LapNumber"]=GP_fp3["LapNumber"].astype(int)
        GP_fp3=GP_fp3.sort_values(['Driver','LapNumber'])
        GP_fp3["DriverNumber"]=GP_fp3["DriverNumber"].astype(int)
        year=GP_fp3['Year'].iloc[0]
        gp=GP_fp3['GP'].iloc[0]
        #Convert LapTime to Time Delta for plotting on Y Axis
        GP_fp3['LapTime_TD']= pd.to_timedelta(GP_fp3["LapTime"])
        GP_fp3["LapTime"]=GP_fp3['LapTime'].str.split('days ').str[1]
        GP_fp3.loc[:, "LapTime (s)"] = GP_fp3["LapTime_TD"].dt.total_seconds()
        # Fastest Driver in each lap
        GP_fp3['s1_TD']= pd.to_timedelta(GP_fp3["Sector1Time"])
        GP_fp3['s2_TD']= pd.to_timedelta(GP_fp3["Sector2Time"])
        GP_fp3['s3_TD']= pd.to_timedelta(GP_fp3["Sector3Time"])

        GP_fp3.loc[:, "Time S1 (s)"] = GP_fp3["s1_TD"].dt.total_seconds()
        GP_fp3.loc[:, "Time S2 (s)"] = GP_fp3["s2_TD"].dt.total_seconds()
        GP_fp3.loc[:, "Time S3 (s)"] = GP_fp3["s3_TD"].dt.total_seconds()
        GP_fp3_Rk=GP_fp3[GP_fp3["LapTime"]!="NaT"]
        GP_fp3_Rk["LAP_RK"] = GP_fp3_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S1_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S2_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S3_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["Race_RK"] = GP_fp3_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

        GP_fp3_Sectors=GP_fp3_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
        GP_fp3_Sectors=GP_fp3_Sectors.fillna(0)
        #get a combined view for fastest drivers in the entire lap, S1, S2, and S3
        Fastest_Lap_fp3=GP_fp3_Sectors[GP_fp3_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_Lap_fp3.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
        Fastest_sector1_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector1_fp3.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
        Fastest_sector2_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector2_fp3.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
        Fastest_sector3_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector3_fp3.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
        Fast_Laps_fp3=Fastest_Lap_fp3.merge(Fastest_sector1_fp3,on=['LapNumber']).merge(Fastest_sector2_fp3,on=['LapNumber']).merge(Fastest_sector3_fp3,on=['LapNumber'])
        Fast_Laps_fp3=Fast_Laps_fp3[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
        Fast_Laps_fp3=Fast_Laps_fp3.reset_index(drop=True)
        Fast_Laps_fp3['color'] = Fast_Laps_fp3['Fastest Lap'].apply(driver_color)
        LapTime_fp3_ordered=Fast_Laps_fp3.sort_values(by=['LapTime (s)'])

        fig_fp3 = go.Figure(go.Table
        (header={"values": LapTime_fp3_ordered.columns},
        cells=dict(
            values=LapTime_fp3_ordered.T.values,
            fill_color=[LapTime_fp3_ordered.color],
            align='center', font=dict(color='white', size=11)
            ))
        )
        fig_fp3.update_layout(
            title="FP3 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi, i),
                title_x=0.5,
            yaxis = dict(tickfont = dict(size=15)),
            xaxis = dict(tickfont = dict(size=15)),
            font=dict(
                family="PT Sans Narrow",
                size=13,
                color="Black"
            ),
            height=780,
            width=1200,
            title_font_family="PT Sans Narrow",
            margin=dict(l=5, r=5, t=35, b=5),
        )
        fig_fp3.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP3/{}/{} {} FP3 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year_multi, year_multi, i),include_plotlyjs='cdn')
    except:
        continue
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_57932/659399502.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
