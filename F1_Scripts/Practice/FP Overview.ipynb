# %%
import pandas as pd
import numpy as np
import pandas_gbq
import time
import itertools
import datetime
import matplotlib.pyplot as plt
from datetime import *
from datetime import datetime, timedelta, date
from pathlib import Path
from zipfile import ZipFile
import urllib
from PIL import Image
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Standard plotly imports
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import requests
import json
import plotly.graph_objects as go
project_id = "perceptive-ivy-290216"

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp1_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp1 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp2_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp2 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp3_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp3 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
race="Australian Grand Prix"

# %%
# FP1

# %%
df_bq_fp1=df_bq2_fp1[(df_bq2_fp1["GP"]==race)&(df_bq2_fp1["Year"]==2025)]
GP_fp1=df_bq_fp1
GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
GP_fp1=GP_fp1.sort_values(['Driver','LapNumber'])
GP_fp1["DriverNumber"]=GP_fp1["DriverNumber"].astype(int)
year=GP_fp1['Year'].iloc[0]
gp=GP_fp1['GP'].iloc[0]
GP_fp1.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_7879/1916111373.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
#                          Time Driver  DriverNumber                 LapTime  \
# 24231  0 days 00:23:30.545000    ALB            23  0 days 00:01:40.296000
# 24232  0 days 00:24:52.158000    ALB            23  0 days 00:01:21.613000
# 24233  0 days 00:41:02.988000    ALB            23                     NaT
# 24234  0 days 00:42:45.857000    ALB            23  0 days 00:01:42.869000
# 24235  0 days 00:44:06.327000    ALB            23  0 days 00:01:20.470000
#
#        LapNumber  Stint              PitOutTime               PitInTime  \
# 24231          1    1.0  0 days 00:21:52.349000                     NaT
# 24232          2    1.0                     NaT                     NaT
# 24233          3    1.0                     NaT  0 days 00:26:44.665000
# 24234          4    2.0  0 days 00:41:05.053000                     NaT
# 24235          5    2.0                     NaT                     NaT
#
#                   Sector1Time             Sector2Time             Sector3Time  \
# 24231  0 days 00:00:40.239000  0 days 00:00:19.709000  0 days 00:00:40.348000
# 24232  0 days 00:00:28.248000  0 days 00:00:18.363000  0 days 00:00:35.002000
# 24233  0 days 00:00:46.898000  0 days 00:00:22.499000                     NaT
# 24234  0 days 00:00:40.477000  0 days 00:00:19.259000  0 days 00:00:43.133000
# 24235  0 days 00:00:27.835000  0 days 00:00:18.142000  0 days 00:00:34.493000
#
#            Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 24231  0 days 00:22:30.709000  0 days 00:22:50.344000  0 days 00:23:30.632000
# 24232  0 days 00:23:58.793000  0 days 00:24:17.156000  0 days 00:24:52.158000
# 24233  0 days 00:25:39.265000  0 days 00:26:01.675000                     NaT
# 24234  0 days 00:41:43.465000  0 days 00:42:02.724000  0 days 00:42:45.857000
# 24235  0 days 00:43:13.692000  0 days 00:43:31.834000  0 days 00:44:06.327000
#
#        SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest Compound  TyreLife  \
# 24231    260.0    297.0    300.0    194.0          False   MEDIUM       1.0
# 24232    281.0    318.0    306.0    319.0           True   MEDIUM       2.0
# 24233    124.0    276.0      NaN    253.0          False   MEDIUM       3.0
# 24234    266.0    291.0    301.0     97.0          False   MEDIUM       4.0
# 24235    282.0    316.0    302.0    318.0           True   MEDIUM       5.0
#
#       FreshTyre      Team            LapStartTime             LapStartDate  \
# 24231      True  Williams  0 days 00:21:52.349000  2025-03-14 01:37:20.358
# 24232      True  Williams  0 days 00:23:30.545000  2025-03-14 01:38:58.554
# 24233      True  Williams  0 days 00:24:52.158000  2025-03-14 01:40:20.167
# 24234     False  Williams  0 days 00:41:05.053000  2025-03-14 01:56:33.062
# 24235     False  Williams  0 days 00:42:45.857000  2025-03-14 01:58:13.866
#
#       TrackStatus  Position  Deleted DeletedReason  FastF1Generated  \
# 24231           1       NaN    False                          False
# 24232           1       NaN    False                          False
# 24233          15       NaN    False                          False
# 24234           1       NaN    False                          False
# 24235          12       NaN    False                          False
#
#       IsAccurate  Year                     GP
# 24231      False  2025  Australian Grand Prix
# 24232       True  2025  Australian Grand Prix
# 24233      False  2025  Australian Grand Prix
# 24234      False  2025  Australian Grand Prix
# 24235       True  2025  Australian Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp1['LapTime_TD']= pd.to_timedelta(GP_fp1["LapTime"])
GP_fp1["LapTime"]=GP_fp1['LapTime'].str.split('days ').str[1]
GP_fp1.loc[:, "LapTime (s)"] = GP_fp1["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp1['s1_TD']= pd.to_timedelta(GP_fp1["Sector1Time"])
GP_fp1['s2_TD']= pd.to_timedelta(GP_fp1["Sector2Time"])
GP_fp1['s3_TD']= pd.to_timedelta(GP_fp1["Sector3Time"])

GP_fp1.loc[:, "Time S1 (s)"] = GP_fp1["s1_TD"].dt.total_seconds()
GP_fp1.loc[:, "Time S2 (s)"] = GP_fp1["s2_TD"].dt.total_seconds()
GP_fp1.loc[:, "Time S3 (s)"] = GP_fp1["s3_TD"].dt.total_seconds()

# %%
GP_fp1_Rk=GP_fp1[GP_fp1["LapTime"]!="NaT"]
GP_fp1_Rk["LAP_RK"] = GP_fp1_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S1_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S2_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S3_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["Race_RK"] = GP_fp1_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp1_Sectors=GP_fp1_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp1_Sectors=GP_fp1_Sectors.fillna(0)
GP_fp1_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#       Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s)  \
# 24249    HUL          1        0.000       21.765       59.197
# 24008    NOR          1        0.000       21.472       42.168
# 24350    RUS          1       38.811       19.386       38.636
# 24096    GAS          1       39.834       19.813       49.798
# 24231    ALB          1       40.239       19.709       40.348
#
#                LapTime  LapTime (s) Compound  Year                     GP  \
# 24249                0        0.000   MEDIUM  2025  Australian Grand Prix
# 24008                0        0.000   MEDIUM  2025  Australian Grand Prix
# 24350  00:01:36.833000       96.833   MEDIUM  2025  Australian Grand Prix
# 24096  00:01:49.445000      109.445   MEDIUM  2025  Australian Grand Prix
# 24231  00:01:40.296000      100.296   MEDIUM  2025  Australian Grand Prix
#
#        LAP_RK  S1_RK  S2_RK  S3_RK
# 24249     0.0    0.0   15.0   20.0
# 24008     0.0    0.0   12.0    4.0
# 24350     1.0    1.0    2.0    1.0
# 24096     5.0    2.0    5.0   14.0
# 24231     2.0    3.0    4.0    2.0

# %%
#2025
def driver_color(driver):
    #RED BULL
    if driver =="VER":
        return "#3860C6"
    elif driver =="LAW":
        return "#3860C6"       
    #MCLAREN
    elif driver =="NOR":
        return '#FF8000'
    elif driver =="PIA":
        return '#FF8000'
    #FERRARI
    elif driver =="LEC":
        return '#E80020'
    elif driver =="HAM":
        return '#E80020'
    elif driver =="ZHO":
        return '#E80020'    
    #MERCEDES
    elif driver =="ANT":
        return '#27F4D2'
    elif driver =="RUS":
        return '#27F4D2'
    elif driver =="BOT":
        return '#27F4D2'    
    #ASTON
    elif driver =="ALO":
        return '#229971'
    elif driver =="STR":
        return '#229971'
    #ALPINE
    elif driver =="GAS":
        return '#0093cc'
    elif driver =="DOO":
        return '#0093cc'
    elif driver =="COL":
        return '#0093cc'
    #HAAS
    elif driver =="BEA":
        return '#B6BABD'
    elif driver =="OCO":
        return '#B6BABD'
    #SAUBER
    elif driver =="HUL":
        return '#52e252'
    elif driver =="BOR":
        return '#52e252'
    #WILLIAMS
    elif driver =="ALB":
        return '#64C4FF'
    elif driver =="SAI":
        return '#64C4FF'
    #RACING BULLS   
    elif driver =="TSU":
        return '#6692FF'
    elif driver =="HAD":
        return '#6692FF'   
    else:
        return '#3860C6'

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp1=GP_fp1_Sectors[GP_fp1_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp1.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp1.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp1.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp1.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp1=Fastest_Lap_fp1.merge(Fastest_sector1_fp1,on=['LapNumber']).merge(Fastest_sector2_fp1,on=['LapNumber']).merge(Fastest_sector3_fp1,on=['LapNumber'])
Fast_Laps_fp1=Fast_Laps_fp1[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp1=Fast_Laps_fp1.reset_index(drop=True)
Fast_Laps_fp1.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Australian Grand Prix  2025          1  00:01:36.833000       96.833
# 1  Australian Grand Prix  2025          2  00:01:19.771000       79.771
# 2  Australian Grand Prix  2025          3  00:01:20.286000       80.286
# 3  Australian Grand Prix  2025          4  00:01:18.317000       78.317
# 4  Australian Grand Prix  2025          5  00:01:19.137000       79.137
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         RUS       MEDIUM       38.811        RUS      MEDIUM       19.264
# 1         VER       MEDIUM       27.888        LEC      MEDIUM       17.793
# 2         RUS       MEDIUM       27.844        RUS      MEDIUM       17.950
# 3         LEC       MEDIUM       27.191        ALO      MEDIUM       17.455
# 4         RUS       MEDIUM       27.428        RUS      MEDIUM       17.757
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        SAI      MEDIUM       38.636        RUS      MEDIUM
# 1        VER      MEDIUM       34.027        VER      MEDIUM
# 2        RUS      MEDIUM       34.492        RUS      MEDIUM
# 3        VER      MEDIUM       33.335        LEC      MEDIUM
# 4        RUS      MEDIUM       33.952        RUS      MEDIUM

# %%
Fast_Laps_fp1['color'] = Fast_Laps_fp1['Fastest Lap'].apply(driver_color)
Fast_Laps_fp1.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Australian Grand Prix  2025          1  00:01:36.833000       96.833
# 1  Australian Grand Prix  2025          2  00:01:19.771000       79.771
# 2  Australian Grand Prix  2025          3  00:01:20.286000       80.286
# 3  Australian Grand Prix  2025          4  00:01:18.317000       78.317
# 4  Australian Grand Prix  2025          5  00:01:19.137000       79.137
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         RUS       MEDIUM       38.811        RUS      MEDIUM       19.264
# 1         VER       MEDIUM       27.888        LEC      MEDIUM       17.793
# 2         RUS       MEDIUM       27.844        RUS      MEDIUM       17.950
# 3         LEC       MEDIUM       27.191        ALO      MEDIUM       17.455
# 4         RUS       MEDIUM       27.428        RUS      MEDIUM       17.757
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        SAI      MEDIUM       38.636        RUS      MEDIUM  #27F4D2
# 1        VER      MEDIUM       34.027        VER      MEDIUM  #3860C6
# 2        RUS      MEDIUM       34.492        RUS      MEDIUM  #27F4D2
# 3        VER      MEDIUM       33.335        LEC      MEDIUM  #E80020
# 4        RUS      MEDIUM       33.952        RUS      MEDIUM  #27F4D2

# %%
LapTime_fp1_ordered=Fast_Laps_fp1.sort_values(by=['LapTime (s)'])
LapTime_fp1_ordered.head()
# Out:
#                        GP  Year  LapNumber          LapTime  LapTime (s)  \
# 17  Australian Grand Prix  2025         18  00:01:17.252000       77.252
# 13  Australian Grand Prix  2025         14  00:01:17.401000       77.401
# 11  Australian Grand Prix  2025         12  00:01:17.461000       77.461
# 14  Australian Grand Prix  2025         15  00:01:17.518000       77.518
# 12  Australian Grand Prix  2025         13  00:01:17.670000       77.670
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 17         NOR         SOFT       26.955        STR        SOFT       17.386
# 13         SAI         SOFT       26.708        SAI        SOFT       17.585
# 11         LEC         SOFT       26.768        RUS        SOFT       17.565
# 14         NOR         SOFT       26.866        ALB        SOFT       17.553
# 12         PIA         SOFT       26.863        PIA        SOFT       17.534
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 17        NOR        SOFT       32.891        NOR        SOFT  #FF8000
# 13        SAI        SOFT       33.108        SAI        SOFT  #64C4FF
# 11        ALB        SOFT       32.978        LEC        SOFT  #E80020
# 14        ALB        SOFT       32.871        NOR        SOFT  #FF8000
# 12        PIA        SOFT       33.273        PIA        SOFT  #FF8000

# %%
import plotly.graph_objects as go

fig_fp1 = go.Figure(go.Table
 (header={"values": LapTime_fp1_ordered.columns},
  cells=dict(
    values=LapTime_fp1_ordered.T.values,
    fill_color=[LapTime_fp1_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp1.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp1_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp1_ordered.loc[LapTime_fp1_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp1_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp1.update_layout(
    title="FP1 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp1.show()

# %%
save_year=2025

# %%
fig_fp1.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP1/{}/{} {} FP1 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year,year,gp),full_html=False, include_plotlyjs='cdn')

# %%
# FP2

# %%
df_bq_fp2=df_bq2_fp2[(df_bq2_fp2["GP"]==race)&(df_bq2_fp2["Year"]==2025)]
GP_fp2=df_bq_fp2
GP_fp2["LapNumber"]=GP_fp2["LapNumber"].astype(int)
GP_fp2=GP_fp2.sort_values(['Driver','LapNumber'])
GP_fp2["DriverNumber"]=GP_fp2["DriverNumber"].astype(int)
year=GP_fp2['Year'].iloc[0]
gp=GP_fp2['GP'].iloc[0]
GP_fp2.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_73022/2277067741.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          Time Driver  DriverNumber                 LapTime  \
# 10753  0 days 00:21:05.266000    ALB            23  0 days 00:01:54.309000
# 10754  0 days 00:22:24.505000    ALB            23  0 days 00:01:19.239000
# 10755  0 days 00:24:27.534000    ALB            23  0 days 00:02:03.029000
# 10756  0 days 00:25:45.182000    ALB            23  0 days 00:01:17.648000
# 10757  0 days 00:27:57.255000    ALB            23  0 days 00:02:12.073000
#
#        LapNumber  Stint              PitOutTime PitInTime  \
# 10753          1    1.0  0 days 00:19:12.922000       NaT
# 10754          2    1.0                     NaT       NaT
# 10755          3    1.0                     NaT       NaT
# 10756          4    1.0                     NaT       NaT
# 10757          5    1.0                     NaT       NaT
#
#                   Sector1Time             Sector2Time             Sector3Time  \
# 10753  0 days 00:00:40.034000  0 days 00:00:19.262000  0 days 00:00:55.013000
# 10754  0 days 00:00:27.539000  0 days 00:00:17.954000  0 days 00:00:33.746000
# 10755  0 days 00:00:41.429000  0 days 00:00:32.258000  0 days 00:00:49.342000
# 10756  0 days 00:00:26.974000  0 days 00:00:17.524000  0 days 00:00:33.150000
# 10757  0 days 00:00:46.633000  0 days 00:00:30.085000  0 days 00:00:55.355000
#
#            Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 10753  0 days 00:19:51.166000  0 days 00:20:10.479000  0 days 00:21:05.381000
# 10754  0 days 00:21:32.805000  0 days 00:21:50.759000  0 days 00:22:24.505000
# 10755  0 days 00:23:05.934000  0 days 00:23:38.192000  0 days 00:24:27.534000
# 10756  0 days 00:24:54.508000  0 days 00:25:12.032000  0 days 00:25:45.182000
# 10757  0 days 00:26:31.815000  0 days 00:27:01.900000  0 days 00:27:57.255000
#
#        SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest Compound  TyreLife  \
# 10753    270.0    296.0    302.0    186.0          False   MEDIUM       1.0
# 10754    282.0    315.0    305.0    320.0           True   MEDIUM       2.0
# 10755    163.0    177.0    305.0    241.0          False   MEDIUM       3.0
# 10756    287.0    319.0    307.0    323.0           True   MEDIUM       4.0
# 10757    186.0    182.0    272.0    266.0          False   MEDIUM       5.0
#
#       FreshTyre      Team            LapStartTime             LapStartDate  \
# 10753      True  Williams  0 days 00:19:12.922000  2025-03-14 05:04:13.372
# 10754      True  Williams  0 days 00:21:05.266000  2025-03-14 05:06:05.716
# 10755      True  Williams  0 days 00:22:24.505000  2025-03-14 05:07:24.955
# 10756      True  Williams  0 days 00:24:27.534000  2025-03-14 05:09:27.984
# 10757      True  Williams  0 days 00:25:45.182000  2025-03-14 05:10:45.632
#
#       TrackStatus  Position  Deleted DeletedReason  FastF1Generated  \
# 10753           1       NaN    False                          False
# 10754           1       NaN    False                          False
# 10755           1       NaN    False                          False
# 10756           1       NaN    False                          False
# 10757           1       NaN    False                          False
#
#       IsAccurate  Year                     GP
# 10753      False  2025  Australian Grand Prix
# 10754       True  2025  Australian Grand Prix
# 10755       True  2025  Australian Grand Prix
# 10756       True  2025  Australian Grand Prix
# 10757       True  2025  Australian Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp2['LapTime_TD']= pd.to_timedelta(GP_fp2["LapTime"])
GP_fp2["LapTime"]=GP_fp2['LapTime'].str.split('days ').str[1]
GP_fp2.loc[:, "LapTime (s)"] = GP_fp2["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp2['s1_TD']= pd.to_timedelta(GP_fp2["Sector1Time"])
GP_fp2['s2_TD']= pd.to_timedelta(GP_fp2["Sector2Time"])
GP_fp2['s3_TD']= pd.to_timedelta(GP_fp2["Sector3Time"])

GP_fp2.loc[:, "Time S1 (s)"] = GP_fp2["s1_TD"].dt.total_seconds()
GP_fp2.loc[:, "Time S2 (s)"] = GP_fp2["s2_TD"].dt.total_seconds()
GP_fp2.loc[:, "Time S3 (s)"] = GP_fp2["s3_TD"].dt.total_seconds()

# %%
GP_fp2_Rk=GP_fp2[GP_fp2["LapTime"]!="NaT"]
GP_fp2_Rk["LAP_RK"] = GP_fp2_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S1_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S2_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S3_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["Race_RK"] = GP_fp2_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp2_Sectors=GP_fp2_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp2_Sectors=GP_fp2_Sectors.fillna(0)
GP_fp2_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#       Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s)  \
# 10606    ANT          1        0.000       21.174       49.540
# 10897    SAI          1       39.711       19.647       38.860
# 10753    ALB          1       40.034       19.262       55.013
# 10487    BOR          1       40.102       20.391       43.857
# 10576    GAS          1       40.370       19.329       42.532
#
#                LapTime  LapTime (s) Compound  Year                     GP  \
# 10606                0        0.000     HARD  2025  Australian Grand Prix
# 10897  00:01:38.218000       98.218   MEDIUM  2025  Australian Grand Prix
# 10753  00:01:54.309000      114.309   MEDIUM  2025  Australian Grand Prix
# 10487  00:01:44.350000      104.350   MEDIUM  2025  Australian Grand Prix
# 10576  00:01:42.231000      102.231   MEDIUM  2025  Australian Grand Prix
#
#        LAP_RK  S1_RK  S2_RK  S3_RK
# 10606     0.0    0.0   16.0   13.0
# 10897     1.0    1.0    8.0    1.0
# 10753     7.0    2.0    4.0   17.0
# 10487     3.0    3.0   12.0    8.0
# 10576     2.0    4.0    6.0    5.0

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp2=GP_fp2_Sectors[GP_fp2_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp2.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp2.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp2.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp2.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp2=Fastest_Lap_fp2.merge(Fastest_sector1_fp2,on=['LapNumber']).merge(Fastest_sector2_fp2,on=['LapNumber']).merge(Fastest_sector3_fp2,on=['LapNumber'])
Fast_Laps_fp2=Fast_Laps_fp2[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp2=Fast_Laps_fp2.reset_index(drop=True)
Fast_Laps_fp2.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Australian Grand Prix  2025          1  00:01:38.218000       98.218
# 1  Australian Grand Prix  2025          2  00:01:17.671000       77.671
# 2  Australian Grand Prix  2025          3  00:01:18.846000       78.846
# 3  Australian Grand Prix  2025          4  00:01:17.302000       77.302
# 4  Australian Grand Prix  2025          5  00:01:17.650000       77.650
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         SAI       MEDIUM       39.711        SAI      MEDIUM       18.598
# 1         NOR       MEDIUM       27.033        TSU      MEDIUM       17.548
# 2         HUL       MEDIUM       27.249        HUL      MEDIUM       17.956
# 3         SAI       MEDIUM       26.792        SAI      MEDIUM       17.479
# 4         TSU       MEDIUM       26.864        TSU      MEDIUM       17.695
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        RUS        HARD       38.860        SAI      MEDIUM
# 1        GAS      MEDIUM       32.925        NOR      MEDIUM
# 2        HUL      MEDIUM       33.641        HUL      MEDIUM
# 3        GAS      MEDIUM       32.952        SAI      MEDIUM
# 4        TSU      MEDIUM       33.091        TSU      MEDIUM

# %%
Fast_Laps_fp2['color'] = Fast_Laps_fp2['Fastest Lap'].apply(driver_color)
Fast_Laps_fp2.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Australian Grand Prix  2025          1  00:01:38.218000       98.218
# 1  Australian Grand Prix  2025          2  00:01:17.671000       77.671
# 2  Australian Grand Prix  2025          3  00:01:18.846000       78.846
# 3  Australian Grand Prix  2025          4  00:01:17.302000       77.302
# 4  Australian Grand Prix  2025          5  00:01:17.650000       77.650
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         SAI       MEDIUM       39.711        SAI      MEDIUM       18.598
# 1         NOR       MEDIUM       27.033        TSU      MEDIUM       17.548
# 2         HUL       MEDIUM       27.249        HUL      MEDIUM       17.956
# 3         SAI       MEDIUM       26.792        SAI      MEDIUM       17.479
# 4         TSU       MEDIUM       26.864        TSU      MEDIUM       17.695
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        RUS        HARD       38.860        SAI      MEDIUM  #64C4FF
# 1        GAS      MEDIUM       32.925        NOR      MEDIUM  #FF8000
# 2        HUL      MEDIUM       33.641        HUL      MEDIUM  #52e252
# 3        GAS      MEDIUM       32.952        SAI      MEDIUM  #64C4FF
# 4        TSU      MEDIUM       33.091        TSU      MEDIUM  #6692FF

# %%
LapTime_fp2_ordered=Fast_Laps_fp2.sort_values(by=['LapTime (s)'])
LapTime_fp2_ordered.head()
# Out:
#                        GP  Year  LapNumber          LapTime  LapTime (s)  \
# 14  Australian Grand Prix  2025         15  00:01:16.439000       76.439
# 11  Australian Grand Prix  2025         12  00:01:16.580000       76.580
# 7   Australian Grand Prix  2025          8  00:01:16.784000       76.784
# 8   Australian Grand Prix  2025          9  00:01:16.794000       76.794
# 13  Australian Grand Prix  2025         14  00:01:16.859000       76.859
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 14         LEC         SOFT       26.477        LEC        SOFT       17.392
# 11         NOR         SOFT       26.494        LEC        SOFT       17.399
# 7          TSU         SOFT       26.460        TSU        SOFT       17.315
# 8          LEC       MEDIUM       26.648        LEC      MEDIUM       17.492
# 13         HAM         SOFT       26.528        HAM        SOFT       17.359
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 14        LEC        SOFT       32.567        PIA        SOFT  #E80020
# 11        NOR        SOFT       32.674        NOR        SOFT  #FF8000
# 7         DOO      MEDIUM       32.825        TSU        SOFT  #6692FF
# 8         LEC      MEDIUM       32.654        LEC      MEDIUM  #E80020
# 13        DOO        SOFT       32.724        HAM        SOFT  #E80020

# %%
import plotly.graph_objects as go
# colors = n_colors('rgb(255, 200, 200)', 'rgb(200, 0, 0)', 9, colortype='rgb')

fig_fp2 = go.Figure(go.Table
 (header={"values": LapTime_fp2_ordered.columns},
  cells=dict(
    values=LapTime_fp2_ordered.T.values,
    fill_color=[LapTime_fp2_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp2.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp2_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp2_ordered.loc[LapTime_fp2_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp2_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp2.update_layout(
    title="FP2 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp2.show()

# %%
fig_fp2.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP2/{}/{} {} FP2 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year,year,gp),full_html=False, include_plotlyjs='cdn')

# %%
# FP3

# %%
df_bq_fp3=df_bq2_fp3[(df_bq2_fp3["GP"]==race)&(df_bq2_fp3["Year"]==2025)]
GP_fp3=df_bq_fp3
GP_fp3["LapNumber"]=GP_fp3["LapNumber"].astype(int)
GP_fp3=GP_fp3.sort_values(['Driver','LapNumber'])
GP_fp3["DriverNumber"]=GP_fp3["DriverNumber"].astype(int)
year=GP_fp3['Year'].iloc[0]
gp=GP_fp3['GP'].iloc[0]
GP_fp3.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_7879/2774860751.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          Time Driver  DriverNumber                 LapTime  \
# 15252  0 days 00:32:33.265000    ALB            23  0 days 00:01:42.922000
# 15253  0 days 00:33:51.872000    ALB            23  0 days 00:01:18.607000
# 15254  0 days 00:35:55.985000    ALB            23  0 days 00:02:04.113000
# 15255  0 days 00:37:13.966000    ALB            23  0 days 00:01:17.981000
# 15256  0 days 00:39:28.660000    ALB            23  0 days 00:02:14.694000
#
#        LapNumber  Stint              PitOutTime               PitInTime  \
# 15252          1    1.0  0 days 00:30:52.377000                     NaT
# 15253          2    1.0                     NaT                     NaT
# 15254          3    1.0                     NaT                     NaT
# 15255          4    1.0                     NaT                     NaT
# 15256          5    1.0                     NaT  0 days 00:39:08.220000
#
#                   Sector1Time             Sector2Time             Sector3Time  \
# 15252  0 days 00:00:38.723000  0 days 00:00:20.954000  0 days 00:00:43.245000
# 15253  0 days 00:00:27.513000  0 days 00:00:17.698000  0 days 00:00:33.396000
# 15254  0 days 00:00:45.965000  0 days 00:00:25.396000  0 days 00:00:52.752000
# 15255  0 days 00:00:26.995000  0 days 00:00:17.447000  0 days 00:00:33.539000
# 15256  0 days 00:00:41.786000  0 days 00:00:24.084000  0 days 00:01:08.824000
#
#            Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 15252  0 days 00:31:29.313000  0 days 00:31:50.318000  0 days 00:32:33.413000
# 15253  0 days 00:33:00.778000  0 days 00:33:18.476000  0 days 00:33:51.872000
# 15254  0 days 00:34:37.837000  0 days 00:35:03.233000  0 days 00:35:55.985000
# 15255  0 days 00:36:22.980000  0 days 00:36:40.427000  0 days 00:37:13.966000
# 15256  0 days 00:37:55.752000  0 days 00:38:19.836000  0 days 00:39:28.660000
#
#        SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest Compound  TyreLife  \
# 15252    274.0    158.0    303.0    204.0          False     HARD       1.0
# 15253    283.0    319.0    303.0    322.0           True     HARD       2.0
# 15254    172.0    223.0    306.0    217.0          False     HARD       3.0
# 15255    285.0    323.0    302.0    325.0           True     HARD       4.0
# 15256    166.0    216.0      NaN    238.0          False     HARD       5.0
#
#       FreshTyre      Team            LapStartTime             LapStartDate  \
# 15252      True  Williams  0 days 00:30:52.377000  2025-03-15 01:49:58.888
# 15253      True  Williams  0 days 00:32:33.265000  2025-03-15 01:51:39.776
# 15254      True  Williams  0 days 00:33:51.872000  2025-03-15 01:52:58.383
# 15255      True  Williams  0 days 00:35:55.985000  2025-03-15 01:55:02.496
# 15256      True  Williams  0 days 00:37:13.966000  2025-03-15 01:56:20.477
#
#       TrackStatus  Position  Deleted DeletedReason  FastF1Generated  \
# 15252           1       NaN    False                          False
# 15253           1       NaN    False                          False
# 15254           1       NaN    False                          False
# 15255           1       NaN    False                          False
# 15256           1       NaN    False                          False
#
#       IsAccurate  Year                     GP
# 15252      False  2025  Australian Grand Prix
# 15253       True  2025  Australian Grand Prix
# 15254       True  2025  Australian Grand Prix
# 15255       True  2025  Australian Grand Prix
# 15256      False  2025  Australian Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp3['LapTime_TD']= pd.to_timedelta(GP_fp3["LapTime"])
GP_fp3["LapTime"]=GP_fp3['LapTime'].str.split('days ').str[1]
GP_fp3.loc[:, "LapTime (s)"] = GP_fp3["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp3['s1_TD']= pd.to_timedelta(GP_fp3["Sector1Time"])
GP_fp3['s2_TD']= pd.to_timedelta(GP_fp3["Sector2Time"])
GP_fp3['s3_TD']= pd.to_timedelta(GP_fp3["Sector3Time"])

GP_fp3.loc[:, "Time S1 (s)"] = GP_fp3["s1_TD"].dt.total_seconds()
GP_fp3.loc[:, "Time S2 (s)"] = GP_fp3["s2_TD"].dt.total_seconds()
GP_fp3.loc[:, "Time S3 (s)"] = GP_fp3["s3_TD"].dt.total_seconds()

# %%
GP_fp3_Rk=GP_fp3[GP_fp3["LapTime"]!="NaT"]
GP_fp3_Rk["LAP_RK"] = GP_fp3_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S1_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S2_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S3_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["Race_RK"] = GP_fp3_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp3_Sectors=GP_fp3_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp3_Sectors=GP_fp3_Sectors.fillna(0)
GP_fp3_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#       Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s)  \
# 15385    BEA          1        0.000       20.958       38.308
# 15329    SAI          1       36.390       18.788       44.269
# 15127    GAS          1       36.784       18.909       43.183
# 15035    VER          1       37.991       19.905       40.142
# 15252    ALB          1       38.723       20.954       43.245
#
#                LapTime  LapTime (s) Compound  Year                     GP  \
# 15385                0        0.000   MEDIUM  2025  Australian Grand Prix
# 15329  00:01:39.447000       99.447     HARD  2025  Australian Grand Prix
# 15127  00:01:38.876000       98.876     HARD  2025  Australian Grand Prix
# 15035  00:01:38.038000       98.038     SOFT  2025  Australian Grand Prix
# 15252  00:01:42.922000      102.922     HARD  2025  Australian Grand Prix
#
#        LAP_RK  S1_RK  S2_RK  S3_RK
# 15385     0.0    0.0    9.0    1.0
# 15329     3.0    1.0    1.0    8.0
# 15127     2.0    2.0    2.0    6.0
# 15035     1.0    3.0    5.0    3.0
# 15252     4.0    4.0    8.0    7.0

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp3=GP_fp3_Sectors[GP_fp3_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp3.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp3.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp3.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp3.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp3=Fastest_Lap_fp3.merge(Fastest_sector1_fp3,on=['LapNumber']).merge(Fastest_sector2_fp3,on=['LapNumber']).merge(Fastest_sector3_fp3,on=['LapNumber'])
Fast_Laps_fp3=Fast_Laps_fp3[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp3=Fast_Laps_fp3.reset_index(drop=True)
Fast_Laps_fp3.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Australian Grand Prix  2025          1  00:01:38.038000       98.038
# 1  Australian Grand Prix  2025          2  00:01:17.242000       77.242
# 2  Australian Grand Prix  2025          3  00:01:17.298000       77.298
# 3  Australian Grand Prix  2025          4  00:01:17.981000       77.981
# 4  Australian Grand Prix  2025          5  00:01:16.646000       76.646
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         VER         SOFT       36.390        SAI        HARD       18.788
# 1         RUS         SOFT       26.767        RUS        SOFT       17.521
# 2         PIA         SOFT       26.971        PIA        SOFT       17.515
# 3         ALB         HARD       26.995        ALB        HARD       17.447
# 4         VER         SOFT       26.616        HUL        SOFT       17.161
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        SAI        HARD       38.308        BEA      MEDIUM
# 1        VER        SOFT       32.868        RUS        SOFT
# 2        PIA        SOFT       32.812        PIA        SOFT
# 3        ALB        HARD       33.314        SAI        HARD
# 4        VER        SOFT       32.678        ANT        SOFT

# %%
Fast_Laps_fp3['color'] = Fast_Laps_fp3['Fastest Lap'].apply(driver_color)
Fast_Laps_fp3.head()
# Out:
#                       GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Australian Grand Prix  2025          1  00:01:38.038000       98.038
# 1  Australian Grand Prix  2025          2  00:01:17.242000       77.242
# 2  Australian Grand Prix  2025          3  00:01:17.298000       77.298
# 3  Australian Grand Prix  2025          4  00:01:17.981000       77.981
# 4  Australian Grand Prix  2025          5  00:01:16.646000       76.646
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         VER         SOFT       36.390        SAI        HARD       18.788
# 1         RUS         SOFT       26.767        RUS        SOFT       17.521
# 2         PIA         SOFT       26.971        PIA        SOFT       17.515
# 3         ALB         HARD       26.995        ALB        HARD       17.447
# 4         VER         SOFT       26.616        HUL        SOFT       17.161
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        SAI        HARD       38.308        BEA      MEDIUM  #3860C6
# 1        VER        SOFT       32.868        RUS        SOFT  #27F4D2
# 2        PIA        SOFT       32.812        PIA        SOFT  #FF8000
# 3        ALB        HARD       33.314        SAI        HARD  #64C4FF
# 4        VER        SOFT       32.678        ANT        SOFT  #3860C6

# %%
LapTime_fp3_ordered=Fast_Laps_fp3.sort_values(by=['LapTime (s)'])
LapTime_fp3_ordered.head()
# Out:
#                        GP  Year  LapNumber          LapTime  LapTime (s)  \
# 11  Australian Grand Prix  2025         12  00:01:15.921000       75.921
# 12  Australian Grand Prix  2025         13  00:01:15.960000       75.960
# 8   Australian Grand Prix  2025          9  00:01:16.077000       76.077
# 9   Australian Grand Prix  2025         10  00:01:16.173000       76.173
# 16  Australian Grand Prix  2025         17  00:01:16.188000       76.188
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 11         PIA         SOFT       26.398        VER        SOFT       17.110
# 12         RUS         SOFT       26.277        RUS        SOFT       17.150
# 8          PIA         SOFT       26.358        PIA        SOFT       17.276
# 9          RUS         SOFT       26.355        RUS        SOFT       17.239
# 16         LEC         SOFT       26.385        LEC        SOFT       17.249
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 11        VER        SOFT       32.296        PIA        SOFT  #FF8000
# 12        NOR        SOFT       32.433        ANT        SOFT  #27F4D2
# 8         PIA        SOFT       32.443        PIA        SOFT  #FF8000
# 9         DOO        SOFT       32.563        RUS        SOFT  #27F4D2
# 16        LEC        SOFT       32.554        LEC        SOFT  #E80020

# %%
import plotly.graph_objects as go
# colors = n_colors('rgb(255, 200, 200)', 'rgb(200, 0, 0)', 9, colortype='rgb')

fig_fp3 = go.Figure(go.Table
 (header={"values": LapTime_fp3_ordered.columns},
  cells=dict(
    values=LapTime_fp3_ordered.T.values,
    fill_color=[LapTime_fp3_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp3.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp3_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp3_ordered.loc[LapTime_fp3_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp3_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp3.update_layout(
    title="FP3 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp3.show()

# %%
fig_fp3.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP3/{}/{} {} FP3 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year,year,gp),full_html=False, include_plotlyjs='cdn')

# %%
#Multi GP Plot FP1

# %%
def driver_color(driver):
    if driver =="VER":
        return "#3860C6"
    elif driver =="PER":
        return '#3860C6'
    elif driver =="NOR":
        return '#FF8000'
    elif driver =="PIA":
        return '#FF8000'
    elif driver =="LEC":
        return '#E80020'
    elif driver =="SAI":
        return '#E80020'
    elif driver =="HAM":
        return '#27F4D2'
    elif driver =="RUS":
        return '#27F4D2'
    elif driver =="ALO":
        return '#229971'
    elif driver =="STR":
        return '#229971'
    elif driver =="GAS":
        return '#0093cc'
    elif driver =="OCO":
        return '#0093cc'
    elif driver =="MAG":
        return '#B6BABD'
    elif driver =="HUL":
        return '#B6BABD'
    elif driver =="ZHO":
        return '#52e252'
    elif driver =="BOT":
        return '#52e252'
    elif driver =="ALB":
        return '#64C4FF'
    elif driver =="SAR":
        return '#64C4FF'
    elif driver =="TSU":
        return '#6692FF'
    elif driver =="RIC":
        return '#6692FF'
    else:
        return '#3860C6'

# %%
save_year_multi=2023

# %%
#2024
race_multi=["Bahrain Grand Prix", "Saudi Arabian Grand Prix", "Australian Grand Prix", "Japanese Grand Prix","Chinese Grand Prix","Miami Grand Prix","Emilia Romagna Grand Prix","Monaco Grand Prix","Canadian Grand Prix","Spanish Grand Prix","Austrian Grand Prix","British Grand Prix","Hungarian Grand Prix","Belgian Grand Prix"]
#2023
# race_multi=["Abu Dhabi Grand Prix","Australian Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Canadian Grand Prix","Dutch Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Japanese Grand Prix","Las Vegas Grand Prix","Mexico City Grand Prix","Miami Grand Prix","Monaco Grand Prix","Pre-Season Testing","Qatar Grand Prix","Saudi Arabian Grand Prix","Singapore Grand Prix","Spanish Grand Prix","São Paulo Grand Prix","United States Grand Prix"]
# 2022
# race_multi=["Abu Dhabi Grand Prix","Australian Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Canadian Grand Prix","Dutch Grand Prix","Emilia Romagna Grand Prix","French Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Japanese Grand Prix","Mexico City Grand Prix","Miami Grand Prix","Monaco Grand Prix","Saudi Arabian Grand Prix","Singapore Grand Prix","Spanish Grand Prix","São Paulo Grand Prix","United States Grand Prix"]
#2021
# race_multi=["Abu Dhabi Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Dutch Grand Prix","Emilia Romagna Grand Prix","French Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Mexico City Grand Prix","Monaco Grand Prix","Portuguese Grand Prix","Qatar Grand Prix","Russian Grand Prix","Saudi Arabian Grand Prix","Spanish Grand Prix","Styrian Grand Prix","São Paulo Grand Prix","Turkish Grand Prix","United States Grand Prix"]
#2020
# race_multi=["70th Anniversary Grand Prix","Abu Dhabi Grand Prix","Austrian Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Eifel Grand Prix","Emilia Romagna Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Portuguese Grand Prix","Russian Grand Prix","Sakhir Grand Prix","Spanish Grand Prix","Styrian Grand Prix","Turkish Grand Prix","Tuscan Grand Prix"]

year_multi=2024
for i in race_multi:
    df_bq_fp1=df_bq2_fp1[(df_bq2_fp1["GP"]==i)&(df_bq2_fp1["Year"]==year_multi)]
    GP_fp1=df_bq_fp1
    GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
    GP_fp1=GP_fp1.sort_values(['Driver','LapNumber'])
    GP_fp1["DriverNumber"]=GP_fp1["DriverNumber"].astype(int)
    # year=GP_fp1['Year'].iloc[0]
    # gp=GP_fp1['GP'].iloc[0]
    GP_fp1['LapTime_TD']= pd.to_timedelta(GP_fp1["LapTime"])
    GP_fp1["LapTime"]=GP_fp1['LapTime'].str.split('days ').str[1]
    GP_fp1.loc[:, "LapTime (s)"] = GP_fp1["LapTime_TD"].dt.total_seconds()
    GP_fp1['s1_TD']= pd.to_timedelta(GP_fp1["Sector1Time"])
    GP_fp1['s2_TD']= pd.to_timedelta(GP_fp1["Sector2Time"])
    GP_fp1['s3_TD']= pd.to_timedelta(GP_fp1["Sector3Time"])

    GP_fp1.loc[:, "Time S1 (s)"] = GP_fp1["s1_TD"].dt.total_seconds()
    GP_fp1.loc[:, "Time S2 (s)"] = GP_fp1["s2_TD"].dt.total_seconds()
    GP_fp1.loc[:, "Time S3 (s)"] = GP_fp1["s3_TD"].dt.total_seconds()
    GP_fp1_Rk=GP_fp1[GP_fp1["LapTime"]!="NaT"]
    GP_fp1_Rk["LAP_RK"] = GP_fp1_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S1_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S2_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S3_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["Race_RK"] = GP_fp1_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)
    GP_fp1_Sectors=GP_fp1_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
    GP_fp1_Sectors=GP_fp1_Sectors.fillna(0)
    Fastest_Lap_fp1=GP_fp1_Sectors[GP_fp1_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_Lap_fp1.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
    Fastest_sector1_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector1_fp1.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
    Fastest_sector2_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector2_fp1.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
    Fastest_sector3_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector3_fp1.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
    Fast_Laps_fp1=Fastest_Lap_fp1.merge(Fastest_sector1_fp1,on=['LapNumber']).merge(Fastest_sector2_fp1,on=['LapNumber']).merge(Fastest_sector3_fp1,on=['LapNumber'])
    Fast_Laps_fp1=Fast_Laps_fp1[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
    Fast_Laps_fp1=Fast_Laps_fp1.reset_index(drop=True)
    Fast_Laps_fp1['color'] = Fast_Laps_fp1['Fastest Lap'].apply(driver_color)
    LapTime_fp1_ordered=Fast_Laps_fp1.sort_values(by=['LapTime (s)'])
    fig_fp1 = go.Figure(go.Table
    (header={"values": LapTime_fp1_ordered.columns},
    cells=dict(
        values=LapTime_fp1_ordered.T.values,
        fill_color=[LapTime_fp1_ordered.color],
        align='center', font=dict(color='white', size=11)
        ))
    )
    fig_fp1.update_layout(
        title="FP1 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi, i),
            title_x=0.5,
        yaxis = dict(tickfont = dict(size=15)),
        xaxis = dict(tickfont = dict(size=15)),
        font=dict(
            family="PT Sans Narrow",
            size=13,
            color="Black"
        ),
        height=780,
        width=1200,
        title_font_family="PT Sans Narrow",
        margin=dict(l=5, r=5, t=35, b=5),
    )
    fig_fp1.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP1/{}/{} {} FP1 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year_multi,year_multi, i),include_plotlyjs='cdn')
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Multi GP Plot FP2

# %%
for i in race_multi:
    try:
        df_bq_fp2=df_bq2_fp2[(df_bq2_fp2["GP"]==i)&(df_bq2_fp2["Year"]==year_multi)]
        GP_fp2=df_bq_fp2
        GP_fp2["LapNumber"]=GP_fp2["LapNumber"].astype(int)
        GP_fp2=GP_fp2.sort_values(['Driver','LapNumber'])
        GP_fp2["DriverNumber"]=GP_fp2["DriverNumber"].astype(int)
        year=GP_fp2['Year'].iloc[0]
        gp=GP_fp2['GP'].iloc[0]
        #Convert LapTime to Time Delta for plotting on Y Axis
        GP_fp2['LapTime_TD']= pd.to_timedelta(GP_fp2["LapTime"])
        GP_fp2["LapTime"]=GP_fp2['LapTime'].str.split('days ').str[1]
        GP_fp2.loc[:, "LapTime (s)"] = GP_fp2["LapTime_TD"].dt.total_seconds()
        # Fastest Driver in each lap
        GP_fp2['s1_TD']= pd.to_timedelta(GP_fp2["Sector1Time"])
        GP_fp2['s2_TD']= pd.to_timedelta(GP_fp2["Sector2Time"])
        GP_fp2['s3_TD']= pd.to_timedelta(GP_fp2["Sector3Time"])

        GP_fp2.loc[:, "Time S1 (s)"] = GP_fp2["s1_TD"].dt.total_seconds()
        GP_fp2.loc[:, "Time S2 (s)"] = GP_fp2["s2_TD"].dt.total_seconds()
        GP_fp2.loc[:, "Time S3 (s)"] = GP_fp2["s3_TD"].dt.total_seconds()
        GP_fp2_Rk=GP_fp2[GP_fp2["LapTime"]!="NaT"]
        GP_fp2_Rk["LAP_RK"] = GP_fp2_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S1_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S2_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S3_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["Race_RK"] = GP_fp2_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

        GP_fp2_Sectors=GP_fp2_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
        GP_fp2_Sectors=GP_fp2_Sectors.fillna(0)
        GP_fp2_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
        #get a combined view for fastest drivers in the entire lap, S1, S2, and S3
        Fastest_Lap_fp2=GP_fp2_Sectors[GP_fp2_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_Lap_fp2.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
        Fastest_sector1_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector1_fp2.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
        Fastest_sector2_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector2_fp2.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
        Fastest_sector3_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector3_fp2.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
        Fast_Laps_fp2=Fastest_Lap_fp2.merge(Fastest_sector1_fp2,on=['LapNumber']).merge(Fastest_sector2_fp2,on=['LapNumber']).merge(Fastest_sector3_fp2,on=['LapNumber'])
        Fast_Laps_fp2=Fast_Laps_fp2[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
        Fast_Laps_fp2=Fast_Laps_fp2.reset_index(drop=True)
        Fast_Laps_fp2['color'] = Fast_Laps_fp2['Fastest Lap'].apply(driver_color)
        LapTime_fp2_ordered=Fast_Laps_fp2.sort_values(by=['LapTime (s)'])
        fig_fp2 = go.Figure(go.Table
        (header={"values": LapTime_fp2_ordered.columns},
        cells=dict(
            values=LapTime_fp2_ordered.T.values,
            fill_color=[LapTime_fp2_ordered.color],
            align='center', font=dict(color='white', size=11)
            ))
        )
        fig_fp2.update_layout(
            title="FP2 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi,i),
                title_x=0.5,
            yaxis = dict(tickfont = dict(size=15)),
            xaxis = dict(tickfont = dict(size=15)),
            font=dict(
                family="PT Sans Narrow",
                size=13,
                color="Black"
            ),
            height=780,
            width=1200,
            title_font_family="PT Sans Narrow",
            margin=dict(l=5, r=5, t=35, b=5),
        )
        fig_fp2.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP2/{}/{} {} FP2 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year_multi,year_multi,i),include_plotlyjs='cdn')
    except:
        continue
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Multi GP Plot FP3

# %%
for i in race_multi:
    try:
        df_bq_fp3=df_bq2_fp3[(df_bq2_fp3["GP"]==i)&(df_bq2_fp3["Year"]==year_multi)]
        GP_fp3=df_bq_fp3
        GP_fp3["LapNumber"]=GP_fp3["LapNumber"].astype(int)
        GP_fp3=GP_fp3.sort_values(['Driver','LapNumber'])
        GP_fp3["DriverNumber"]=GP_fp3["DriverNumber"].astype(int)
        year=GP_fp3['Year'].iloc[0]
        gp=GP_fp3['GP'].iloc[0]
        #Convert LapTime to Time Delta for plotting on Y Axis
        GP_fp3['LapTime_TD']= pd.to_timedelta(GP_fp3["LapTime"])
        GP_fp3["LapTime"]=GP_fp3['LapTime'].str.split('days ').str[1]
        GP_fp3.loc[:, "LapTime (s)"] = GP_fp3["LapTime_TD"].dt.total_seconds()
        # Fastest Driver in each lap
        GP_fp3['s1_TD']= pd.to_timedelta(GP_fp3["Sector1Time"])
        GP_fp3['s2_TD']= pd.to_timedelta(GP_fp3["Sector2Time"])
        GP_fp3['s3_TD']= pd.to_timedelta(GP_fp3["Sector3Time"])

        GP_fp3.loc[:, "Time S1 (s)"] = GP_fp3["s1_TD"].dt.total_seconds()
        GP_fp3.loc[:, "Time S2 (s)"] = GP_fp3["s2_TD"].dt.total_seconds()
        GP_fp3.loc[:, "Time S3 (s)"] = GP_fp3["s3_TD"].dt.total_seconds()
        GP_fp3_Rk=GP_fp3[GP_fp3["LapTime"]!="NaT"]
        GP_fp3_Rk["LAP_RK"] = GP_fp3_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S1_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S2_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S3_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["Race_RK"] = GP_fp3_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

        GP_fp3_Sectors=GP_fp3_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
        GP_fp3_Sectors=GP_fp3_Sectors.fillna(0)
        #get a combined view for fastest drivers in the entire lap, S1, S2, and S3
        Fastest_Lap_fp3=GP_fp3_Sectors[GP_fp3_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_Lap_fp3.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
        Fastest_sector1_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector1_fp3.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
        Fastest_sector2_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector2_fp3.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
        Fastest_sector3_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector3_fp3.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
        Fast_Laps_fp3=Fastest_Lap_fp3.merge(Fastest_sector1_fp3,on=['LapNumber']).merge(Fastest_sector2_fp3,on=['LapNumber']).merge(Fastest_sector3_fp3,on=['LapNumber'])
        Fast_Laps_fp3=Fast_Laps_fp3[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
        Fast_Laps_fp3=Fast_Laps_fp3.reset_index(drop=True)
        Fast_Laps_fp3['color'] = Fast_Laps_fp3['Fastest Lap'].apply(driver_color)
        LapTime_fp3_ordered=Fast_Laps_fp3.sort_values(by=['LapTime (s)'])

        fig_fp3 = go.Figure(go.Table
        (header={"values": LapTime_fp3_ordered.columns},
        cells=dict(
            values=LapTime_fp3_ordered.T.values,
            fill_color=[LapTime_fp3_ordered.color],
            align='center', font=dict(color='white', size=11)
            ))
        )
        fig_fp3.update_layout(
            title="FP3 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi, i),
                title_x=0.5,
            yaxis = dict(tickfont = dict(size=15)),
            xaxis = dict(tickfont = dict(size=15)),
            font=dict(
                family="PT Sans Narrow",
                size=13,
                color="Black"
            ),
            height=780,
            width=1200,
            title_font_family="PT Sans Narrow",
            margin=dict(l=5, r=5, t=35, b=5),
        )
        fig_fp3.write_html("/Users/rdesh723/statpulse-html/plots/Free Practice/FP3/{}/{} {} FP3 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(save_year_multi, year_multi, i),include_plotlyjs='cdn')
    except:
        continue
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
