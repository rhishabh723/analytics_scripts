# %%
import pandas as pd
import numpy as np
import pandas_gbq
import time
import itertools
import datetime
import matplotlib.pyplot as plt
from datetime import *
from datetime import datetime, timedelta, date
from pathlib import Path
from zipfile import ZipFile
import urllib
from PIL import Image
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Standard plotly imports
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import requests
import json
import plotly.graph_objects as go
project_id = "perceptive-ivy-290216"

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp1_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp1 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp2_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp2 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
#Change the date to the previous day
query = """
SELECT
*
FROM
`perceptive-ivy-290216.f1_api.fp3_lap_time`
"""
project_id = "perceptive-ivy-290216"
df_bq2_fp3 = pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
race="Dutch Grand Prix"

# %%
# FP1

# %%
df_bq_fp1=df_bq2_fp1[(df_bq2_fp1["GP"]==race)&(df_bq2_fp1["Year"]==2024)]
GP_fp1=df_bq_fp1
GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
GP_fp1=GP_fp1.sort_values(['Driver','LapNumber'])
GP_fp1["DriverNumber"]=GP_fp1["DriverNumber"].astype(int)
year=GP_fp1['Year'].iloc[0]
gp=GP_fp1['GP'].iloc[0]
GP_fp1.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/3355874270.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Time Driver  DriverNumber                 LapTime  \
# 225  0 days 00:28:19.797000    ALB            23                     NaT
# 245  0 days 00:48:26.439000    ALB            23                     NaT
# 249  0 days 00:50:18.647000    ALB            23  0 days 00:01:52.208000
# 34   0 days 00:51:41.469000    ALB            23  0 days 00:01:22.822000
# 143  0 days 00:53:40.779000    ALB            23  0 days 00:01:59.310000
#
#      LapNumber  Stint              PitOutTime               PitInTime  \
# 225          1    1.0  0 days 00:26:35.765000  0 days 00:28:17.944000
# 245          2    2.0  0 days 00:46:48.605000  0 days 00:48:24.928000
# 249          3    3.0  0 days 00:48:49.356000                     NaT
# 34           4    3.0                     NaT                     NaT
# 143          5    3.0                     NaT  0 days 00:53:39.282000
#
#                 Sector1Time             Sector2Time             Sector3Time  \
# 225                     NaT  0 days 00:00:34.522000  0 days 00:00:35.252000
# 245                     NaT  0 days 00:00:33.226000  0 days 00:00:33.010000
# 249  0 days 00:00:54.393000  0 days 00:00:31.495000  0 days 00:00:26.320000
# 34   0 days 00:00:28.424000  0 days 00:00:29.377000  0 days 00:00:25.021000
# 143  0 days 00:00:41.424000  0 days 00:00:41.789000  0 days 00:00:36.097000
#
#          Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 225                     NaT  0 days 00:27:44.597000  0 days 00:28:19.797000
# 245                     NaT  0 days 00:47:53.647000  0 days 00:48:26.439000
# 249  0 days 00:49:20.832000  0 days 00:49:52.327000  0 days 00:50:18.647000
# 34   0 days 00:50:47.071000  0 days 00:51:16.448000  0 days 00:51:41.469000
# 143  0 days 00:52:22.893000  0 days 00:53:04.682000  0 days 00:53:40.779000
#
#      SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest      Compound  \
# 225    243.0    228.0      NaN      NaN          False           WET
# 245    273.0    232.0      NaN      NaN          False           WET
# 249    282.0    252.0    301.0      NaN          False  INTERMEDIATE
# 34     283.0    265.0    306.0    260.0           True  INTERMEDIATE
# 143    158.0    216.0      NaN    225.0          False  INTERMEDIATE
#
#      TyreLife FreshTyre      Team            LapStartTime  \
# 225       1.0      True  Williams  0 days 00:26:35.765000
# 245       2.0     False  Williams  0 days 00:28:19.797000
# 249       1.0      True  Williams  0 days 00:48:26.439000
# 34        2.0      True  Williams  0 days 00:50:18.647000
# 143       3.0      True  Williams  0 days 00:51:41.469000
#
#                 LapStartDate TrackStatus  Position  Deleted DeletedReason  \
# 225  2024-08-23 10:42:18.164           1       NaN    False
# 245  2024-08-23 10:44:02.196          12       NaN    False
# 249  2024-08-23 11:04:08.838           1       NaN    False
# 34   2024-08-23 11:06:01.046           1       NaN    False
# 143  2024-08-23 11:07:23.868           1       NaN    False
#
#      FastF1Generated IsAccurate  Year                GP
# 225            False      False  2024  Dutch Grand Prix
# 245            False      False  2024  Dutch Grand Prix
# 249            False      False  2024  Dutch Grand Prix
# 34             False       True  2024  Dutch Grand Prix
# 143            False      False  2024  Dutch Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp1['LapTime_TD']= pd.to_timedelta(GP_fp1["LapTime"])
GP_fp1["LapTime"]=GP_fp1['LapTime'].str.split('days ').str[1]
GP_fp1.loc[:, "LapTime (s)"] = GP_fp1["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp1['s1_TD']= pd.to_timedelta(GP_fp1["Sector1Time"])
GP_fp1['s2_TD']= pd.to_timedelta(GP_fp1["Sector2Time"])
GP_fp1['s3_TD']= pd.to_timedelta(GP_fp1["Sector3Time"])

GP_fp1.loc[:, "Time S1 (s)"] = GP_fp1["s1_TD"].dt.total_seconds()
GP_fp1.loc[:, "Time S2 (s)"] = GP_fp1["s2_TD"].dt.total_seconds()
GP_fp1.loc[:, "Time S3 (s)"] = GP_fp1["s3_TD"].dt.total_seconds()

# %%
GP_fp1_Rk=GP_fp1[GP_fp1["LapTime"]!="NaT"]
GP_fp1_Rk["LAP_RK"] = GP_fp1_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S1_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S2_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["S3_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp1_Rk["Race_RK"] = GP_fp1_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp1_Sectors=GP_fp1_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp1_Sectors=GP_fp1_Sectors.fillna(0)
GP_fp1_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#     Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s) LapTime  \
# 225    ALB          1          0.0       34.522       35.252       0
# 234    ALO          1          0.0       34.204       28.134       0
# 216    GAS          1          0.0       34.375       29.537       0
# 242    HAM          1          0.0       32.948       27.537       0
# 218    HUL          1          0.0       47.601       41.157       0
#
#      LapTime (s)      Compound  Year                GP  LAP_RK  S1_RK  S2_RK  \
# 225          0.0           WET  2024  Dutch Grand Prix     0.0    0.0   12.0
# 234          0.0           WET  2024  Dutch Grand Prix     0.0    0.0    8.0
# 216          0.0           WET  2024  Dutch Grand Prix     0.0    0.0    9.0
# 242          0.0  INTERMEDIATE  2024  Dutch Grand Prix     0.0    0.0    3.0
# 218          0.0           WET  2024  Dutch Grand Prix     0.0    0.0   20.0
#
#      S3_RK
# 225   13.0
# 234    7.0
# 216    9.0
# 242    4.0
# 218   20.0

# %%
#2024
def driver_color(driver):
    if driver =="VER":
        return "#3860C6"
    elif driver =="PER":
        return '#3860C6'
    elif driver =="NOR":
        return '#FF8000'
    elif driver =="PIA":
        return '#FF8000'
    elif driver =="LEC":
        return '#E80020'
    elif driver =="SAI":
        return '#E80020'
    elif driver =="HAM":
        return '#27F4D2'
    elif driver =="RUS":
        return '#27F4D2'
    elif driver =="ALO":
        return '#229971'
    elif driver =="STR":
        return '#229971'
    elif driver =="GAS":
        return '#0093cc'
    elif driver =="OCO":
        return '#0093cc'
    elif driver =="MAG":
        return '#B6BABD'
    elif driver =="HUL":
        return '#B6BABD'
    elif driver =="ZHO":
        return '#52e252'
    elif driver =="BOT":
        return '#52e252'
    elif driver =="ALB":
        return '#64C4FF'
    elif driver =="SAR":
        return '#64C4FF'
    elif driver =="COL":
        return '#64C4FF'    
    elif driver =="TSU":
        return '#6692FF'
    elif driver =="RIC":
        return '#6692FF'
    else:
        return '#3860C6'

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp1=GP_fp1_Sectors[GP_fp1_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp1.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp1.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp1.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp1.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp1=Fastest_Lap_fp1.merge(Fastest_sector1_fp1,on=['LapNumber']).merge(Fastest_sector2_fp1,on=['LapNumber']).merge(Fastest_sector3_fp1,on=['LapNumber'])
Fast_Laps_fp1=Fast_Laps_fp1[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp1=Fast_Laps_fp1.reset_index(drop=True)
Fast_Laps_fp1.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Dutch Grand Prix  2024          2  00:01:24.638000       84.638
# 1  Dutch Grand Prix  2024          3  00:01:21.300000       81.300
# 2  Dutch Grand Prix  2024          4  00:01:22.036000       82.036
# 3  Dutch Grand Prix  2024          5  00:01:18.315000       78.315
# 4  Dutch Grand Prix  2024          6  00:01:15.971000       75.971
#
#   Fastest Lap  Lap Compound  Time S1 (s) Fastest S1   S1 Compound  \
# 0         HAM  INTERMEDIATE       29.098        VER  INTERMEDIATE
# 1         VER  INTERMEDIATE       28.224        VER  INTERMEDIATE
# 2         GAS  INTERMEDIATE       28.196        GAS  INTERMEDIATE
# 3         PIA          SOFT       26.978        PIA          SOFT
# 4         PIA          SOFT       25.889        PIA          SOFT
#
#    Time S2 (s) Fastest S2   S2 Compound  Time S3 (s) Fastest S3   S3 Compound
# 0       28.490        VER  INTERMEDIATE       25.477        HAM  INTERMEDIATE
# 1       28.241        VER  INTERMEDIATE       24.835        VER  INTERMEDIATE
# 2       28.846        GAS  INTERMEDIATE       24.806        ALO  INTERMEDIATE
# 3       27.898        PIA          SOFT       23.439        PIA          SOFT
# 4       26.682        HAM          SOFT       22.983        PIA          SOFT

# %%
Fast_Laps_fp1['color'] = Fast_Laps_fp1['Fastest Lap'].apply(driver_color)
Fast_Laps_fp1.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Dutch Grand Prix  2024          2  00:01:24.638000       84.638
# 1  Dutch Grand Prix  2024          3  00:01:21.300000       81.300
# 2  Dutch Grand Prix  2024          4  00:01:22.036000       82.036
# 3  Dutch Grand Prix  2024          5  00:01:18.315000       78.315
# 4  Dutch Grand Prix  2024          6  00:01:15.971000       75.971
#
#   Fastest Lap  Lap Compound  Time S1 (s) Fastest S1   S1 Compound  \
# 0         HAM  INTERMEDIATE       29.098        VER  INTERMEDIATE
# 1         VER  INTERMEDIATE       28.224        VER  INTERMEDIATE
# 2         GAS  INTERMEDIATE       28.196        GAS  INTERMEDIATE
# 3         PIA          SOFT       26.978        PIA          SOFT
# 4         PIA          SOFT       25.889        PIA          SOFT
#
#    Time S2 (s) Fastest S2   S2 Compound  Time S3 (s) Fastest S3   S3 Compound  \
# 0       28.490        VER  INTERMEDIATE       25.477        HAM  INTERMEDIATE
# 1       28.241        VER  INTERMEDIATE       24.835        VER  INTERMEDIATE
# 2       28.846        GAS  INTERMEDIATE       24.806        ALO  INTERMEDIATE
# 3       27.898        PIA          SOFT       23.439        PIA          SOFT
# 4       26.682        HAM          SOFT       22.983        PIA          SOFT
#
#      color
# 0  #27F4D2
# 1  #3860C6
# 2  #0093cc
# 3  #FF8000
# 4  #FF8000

# %%
LapTime_fp1_ordered=Fast_Laps_fp1.sort_values(by=['LapTime (s)'])
LapTime_fp1_ordered.head()
# Out:
#                   GP  Year  LapNumber          LapTime  LapTime (s)  \
# 13  Dutch Grand Prix  2024         15  00:01:12.322000       72.322
# 9   Dutch Grand Prix  2024         11  00:01:12.523000       72.523
# 10  Dutch Grand Prix  2024         12  00:01:12.818000       72.818
# 8   Dutch Grand Prix  2024         10  00:01:13.006000       73.006
# 11  Dutch Grand Prix  2024         13  00:01:13.074000       73.074
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 13         NOR         SOFT       24.630        NOR        SOFT       25.931
# 9          VER         SOFT       24.778        VER        SOFT       25.967
# 10         NOR         SOFT       24.927        PIA        SOFT       25.964
# 8          HAM         SOFT       24.884        HAM        SOFT       25.915
# 11         SAI       MEDIUM       24.978        SAI      MEDIUM       26.050
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 13        NOR        SOFT       21.761        NOR        SOFT  #FF8000
# 9         VER        SOFT       21.778        VER        SOFT  #3860C6
# 10        NOR        SOFT       21.870        NOR        SOFT  #FF8000
# 8         HAM        SOFT       21.979        PIA        SOFT  #27F4D2
# 11        ZHO        SOFT       22.016        SAI      MEDIUM  #E80020

# %%
import plotly.graph_objects as go

fig_fp1 = go.Figure(go.Table
 (header={"values": LapTime_fp1_ordered.columns},
  cells=dict(
    values=LapTime_fp1_ordered.T.values,
    fill_color=[LapTime_fp1_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp1.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp1_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp1_ordered.loc[LapTime_fp1_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp1_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp1.update_layout(
    title="FP1 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp1.show()

# %%
fig_fp1.write_html("{} {} FP1 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(year,gp),full_html=False, include_plotlyjs='cdn')

# %%
# FP2

# %%
df_bq_fp2=df_bq2_fp2[(df_bq2_fp2["GP"]==race)&(df_bq2_fp2["Year"]==2024)]
GP_fp2=df_bq_fp2
GP_fp2["LapNumber"]=GP_fp2["LapNumber"].astype(int)
GP_fp2=GP_fp2.sort_values(['Driver','LapNumber'])
GP_fp2["DriverNumber"]=GP_fp2["DriverNumber"].astype(int)
year=GP_fp2['Year'].iloc[0]
gp=GP_fp2['GP'].iloc[0]
GP_fp2.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/4056779151.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Time Driver  DriverNumber                 LapTime  \
# 556  0 days 00:15:27.671000    ALB            23                     NaT
# 34   0 days 00:16:41.833000    ALB            23  0 days 00:01:14.162000
# 297  0 days 00:18:23.955000    ALB            23  0 days 00:01:42.122000
# 35   0 days 00:19:37.135000    ALB            23  0 days 00:01:13.180000
# 298  0 days 00:21:27.271000    ALB            23  0 days 00:01:50.136000
#
#      LapNumber  Stint              PitOutTime PitInTime  \
# 556          1    1.0  0 days 00:13:52.205000       NaT
# 34           2    1.0                     NaT       NaT
# 297          3    1.0                     NaT       NaT
# 35           4    1.0                     NaT       NaT
# 298          5    1.0                     NaT       NaT
#
#                 Sector1Time             Sector2Time             Sector3Time  \
# 556                     NaT  0 days 00:00:29.797000  0 days 00:00:29.785000
# 34   0 days 00:00:25.745000  0 days 00:00:26.059000  0 days 00:00:22.358000
# 297  0 days 00:00:37.530000  0 days 00:00:38.151000  0 days 00:00:26.441000
# 35   0 days 00:00:25.259000  0 days 00:00:25.946000  0 days 00:00:21.975000
# 298  0 days 00:00:42.225000  0 days 00:00:38.147000  0 days 00:00:29.764000
#
#          Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 556                     NaT  0 days 00:14:58.047000  0 days 00:15:27.777000
# 34   0 days 00:15:53.416000  0 days 00:16:19.475000  0 days 00:16:41.833000
# 297  0 days 00:17:19.363000  0 days 00:17:57.514000  0 days 00:18:23.955000
# 35   0 days 00:18:49.214000  0 days 00:19:15.160000  0 days 00:19:37.135000
# 298  0 days 00:20:19.360000  0 days 00:20:57.507000  0 days 00:21:27.271000
#
#      SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest Compound  TyreLife  \
# 556    281.0    247.0    310.0      NaN          False     HARD       1.0
# 34     285.0    273.0    319.0    305.0           True     HARD       2.0
# 297    170.0    240.0    314.0    267.0          False     HARD       3.0
# 35     288.0    278.0    317.0    322.0           True     HARD       4.0
# 298    170.0    127.0    285.0    185.0          False     HARD       5.0
#
#     FreshTyre      Team            LapStartTime             LapStartDate  \
# 556      True  Williams  0 days 00:13:52.205000  2024-08-23 14:00:20.125
# 34       True  Williams  0 days 00:15:27.671000  2024-08-23 14:01:55.591
# 297      True  Williams  0 days 00:16:41.833000  2024-08-23 14:03:09.753
# 35       True  Williams  0 days 00:18:23.955000  2024-08-23 14:04:51.875
# 298      True  Williams  0 days 00:19:37.135000  2024-08-23 14:06:05.055
#
#     TrackStatus  Position  Deleted DeletedReason  FastF1Generated IsAccurate  \
# 556           1       NaN    False                          False      False
# 34            1       NaN    False                          False       True
# 297           1       NaN    False                          False       True
# 35            1       NaN    False                          False       True
# 298           1       NaN    False                          False       True
#
#      Year                GP
# 556  2024  Dutch Grand Prix
# 34   2024  Dutch Grand Prix
# 297  2024  Dutch Grand Prix
# 35   2024  Dutch Grand Prix
# 298  2024  Dutch Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp2['LapTime_TD']= pd.to_timedelta(GP_fp2["LapTime"])
GP_fp2["LapTime"]=GP_fp2['LapTime'].str.split('days ').str[1]
GP_fp2.loc[:, "LapTime (s)"] = GP_fp2["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp2['s1_TD']= pd.to_timedelta(GP_fp2["Sector1Time"])
GP_fp2['s2_TD']= pd.to_timedelta(GP_fp2["Sector2Time"])
GP_fp2['s3_TD']= pd.to_timedelta(GP_fp2["Sector3Time"])

GP_fp2.loc[:, "Time S1 (s)"] = GP_fp2["s1_TD"].dt.total_seconds()
GP_fp2.loc[:, "Time S2 (s)"] = GP_fp2["s2_TD"].dt.total_seconds()
GP_fp2.loc[:, "Time S3 (s)"] = GP_fp2["s3_TD"].dt.total_seconds()

# %%
GP_fp2_Rk=GP_fp2[GP_fp2["LapTime"]!="NaT"]
GP_fp2_Rk["LAP_RK"] = GP_fp2_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S1_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S2_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["S3_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp2_Rk["Race_RK"] = GP_fp2_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp2_Sectors=GP_fp2_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp2_Sectors=GP_fp2_Sectors.fillna(0)
GP_fp2_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#     Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s) LapTime  \
# 556    ALB          1          0.0       29.797       29.785       0
# 537    ALO          1          0.0       33.395       29.587       0
# 582    BOT          1          0.0       31.017       32.547       0
# 530    GAS          1          0.0       28.148       25.206       0
# 574    HAM          1          0.0       29.440       25.938       0
#
#      LapTime (s) Compound  Year                GP  LAP_RK  S1_RK  S2_RK  S3_RK
# 556          0.0     HARD  2024  Dutch Grand Prix     0.0    0.0    7.0   16.0
# 537          0.0   MEDIUM  2024  Dutch Grand Prix     0.0    0.0   19.0   14.0
# 582          0.0   MEDIUM  2024  Dutch Grand Prix     0.0    0.0    9.0   18.0
# 530          0.0     HARD  2024  Dutch Grand Prix     0.0    0.0    2.0    3.0
# 574          0.0   MEDIUM  2024  Dutch Grand Prix     0.0    0.0    5.0    4.0

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp2=GP_fp2_Sectors[GP_fp2_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp2.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp2.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp2.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp2.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp2=Fastest_Lap_fp2.merge(Fastest_sector1_fp2,on=['LapNumber']).merge(Fastest_sector2_fp2,on=['LapNumber']).merge(Fastest_sector3_fp2,on=['LapNumber'])
Fast_Laps_fp2=Fast_Laps_fp2[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp2=Fast_Laps_fp2.reset_index(drop=True)
Fast_Laps_fp2.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Dutch Grand Prix  2024          2  00:01:12.131000       72.131
# 1  Dutch Grand Prix  2024          3  00:01:13.815000       73.815
# 2  Dutch Grand Prix  2024          4  00:01:13.023000       73.023
# 3  Dutch Grand Prix  2024          5  00:01:12.352000       72.352
# 4  Dutch Grand Prix  2024          6  00:01:12.453000       72.453
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         VER       MEDIUM       24.899        HAM      MEDIUM       25.328
# 1         PIA       MEDIUM       25.748        PIA      MEDIUM       26.096
# 2         STR       MEDIUM       24.884        RUS      MEDIUM       25.731
# 3         HAM       MEDIUM       24.941        PIA      MEDIUM       25.547
# 4         NOR       MEDIUM       24.735        NOR      MEDIUM       25.663
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound
# 0        VER      MEDIUM       21.857        VER      MEDIUM
# 1        PIA      MEDIUM       21.971        PIA      MEDIUM
# 2        STR      MEDIUM       21.848        SAI      MEDIUM
# 3        HAM      MEDIUM       21.775        HAM      MEDIUM
# 4        RUS      MEDIUM       21.840        TSU        HARD

# %%
Fast_Laps_fp2['color'] = Fast_Laps_fp2['Fastest Lap'].apply(driver_color)
Fast_Laps_fp2.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Dutch Grand Prix  2024          2  00:01:12.131000       72.131
# 1  Dutch Grand Prix  2024          3  00:01:13.815000       73.815
# 2  Dutch Grand Prix  2024          4  00:01:13.023000       73.023
# 3  Dutch Grand Prix  2024          5  00:01:12.352000       72.352
# 4  Dutch Grand Prix  2024          6  00:01:12.453000       72.453
#
#   Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 0         VER       MEDIUM       24.899        HAM      MEDIUM       25.328
# 1         PIA       MEDIUM       25.748        PIA      MEDIUM       26.096
# 2         STR       MEDIUM       24.884        RUS      MEDIUM       25.731
# 3         HAM       MEDIUM       24.941        PIA      MEDIUM       25.547
# 4         NOR       MEDIUM       24.735        NOR      MEDIUM       25.663
#
#   Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 0        VER      MEDIUM       21.857        VER      MEDIUM  #3860C6
# 1        PIA      MEDIUM       21.971        PIA      MEDIUM  #FF8000
# 2        STR      MEDIUM       21.848        SAI      MEDIUM  #229971
# 3        HAM      MEDIUM       21.775        HAM      MEDIUM  #27F4D2
# 4        RUS      MEDIUM       21.840        TSU        HARD  #FF8000

# %%
LapTime_fp2_ordered=Fast_Laps_fp2.sort_values(by=['LapTime (s)'])
LapTime_fp2_ordered.head()
# Out:
#                   GP  Year  LapNumber          LapTime  LapTime (s)  \
# 10  Dutch Grand Prix  2024         12  00:01:10.702000       70.702
# 8   Dutch Grand Prix  2024         10  00:01:10.763000       70.763
# 9   Dutch Grand Prix  2024         11  00:01:10.813000       70.813
# 7   Dutch Grand Prix  2024          9  00:01:10.961000       70.961
# 6   Dutch Grand Prix  2024          8  00:01:10.986000       70.986
#
#    Fastest Lap Lap Compound  Time S1 (s) Fastest S1 S1 Compound  Time S2 (s)  \
# 10         RUS         SOFT       24.331        RUS        SOFT       24.945
# 8          PIA         SOFT       24.396        PIA        SOFT       25.037
# 9          HAM         SOFT       24.259        HAM        SOFT       25.038
# 7          NOR         SOFT       24.313        NOR        SOFT       25.168
# 6          VER         SOFT       24.470        VER        SOFT       25.142
#
#    Fastest S2 S2 Compound  Time S3 (s) Fastest S3 S3 Compound    color
# 10        RUS        SOFT       21.426        RUS        SOFT  #27F4D2
# 8         PIA        SOFT       21.330        PIA        SOFT  #FF8000
# 9         HAM        SOFT       21.516        HAM        SOFT  #27F4D2
# 7         NOR        SOFT       21.480        NOR        SOFT  #FF8000
# 6         VER        SOFT       21.374        VER        SOFT  #3860C6

# %%
import plotly.graph_objects as go
# colors = n_colors('rgb(255, 200, 200)', 'rgb(200, 0, 0)', 9, colortype='rgb')

fig_fp2 = go.Figure(go.Table
 (header={"values": LapTime_fp2_ordered.columns},
  cells=dict(
    values=LapTime_fp2_ordered.T.values,
    fill_color=[LapTime_fp2_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp2.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp2_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp2_ordered.loc[LapTime_fp2_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp2_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp2.update_layout(
    title="FP2 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp2.show()

# %%
fig_fp2.write_html("{} {} FP2 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(year,gp),full_html=False, include_plotlyjs='cdn')

# %%
# FP3

# %%
df_bq_fp3=df_bq2_fp3[(df_bq2_fp3["GP"]==race)&(df_bq2_fp3["Year"]==2024)]
GP_fp3=df_bq_fp3
GP_fp3["LapNumber"]=GP_fp3["LapNumber"].astype(int)
GP_fp3=GP_fp3.sort_values(['Driver','LapNumber'])
GP_fp3["DriverNumber"]=GP_fp3["DriverNumber"].astype(int)
year=GP_fp3['Year'].iloc[0]
gp=GP_fp3['GP'].iloc[0]
GP_fp3.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1826480154.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       Time Driver  DriverNumber                 LapTime  \
# 42  0 days 00:25:53.049000    ALB            23                     NaT
# 85  0 days 00:27:17.056000    ALB            23  0 days 00:01:24.007000
# 95  0 days 01:12:25.417000    ALB            23                     NaT
# 64  0 days 01:13:58.487000    ALB            23                     NaT
# 11  0 days 01:15:36.802000    ALB            23                     NaT
#
#     LapNumber  Stint              PitOutTime               PitInTime  \
# 42          1    1.0  0 days 00:24:20.213000                     NaT
# 85          2    1.0                     NaT                     NaT
# 95          3    1.0                     NaT  0 days 00:29:04.496000
# 64          4    2.0  0 days 01:12:25.417000                     NaT
# 11          5    2.0                     NaT  0 days 01:15:36.802000
#
#                Sector1Time             Sector2Time             Sector3Time  \
# 42                     NaT  0 days 00:00:31.608000  0 days 00:00:27.348000
# 85  0 days 00:00:29.698000  0 days 00:00:28.558000  0 days 00:00:25.751000
# 95  0 days 00:00:28.814000  0 days 00:00:27.927000                     NaT
# 64                     NaT  0 days 00:00:29.859000  0 days 00:00:29.632000
# 11                     NaT                     NaT                     NaT
#
#         Sector1SessionTime      Sector2SessionTime      Sector3SessionTime  \
# 42                     NaT  0 days 00:25:25.874000  0 days 00:25:53.049000
# 85  0 days 00:26:22.747000  0 days 00:26:51.305000  0 days 00:27:17.056000
# 95  0 days 00:27:45.989000  0 days 00:28:13.900000                     NaT
# 64                     NaT  0 days 01:13:29.098000  0 days 01:13:58.487000
# 11                     NaT                     NaT                     NaT
#
#     SpeedI1  SpeedI2  SpeedFL  SpeedST IsPersonalBest      Compound  TyreLife  \
# 42    270.0    240.0    283.0      NaN          False  INTERMEDIATE       4.0
# 85    272.0    260.0    285.0    231.0           True  INTERMEDIATE       5.0
# 95    274.0    263.0      NaN    262.0          False  INTERMEDIATE       6.0
# 64    273.0    252.0    290.0      NaN          False  INTERMEDIATE       7.0
# 11      NaN      NaN      NaN    251.0          False  INTERMEDIATE       8.0
#
#    FreshTyre      Team            LapStartTime             LapStartDate  \
# 42     False  Williams  0 days 00:24:20.213000  2024-08-24 09:40:32.421
# 85     False  Williams  0 days 00:25:53.049000  2024-08-24 09:42:05.257
# 95     False  Williams  0 days 00:27:17.056000  2024-08-24 09:43:29.264
# 64     False  Williams  0 days 01:12:25.417000  2024-08-24 10:28:37.625
# 11     False  Williams  0 days 01:13:58.487000  2024-08-24 10:30:10.695
#
#    TrackStatus  Position  Deleted DeletedReason  FastF1Generated IsAccurate  \
# 42           1       NaN    False                          False      False
# 85           1       NaN    False                          False       True
# 95         125       NaN    False                          False      False
# 64           1       NaN    False                          False      False
# 11           1       NaN    False                          False      False
#
#     Year                GP
# 42  2024  Dutch Grand Prix
# 85  2024  Dutch Grand Prix
# 95  2024  Dutch Grand Prix
# 64  2024  Dutch Grand Prix
# 11  2024  Dutch Grand Prix

# %%
#Convert LapTime to Time Delta for plotting on Y Axis
GP_fp3['LapTime_TD']= pd.to_timedelta(GP_fp3["LapTime"])
GP_fp3["LapTime"]=GP_fp3['LapTime'].str.split('days ').str[1]
GP_fp3.loc[:, "LapTime (s)"] = GP_fp3["LapTime_TD"].dt.total_seconds()

# %% [markdown]
# # Fastest Driver in each lap

# %%
GP_fp3['s1_TD']= pd.to_timedelta(GP_fp3["Sector1Time"])
GP_fp3['s2_TD']= pd.to_timedelta(GP_fp3["Sector2Time"])
GP_fp3['s3_TD']= pd.to_timedelta(GP_fp3["Sector3Time"])

GP_fp3.loc[:, "Time S1 (s)"] = GP_fp3["s1_TD"].dt.total_seconds()
GP_fp3.loc[:, "Time S2 (s)"] = GP_fp3["s2_TD"].dt.total_seconds()
GP_fp3.loc[:, "Time S3 (s)"] = GP_fp3["s3_TD"].dt.total_seconds()

# %%
GP_fp3_Rk=GP_fp3[GP_fp3["LapTime"]!="NaT"]
GP_fp3_Rk["LAP_RK"] = GP_fp3_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S1_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S2_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["S3_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
GP_fp3_Rk["Race_RK"] = GP_fp3_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

# %%
GP_fp3_Sectors=GP_fp3_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
GP_fp3_Sectors=GP_fp3_Sectors.fillna(0)
GP_fp3_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
# Out:
#    Driver  LapNumber  Time S1 (s)  Time S2 (s)  Time S3 (s) LapTime  \
# 42    ALB          1          0.0       31.608       27.348       0
# 34    ALO          1          0.0       32.903       28.293       0
# 28    BOT          1          0.0       36.536       36.517       0
# 44    GAS          1          0.0       31.313       27.726       0
# 57    HAM          1          0.0       30.254       28.622       0
#
#     LapTime (s)      Compound  Year                GP  LAP_RK  S1_RK  S2_RK  \
# 42          0.0  INTERMEDIATE  2024  Dutch Grand Prix     0.0    0.0    8.0
# 34          0.0  INTERMEDIATE  2024  Dutch Grand Prix     0.0    0.0   12.0
# 28          0.0           WET  2024  Dutch Grand Prix     0.0    0.0   18.0
# 44          0.0  INTERMEDIATE  2024  Dutch Grand Prix     0.0    0.0    7.0
# 57          0.0  INTERMEDIATE  2024  Dutch Grand Prix     0.0    0.0    4.0
#
#     S3_RK
# 42    3.0
# 34    7.0
# 28   16.0
# 44    5.0
# 57    9.0

# %%
#get a combined view for fastest drivers in the entire lap, S1, S2, and S3
Fastest_Lap_fp3=GP_fp3_Sectors[GP_fp3_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_Lap_fp3.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
Fastest_sector1_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector1_fp3.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
Fastest_sector2_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector2_fp3.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
Fastest_sector3_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
Fastest_sector3_fp3.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
Fast_Laps_fp3=Fastest_Lap_fp3.merge(Fastest_sector1_fp3,on=['LapNumber']).merge(Fastest_sector2_fp3,on=['LapNumber']).merge(Fastest_sector3_fp3,on=['LapNumber'])
Fast_Laps_fp3=Fast_Laps_fp3[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
Fast_Laps_fp3=Fast_Laps_fp3.reset_index(drop=True)
Fast_Laps_fp3.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Dutch Grand Prix  2024          2  00:01:23.772000       83.772
# 1  Dutch Grand Prix  2024          3  00:01:21.643000       81.643
# 2  Dutch Grand Prix  2024          4  00:01:20.311000       80.311
# 3  Dutch Grand Prix  2024          5  00:01:21.387000       81.387
# 4  Dutch Grand Prix  2024          6  00:01:21.155000       81.155
#
#   Fastest Lap  Lap Compound  Time S1 (s) Fastest S1   S1 Compound  \
# 0         NOR  INTERMEDIATE       29.555        STR  INTERMEDIATE
# 1         OCO  INTERMEDIATE       28.493        OCO  INTERMEDIATE
# 2         GAS  INTERMEDIATE       27.933        GAS  INTERMEDIATE
# 3         NOR  INTERMEDIATE       28.486        ALO  INTERMEDIATE
# 4         BOT  INTERMEDIATE       28.149        BOT  INTERMEDIATE
#
#    Time S2 (s) Fastest S2   S2 Compound  Time S3 (s) Fastest S3   S3 Compound
# 0       28.387        NOR  INTERMEDIATE       25.559        HAM  INTERMEDIATE
# 1       27.912        STR  INTERMEDIATE       25.036        OCO  INTERMEDIATE
# 2       27.420        PIA  INTERMEDIATE       24.813        GAS  INTERMEDIATE
# 3       27.707        NOR  INTERMEDIATE       24.870        NOR  INTERMEDIATE
# 4       27.223        PIA  INTERMEDIATE       25.143        BOT  INTERMEDIATE

# %%
Fast_Laps_fp3['color'] = Fast_Laps_fp3['Fastest Lap'].apply(driver_color)
Fast_Laps_fp3.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 0  Dutch Grand Prix  2024          2  00:01:23.772000       83.772
# 1  Dutch Grand Prix  2024          3  00:01:21.643000       81.643
# 2  Dutch Grand Prix  2024          4  00:01:20.311000       80.311
# 3  Dutch Grand Prix  2024          5  00:01:21.387000       81.387
# 4  Dutch Grand Prix  2024          6  00:01:21.155000       81.155
#
#   Fastest Lap  Lap Compound  Time S1 (s) Fastest S1   S1 Compound  \
# 0         NOR  INTERMEDIATE       29.555        STR  INTERMEDIATE
# 1         OCO  INTERMEDIATE       28.493        OCO  INTERMEDIATE
# 2         GAS  INTERMEDIATE       27.933        GAS  INTERMEDIATE
# 3         NOR  INTERMEDIATE       28.486        ALO  INTERMEDIATE
# 4         BOT  INTERMEDIATE       28.149        BOT  INTERMEDIATE
#
#    Time S2 (s) Fastest S2   S2 Compound  Time S3 (s) Fastest S3   S3 Compound  \
# 0       28.387        NOR  INTERMEDIATE       25.559        HAM  INTERMEDIATE
# 1       27.912        STR  INTERMEDIATE       25.036        OCO  INTERMEDIATE
# 2       27.420        PIA  INTERMEDIATE       24.813        GAS  INTERMEDIATE
# 3       27.707        NOR  INTERMEDIATE       24.870        NOR  INTERMEDIATE
# 4       27.223        PIA  INTERMEDIATE       25.143        BOT  INTERMEDIATE
#
#      color
# 0  #FF8000
# 1  #0093cc
# 2  #0093cc
# 3  #FF8000
# 4  #52e252

# %%
LapTime_fp3_ordered=Fast_Laps_fp3.sort_values(by=['LapTime (s)'])
LapTime_fp3_ordered.head()
# Out:
#                  GP  Year  LapNumber          LapTime  LapTime (s)  \
# 2  Dutch Grand Prix  2024          4  00:01:20.311000       80.311
# 5  Dutch Grand Prix  2024          8  00:01:20.450000       80.450
# 4  Dutch Grand Prix  2024          6  00:01:21.155000       81.155
# 3  Dutch Grand Prix  2024          5  00:01:21.387000       81.387
# 1  Dutch Grand Prix  2024          3  00:01:21.643000       81.643
#
#   Fastest Lap  Lap Compound  Time S1 (s) Fastest S1   S1 Compound  \
# 2         GAS  INTERMEDIATE       27.933        GAS  INTERMEDIATE
# 5         MAG  INTERMEDIATE       27.942        MAG  INTERMEDIATE
# 4         BOT  INTERMEDIATE       28.149        BOT  INTERMEDIATE
# 3         NOR  INTERMEDIATE       28.486        ALO  INTERMEDIATE
# 1         OCO  INTERMEDIATE       28.493        OCO  INTERMEDIATE
#
#    Time S2 (s) Fastest S2   S2 Compound  Time S3 (s) Fastest S3   S3 Compound  \
# 2       27.420        PIA  INTERMEDIATE       24.813        GAS  INTERMEDIATE
# 5       27.701        MAG  INTERMEDIATE       24.807        MAG  INTERMEDIATE
# 4       27.223        PIA  INTERMEDIATE       25.143        BOT  INTERMEDIATE
# 3       27.707        NOR  INTERMEDIATE       24.870        NOR  INTERMEDIATE
# 1       27.912        STR  INTERMEDIATE       25.036        OCO  INTERMEDIATE
#
#      color
# 2  #0093cc
# 5  #B6BABD
# 4  #52e252
# 3  #FF8000
# 1  #0093cc

# %%
import plotly.graph_objects as go
# colors = n_colors('rgb(255, 200, 200)', 'rgb(200, 0, 0)', 9, colortype='rgb')

fig_fp3 = go.Figure(go.Table
 (header={"values": LapTime_fp3_ordered.columns},
  cells=dict(
    values=LapTime_fp3_ordered.T.values,
    fill_color=[LapTime_fp3_ordered.color],
    align='center', font=dict(color='white', size=11)
    ))
 )

# fig_fp3.update_layout(
#     updatemenus=[
#         {
#             "buttons": [
#                 {
#                     "label": c,
#                     "method": "update",
#                     "args": [
#                         {
#                             "cells": {
#                                 "values": LapTime_fp3_ordered.T.values
#                                 if c == "All"
#                                 else LapTime_fp3_ordered.loc[LapTime_fp3_ordered["LapNumber"].eq(c)].T.values
#                             }
#                         }
#                     ],
#                 }
#                 for c in ["All"] + LapTime_fp3_ordered["LapNumber"].unique().tolist()
#             ]
#         }
#     ]
# )
fig_fp3.update_layout(
    title="FP3 Fastest Lap and Sector Times Ordered By Lap Times",
        title_x=0.5,
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=13,
        color="Black"
    ),
    height=780,
    width=1200,
    title_font_family="PT Sans Narrow",
    margin=dict(l=5, r=5, t=35, b=5),
)

fig_fp3.show()

# %%
fig_fp3.write_html("{} {} FP3 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(year,gp),full_html=False, include_plotlyjs='cdn')

# %%
#Multi GP Plot FP1

# %%
def driver_color(driver):
    if driver =="VER":
        return "#3860C6"
    elif driver =="PER":
        return '#3860C6'
    elif driver =="NOR":
        return '#FF8000'
    elif driver =="PIA":
        return '#FF8000'
    elif driver =="LEC":
        return '#E80020'
    elif driver =="SAI":
        return '#E80020'
    elif driver =="HAM":
        return '#27F4D2'
    elif driver =="RUS":
        return '#27F4D2'
    elif driver =="ALO":
        return '#229971'
    elif driver =="STR":
        return '#229971'
    elif driver =="GAS":
        return '#0093cc'
    elif driver =="OCO":
        return '#0093cc'
    elif driver =="MAG":
        return '#B6BABD'
    elif driver =="HUL":
        return '#B6BABD'
    elif driver =="ZHO":
        return '#52e252'
    elif driver =="BOT":
        return '#52e252'
    elif driver =="ALB":
        return '#64C4FF'
    elif driver =="SAR":
        return '#64C4FF'
    elif driver =="TSU":
        return '#6692FF'
    elif driver =="RIC":
        return '#6692FF'
    else:
        return '#3860C6'

# %%
#2024
race_multi=["Bahrain Grand Prix", "Saudi Arabian Grand Prix", "Australian Grand Prix", "Japanese Grand Prix","Chinese Grand Prix","Miami Grand Prix","Emilia Romagna Grand Prix","Monaco Grand Prix","Canadian Grand Prix","Spanish Grand Prix","Austrian Grand Prix","British Grand Prix","Hungarian Grand Prix","Belgian Grand Prix"]
#2023
# race_multi=["Abu Dhabi Grand Prix","Australian Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Canadian Grand Prix","Dutch Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Japanese Grand Prix","Las Vegas Grand Prix","Mexico City Grand Prix","Miami Grand Prix","Monaco Grand Prix","Pre-Season Testing","Qatar Grand Prix","Saudi Arabian Grand Prix","Singapore Grand Prix","Spanish Grand Prix","São Paulo Grand Prix","United States Grand Prix"]
# 2022
# race_multi=["Abu Dhabi Grand Prix","Australian Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Canadian Grand Prix","Dutch Grand Prix","Emilia Romagna Grand Prix","French Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Japanese Grand Prix","Mexico City Grand Prix","Miami Grand Prix","Monaco Grand Prix","Saudi Arabian Grand Prix","Singapore Grand Prix","Spanish Grand Prix","São Paulo Grand Prix","United States Grand Prix"]
#2021
# race_multi=["Abu Dhabi Grand Prix","Austrian Grand Prix","Azerbaijan Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Dutch Grand Prix","Emilia Romagna Grand Prix","French Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Mexico City Grand Prix","Monaco Grand Prix","Portuguese Grand Prix","Qatar Grand Prix","Russian Grand Prix","Saudi Arabian Grand Prix","Spanish Grand Prix","Styrian Grand Prix","São Paulo Grand Prix","Turkish Grand Prix","United States Grand Prix"]
#2020
# race_multi=["70th Anniversary Grand Prix","Abu Dhabi Grand Prix","Austrian Grand Prix","Bahrain Grand Prix","Belgian Grand Prix","British Grand Prix","Eifel Grand Prix","Emilia Romagna Grand Prix","Hungarian Grand Prix","Italian Grand Prix","Portuguese Grand Prix","Russian Grand Prix","Sakhir Grand Prix","Spanish Grand Prix","Styrian Grand Prix","Turkish Grand Prix","Tuscan Grand Prix"]

year_multi=2024
for i in race_multi:
    df_bq_fp1=df_bq2_fp1[(df_bq2_fp1["GP"]==i)&(df_bq2_fp1["Year"]==year_multi)]
    GP_fp1=df_bq_fp1
    GP_fp1["LapNumber"]=GP_fp1["LapNumber"].astype(int)
    GP_fp1=GP_fp1.sort_values(['Driver','LapNumber'])
    GP_fp1["DriverNumber"]=GP_fp1["DriverNumber"].astype(int)
    # year=GP_fp1['Year'].iloc[0]
    # gp=GP_fp1['GP'].iloc[0]
    GP_fp1['LapTime_TD']= pd.to_timedelta(GP_fp1["LapTime"])
    GP_fp1["LapTime"]=GP_fp1['LapTime'].str.split('days ').str[1]
    GP_fp1.loc[:, "LapTime (s)"] = GP_fp1["LapTime_TD"].dt.total_seconds()
    GP_fp1['s1_TD']= pd.to_timedelta(GP_fp1["Sector1Time"])
    GP_fp1['s2_TD']= pd.to_timedelta(GP_fp1["Sector2Time"])
    GP_fp1['s3_TD']= pd.to_timedelta(GP_fp1["Sector3Time"])

    GP_fp1.loc[:, "Time S1 (s)"] = GP_fp1["s1_TD"].dt.total_seconds()
    GP_fp1.loc[:, "Time S2 (s)"] = GP_fp1["s2_TD"].dt.total_seconds()
    GP_fp1.loc[:, "Time S3 (s)"] = GP_fp1["s3_TD"].dt.total_seconds()
    GP_fp1_Rk=GP_fp1[GP_fp1["LapTime"]!="NaT"]
    GP_fp1_Rk["LAP_RK"] = GP_fp1_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S1_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S2_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["S3_RK"] = GP_fp1_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
    GP_fp1_Rk["Race_RK"] = GP_fp1_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)
    GP_fp1_Sectors=GP_fp1_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
    GP_fp1_Sectors=GP_fp1_Sectors.fillna(0)
    Fastest_Lap_fp1=GP_fp1_Sectors[GP_fp1_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_Lap_fp1.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
    Fastest_sector1_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector1_fp1.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
    Fastest_sector2_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector2_fp1.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
    Fastest_sector3_fp1=GP_fp1_Sectors[GP_fp1_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
    Fastest_sector3_fp1.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
    Fast_Laps_fp1=Fastest_Lap_fp1.merge(Fastest_sector1_fp1,on=['LapNumber']).merge(Fastest_sector2_fp1,on=['LapNumber']).merge(Fastest_sector3_fp1,on=['LapNumber'])
    Fast_Laps_fp1=Fast_Laps_fp1[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
    Fast_Laps_fp1=Fast_Laps_fp1.reset_index(drop=True)
    Fast_Laps_fp1['color'] = Fast_Laps_fp1['Fastest Lap'].apply(driver_color)
    LapTime_fp1_ordered=Fast_Laps_fp1.sort_values(by=['LapTime (s)'])
    fig_fp1 = go.Figure(go.Table
    (header={"values": LapTime_fp1_ordered.columns},
    cells=dict(
        values=LapTime_fp1_ordered.T.values,
        fill_color=[LapTime_fp1_ordered.color],
        align='center', font=dict(color='white', size=11)
        ))
    )
    fig_fp1.update_layout(
        title="FP1 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi, i),
            title_x=0.5,
        yaxis = dict(tickfont = dict(size=15)),
        xaxis = dict(tickfont = dict(size=15)),
        font=dict(
            family="PT Sans Narrow",
            size=13,
            color="Black"
        ),
        height=780,
        width=1200,
        title_font_family="PT Sans Narrow",
        margin=dict(l=5, r=5, t=35, b=5),
    )
    fig_fp1.write_html("{} {} FP1 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(year_multi, i),include_plotlyjs='cdn')
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/1988034499.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Multi GP Plot FP2

# %%
for i in race_multi:
    try:
        df_bq_fp2=df_bq2_fp2[(df_bq2_fp2["GP"]==i)&(df_bq2_fp2["Year"]==year_multi)]
        GP_fp2=df_bq_fp2
        GP_fp2["LapNumber"]=GP_fp2["LapNumber"].astype(int)
        GP_fp2=GP_fp2.sort_values(['Driver','LapNumber'])
        GP_fp2["DriverNumber"]=GP_fp2["DriverNumber"].astype(int)
        year=GP_fp2['Year'].iloc[0]
        gp=GP_fp2['GP'].iloc[0]
        #Convert LapTime to Time Delta for plotting on Y Axis
        GP_fp2['LapTime_TD']= pd.to_timedelta(GP_fp2["LapTime"])
        GP_fp2["LapTime"]=GP_fp2['LapTime'].str.split('days ').str[1]
        GP_fp2.loc[:, "LapTime (s)"] = GP_fp2["LapTime_TD"].dt.total_seconds()
        # Fastest Driver in each lap
        GP_fp2['s1_TD']= pd.to_timedelta(GP_fp2["Sector1Time"])
        GP_fp2['s2_TD']= pd.to_timedelta(GP_fp2["Sector2Time"])
        GP_fp2['s3_TD']= pd.to_timedelta(GP_fp2["Sector3Time"])

        GP_fp2.loc[:, "Time S1 (s)"] = GP_fp2["s1_TD"].dt.total_seconds()
        GP_fp2.loc[:, "Time S2 (s)"] = GP_fp2["s2_TD"].dt.total_seconds()
        GP_fp2.loc[:, "Time S3 (s)"] = GP_fp2["s3_TD"].dt.total_seconds()
        GP_fp2_Rk=GP_fp2[GP_fp2["LapTime"]!="NaT"]
        GP_fp2_Rk["LAP_RK"] = GP_fp2_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S1_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S2_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["S3_RK"] = GP_fp2_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
        GP_fp2_Rk["Race_RK"] = GP_fp2_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

        GP_fp2_Sectors=GP_fp2_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
        GP_fp2_Sectors=GP_fp2_Sectors.fillna(0)
        GP_fp2_Sectors.sort_values(by=["LapNumber","S1_RK"]).head()
        #get a combined view for fastest drivers in the entire lap, S1, S2, and S3
        Fastest_Lap_fp2=GP_fp2_Sectors[GP_fp2_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_Lap_fp2.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
        Fastest_sector1_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector1_fp2.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
        Fastest_sector2_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector2_fp2.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
        Fastest_sector3_fp2=GP_fp2_Sectors[GP_fp2_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector3_fp2.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
        Fast_Laps_fp2=Fastest_Lap_fp2.merge(Fastest_sector1_fp2,on=['LapNumber']).merge(Fastest_sector2_fp2,on=['LapNumber']).merge(Fastest_sector3_fp2,on=['LapNumber'])
        Fast_Laps_fp2=Fast_Laps_fp2[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
        Fast_Laps_fp2=Fast_Laps_fp2.reset_index(drop=True)
        Fast_Laps_fp2['color'] = Fast_Laps_fp2['Fastest Lap'].apply(driver_color)
        LapTime_fp2_ordered=Fast_Laps_fp2.sort_values(by=['LapTime (s)'])
        fig_fp2 = go.Figure(go.Table
        (header={"values": LapTime_fp2_ordered.columns},
        cells=dict(
            values=LapTime_fp2_ordered.T.values,
            fill_color=[LapTime_fp2_ordered.color],
            align='center', font=dict(color='white', size=11)
            ))
        )
        fig_fp2.update_layout(
            title="FP2 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi,i),
                title_x=0.5,
            yaxis = dict(tickfont = dict(size=15)),
            xaxis = dict(tickfont = dict(size=15)),
            font=dict(
                family="PT Sans Narrow",
                size=13,
                color="Black"
            ),
            height=780,
            width=1200,
            title_font_family="PT Sans Narrow",
            margin=dict(l=5, r=5, t=35, b=5),
        )
        fig_fp2.write_html("{} {} FP2 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(year_multi,i),include_plotlyjs='cdn')
    except:
        continue
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/290820071.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Multi GP Plot FP3

# %%
for i in race_multi:
    try:
        df_bq_fp3=df_bq2_fp3[(df_bq2_fp3["GP"]==i)&(df_bq2_fp3["Year"]==year_multi)]
        GP_fp3=df_bq_fp3
        GP_fp3["LapNumber"]=GP_fp3["LapNumber"].astype(int)
        GP_fp3=GP_fp3.sort_values(['Driver','LapNumber'])
        GP_fp3["DriverNumber"]=GP_fp3["DriverNumber"].astype(int)
        year=GP_fp3['Year'].iloc[0]
        gp=GP_fp3['GP'].iloc[0]
        #Convert LapTime to Time Delta for plotting on Y Axis
        GP_fp3['LapTime_TD']= pd.to_timedelta(GP_fp3["LapTime"])
        GP_fp3["LapTime"]=GP_fp3['LapTime'].str.split('days ').str[1]
        GP_fp3.loc[:, "LapTime (s)"] = GP_fp3["LapTime_TD"].dt.total_seconds()
        # Fastest Driver in each lap
        GP_fp3['s1_TD']= pd.to_timedelta(GP_fp3["Sector1Time"])
        GP_fp3['s2_TD']= pd.to_timedelta(GP_fp3["Sector2Time"])
        GP_fp3['s3_TD']= pd.to_timedelta(GP_fp3["Sector3Time"])

        GP_fp3.loc[:, "Time S1 (s)"] = GP_fp3["s1_TD"].dt.total_seconds()
        GP_fp3.loc[:, "Time S2 (s)"] = GP_fp3["s2_TD"].dt.total_seconds()
        GP_fp3.loc[:, "Time S3 (s)"] = GP_fp3["s3_TD"].dt.total_seconds()
        GP_fp3_Rk=GP_fp3[GP_fp3["LapTime"]!="NaT"]
        GP_fp3_Rk["LAP_RK"] = GP_fp3_Rk.groupby("LapNumber")["LapTime (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S1_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S1 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S2_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S2 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["S3_RK"] = GP_fp3_Rk.groupby("LapNumber")["Time S3 (s)"].rank(method="dense", ascending=True)
        GP_fp3_Rk["Race_RK"] = GP_fp3_Rk.groupby("GP")["LapTime (s)"].rank(method="dense", ascending=True)

        GP_fp3_Sectors=GP_fp3_Rk[["Driver","LapNumber","Time S1 (s)","Time S2 (s)","Time S3 (s)","LapTime","LapTime (s)","Compound","Year","GP","LAP_RK","S1_RK","S2_RK","S3_RK"]]
        GP_fp3_Sectors=GP_fp3_Sectors.fillna(0)
        #get a combined view for fastest drivers in the entire lap, S1, S2, and S3
        Fastest_Lap_fp3=GP_fp3_Sectors[GP_fp3_Sectors["LAP_RK"]==1][["GP","Year","LapNumber","LapTime","LapTime (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_Lap_fp3.columns=["GP","Year","LapNumber","LapTime","LapTime (s)","Lap Compound","Fastest Lap"]
        Fastest_sector1_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S1_RK"]==1][["LapNumber","Time S1 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector1_fp3.columns=["LapNumber","Time S1 (s)","S1 Compound","Fastest S1"]
        Fastest_sector2_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S2_RK"]==1][["LapNumber","Time S2 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector2_fp3.columns=["LapNumber","Time S2 (s)","S2 Compound","Fastest S2"]
        Fastest_sector3_fp3=GP_fp3_Sectors[GP_fp3_Sectors["S3_RK"]==1][["LapNumber","Time S3 (s)","Compound","Driver"]].reset_index(drop=True)
        Fastest_sector3_fp3.columns=["LapNumber","Time S3 (s)","S3 Compound","Fastest S3"]
        Fast_Laps_fp3=Fastest_Lap_fp3.merge(Fastest_sector1_fp3,on=['LapNumber']).merge(Fastest_sector2_fp3,on=['LapNumber']).merge(Fastest_sector3_fp3,on=['LapNumber'])
        Fast_Laps_fp3=Fast_Laps_fp3[["GP","Year","LapNumber","LapTime","LapTime (s)","Fastest Lap","Lap Compound","Time S1 (s)","Fastest S1","S1 Compound","Time S2 (s)","Fastest S2","S2 Compound","Time S3 (s)","Fastest S3","S3 Compound"]].sort_values(by=["LapNumber"])
        Fast_Laps_fp3=Fast_Laps_fp3.reset_index(drop=True)
        Fast_Laps_fp3['color'] = Fast_Laps_fp3['Fastest Lap'].apply(driver_color)
        LapTime_fp3_ordered=Fast_Laps_fp3.sort_values(by=['LapTime (s)'])

        fig_fp3 = go.Figure(go.Table
        (header={"values": LapTime_fp3_ordered.columns},
        cells=dict(
            values=LapTime_fp3_ordered.T.values,
            fill_color=[LapTime_fp3_ordered.color],
            align='center', font=dict(color='white', size=11)
            ))
        )
        fig_fp3.update_layout(
            title="FP3 Fastest Lap and Sector Times Ordered By Lap Times For The {} {}".format(year_multi, i),
                title_x=0.5,
            yaxis = dict(tickfont = dict(size=15)),
            xaxis = dict(tickfont = dict(size=15)),
            font=dict(
                family="PT Sans Narrow",
                size=13,
                color="Black"
            ),
            height=780,
            width=1200,
            title_font_family="PT Sans Narrow",
            margin=dict(l=5, r=5, t=35, b=5),
        )
        fig_fp3.write_html("{} {} FP3 Fastest Lap Times and Sectors Ordered by Lap Times.html".format(year_multi, i),include_plotlyjs='cdn')
    except:
        continue
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_26512/2753040708.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
