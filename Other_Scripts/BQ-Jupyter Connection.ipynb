# %%
import pandas as pd
import pandas_gbq
from google.cloud import bigquery
# %load_ext google.cloud.bigquery
pandas_gbq.context.project='perceptive-ivy-290216'
pandas_gbq.context.dialect='standard'

# %%
import google.auth
google.auth.default()
credentials, project_id = google.auth.default()

# %%
project_id='perceptive-ivy-290216'

# %%
project_id='perceptive-ivy-290216'
query=f"""
    SELECT *
    FROM
    perceptive-ivy-290216.nba_api_standings.standings_05_onward
    WHERE SEASON='2022-23'
"""
a=pandas_gbq.read_gbq(query,project_id,dialect='standard')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/bigquery/table.py:2379: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(

# %%
a
# Out:
#    LeagueID SeasonID      TeamID       TeamCity       TeamName Conference  \
# 0        00    22022  1610612737        Atlanta          Hawks       East
# 1        00    22022  1610612741        Chicago          Bulls       East
# 2        00    22022  1610612761        Toronto        Raptors       East
# 3        00    22022  1610612748          Miami           Heat       East
# 4        00    22022  1610612740    New Orleans       Pelicans       West
# 5        00    22022  1610612747    Los Angeles         Lakers       West
# 6        00    22022  1610612750      Minnesota   Timberwolves       West
# 7        00    22022  1610612760  Oklahoma City        Thunder       West
# 8        00    22022  1610612745        Houston        Rockets       West
# 9        00    22022  1610612759    San Antonio          Spurs       West
# 10       00    22022  1610612738         Boston        Celtics       East
# 11       00    22022  1610612739      Cleveland      Cavaliers       East
# 12       00    22022  1610612751       Brooklyn           Nets       East
# 13       00    22022  1610612752       New York         Knicks       East
# 14       00    22022  1610612755   Philadelphia          76ers       East
# 15       00    22022  1610612758     Sacramento          Kings       West
# 16       00    22022  1610612744   Golden State       Warriors       West
# 17       00    22022  1610612746             LA       Clippers       West
# 18       00    22022  1610612756        Phoenix           Suns       West
# 19       00    22022  1610612763        Memphis      Grizzlies       West
# 20       00    22022  1610612749      Milwaukee          Bucks       East
# 21       00    22022  1610612743         Denver        Nuggets       West
# 22       00    22022  1610612753        Orlando          Magic       East
# 23       00    22022  1610612754        Indiana         Pacers       East
# 24       00    22022  1610612764     Washington        Wizards       East
# 25       00    22022  1610612765        Detroit        Pistons       East
# 26       00    22022  1610612766      Charlotte        Hornets       East
# 27       00    22022  1610612742         Dallas      Mavericks       West
# 28       00    22022  1610612757       Portland  Trail Blazers       West
# 29       00    22022  1610612762           Utah           Jazz       West
#
#    ConferenceRecord  PlayoffRank ClinchIndicator   Division  ...   Jun   Jul  \
# 0             26-26            8                  Southeast  ...  None  None
# 1             27-25           10                    Central  ...  None  None
# 2             26-26            9                   Atlantic  ...  None  None
# 3             24-28            7            - se  Southeast  ...  None  None
# 4             29-23            9                  Southwest  ...  None  None
# 5             27-25            7                    Pacific  ...  None  None
# 6             29-23            8                  Northwest  ...  None  None
# 7             25-27           10                  Northwest  ...  None  None
# 8             12-40           14             - o  Southwest  ...  None  None
# 9             10-42           15             - o  Southwest  ...  None  None
# 10            34-18            2             - a   Atlantic  ...  None  None
# 11            34-18            4             - x    Central  ...  None  None
# 12            30-22            6             - x   Atlantic  ...  None  None
