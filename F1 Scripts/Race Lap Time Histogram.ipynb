# %%
import pandas as pd
import numpy as np
import itertools
import datetime
import matplotlib.pyplot as plt
from datetime import *
from datetime import datetime, timedelta, date
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
project_id = "perceptive-ivy-290216"

# Standard plotly imports
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# from google.colab import auth
# auth.authenticate_user()
# print('Authenticated')

# %%
query2=f"""
SELECT
*
FROM `perceptive-ivy-290216.f1_api.race_lap_time`  A
WHERE
# A.Year=2023
# AND
A.GP="Austrian Grand Prix"
# AND A.DRIVER='HAM'
ORDER BY LapNumber, LapStartTime
"""
track2=pd.read_gbq(query2,project_id,dialect='standard')
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4170/804458899.py:12: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   track2=pd.read_gbq(query2,project_id,dialect='standard')

# %%
track2.head()
year=track2['Year'][0]
gp=track2['GP'][0]
# Out:
#                      Time Driver DriverNumber                 LapTime  \
# 0  0 days 01:03:23.460000    OCO           31                     NaT
# 1                    None    BAR         None  0 days 00:01:23.884000
# 2                    None    COU         None  0 days 00:01:26.997000
# 3                    None    FIS         None  0 days 00:01:29.443000
# 4                    None    MAG         None  0 days 00:01:25.025000
#
#    LapNumber  Stint PitOutTime PitInTime Sector1Time Sector2Time Sector3Time  \
# 0        0.0    1.0        NaT       NaT         NaT         NaT         NaT
# 1        1.0    NaN       None      None        None        None        None
# 2        1.0    NaN       None      None        None        None        None
# 3        1.0    NaN       None      None        None        None        None
# 4        1.0    NaN       None      None        None        None        None
#
#   Sector1SessionTime Sector2SessionTime Sector3SessionTime  SpeedI1  SpeedI2  \
# 0                NaT                NaT                NaT      NaN      NaN
# 1               None               None               None      NaN      NaN
# 2               None               None               None      NaN      NaN
# 3               None               None               None      NaN      NaN
# 4               None               None               None      NaN      NaN
#
#    SpeedFL  SpeedST IsPersonalBest Compound  TyreLife FreshTyre     Team  \
# 0      NaN      NaN          False   MEDIUM       1.0      True   Alpine
# 1      NaN      NaN           None     None       NaN      None  Stewart
# 2      NaN      NaN           None     None       NaN      None  McLaren
# 3      NaN      NaN           None     None       NaN      None   Jordan
# 4      NaN      NaN           None     None       NaN      None  Stewart
#
#              LapStartTime LapStartDate TrackStatus  Position  Deleted  \
# 0  0 days 01:01:55.477000          NaT           4       1.0    False
# 1                    None         None        None       2.0     <NA>
# 2                    None         None        None       7.0     <NA>
# 3                    None         None        None      12.0     <NA>
# 4                    None         None        None       4.0     <NA>
#
#   DeletedReason  FastF1Generated IsAccurate  Year                   GP
# 0                           True      False  2021  Austrian Grand Prix
# 1          None             <NA>       None  1997  Austrian Grand Prix
# 2          None             <NA>       None  1997  Austrian Grand Prix
# 3          None             <NA>       None  1997  Austrian Grand Prix
# 4          None             <NA>       None  1997  Austrian Grand Prix

# %%
track2['LapTime']= pd.to_timedelta(track2["LapTime"])

# %%
quicklaps=track2[track2["LapTime"]<track2['LapTime'].min()*1.14]
# quicklaps=track2
quicklaps.head()
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 206                    None    BOT           77 0 days 00:01:11.506000
# 218                    None    RIC            3 0 days 00:01:14.564000
# 222                    None    VET            5 0 days 00:01:12.975000
# 235  0 days 00:07:58.823000    VER           33 0 days 00:01:15.229000
# 237  0 days 00:07:56.598000    HAM           44 0 days 00:01:13.004000
#
#      LapNumber  Stint              PitOutTime PitInTime Sector1Time  \
# 206        1.0    NaN                    None      None        None
# 218        1.0    NaN                    None      None        None
# 222        1.0    NaN                    None      None        None
# 235        1.0    NaN  0 days 00:00:03.744000       NaT         NaT
# 237        1.0    NaN  0 days 00:00:03.744000       NaT         NaT
#
#                 Sector2Time             Sector3Time Sector1SessionTime  \
# 206                    None                    None               None
# 218                    None                    None               None
# 222                    None                    None               None
# 235  0 days 00:00:32.167000  0 days 00:00:22.151000                NaT
# 237  0 days 00:00:31.069000  0 days 00:00:21.268000                NaT
#
#          Sector2SessionTime      Sector3SessionTime  SpeedI1  SpeedI2  \
# 206                    None                    None      NaN      NaN
# 218                    None                    None      NaN      NaN
# 222                    None                    None      NaN      NaN
# 235  0 days 00:07:36.712000  0 days 00:07:58.915000    304.0    229.0
# 237  0 days 00:07:35.367000  0 days 00:07:56.690000    299.0    238.0
#
#      SpeedFL  SpeedST IsPersonalBest Compound  TyreLife FreshTyre  \
# 206      NaN      NaN           None     None       NaN      None
# 218      NaN      NaN           None     None       NaN      None
# 222      NaN      NaN           None     None       NaN      None
# 235    274.0    299.0          False      nan       NaN      True
# 237    275.0    297.0          False      nan       NaN      True
#
#                 Team            LapStartTime LapStartDate TrackStatus  \
# 206         Mercedes                    None         None        None
# 218         Red Bull                    None         None        None
# 222          Ferrari                    None         None        None
# 235  Red Bull Racing  0 days 00:06:43.395000          NaT           1
# 237         Mercedes  0 days 00:06:43.395000          NaT           1
#
#      Position  Deleted DeletedReason  FastF1Generated IsAccurate  Year  \
# 206       1.0     <NA>          None             <NA>       None  2017
# 218       3.0     <NA>          None             <NA>       None  2017
# 222       2.0     <NA>          None             <NA>       None  2017
# 235       3.0    False                          False      False  2018
# 237       1.0    False                          False      False  2018
#
#                       GP
# 206  Austrian Grand Prix
# 218  Austrian Grand Prix
# 222  Austrian Grand Prix
# 235  Austrian Grand Prix
# 237  Austrian Grand Prix

# %%
transformed_laps = quicklaps.copy()
transformed_laps.loc[:, "LapTime (s)"] = quicklaps["LapTime"].dt.total_seconds()

# %%
fig=px.histogram(
    transformed_laps[transformed_laps['Team']=="Red Bull Racing"],
    x="LapTime (s)",
    title="<b>Lap Time Histogram for the {} {}</b>".format(year,gp),
    # color='Team',
    template="plotly_dark",

color_discrete_map={
                 "Mercedes": "#6CD3BF",
                 "Red Bull Racing": "#3671C6",
                 "Alpine": "#2293D1",
                 "McLaren": "#FFA500",
                 "Haas": "#B6BABD",
                 "Williams": "#37BEDD",
                 "Alfa Romeo Racing": "#C92D4B",
                 "Ferrari": "#F91536",
                 "Aston Martin": "#358C75",
                 "AlphaTauri": "#5E8FAA" }
)
fig.update_traces(opacity=1)
fig.update_layout(
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="White"
    ),
    title_font_family="PT Sans Narrow"
#  "Arial", "Balto", "Courier New", "Droid Sans", "Droid Serif", "Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans", "Overpass", "PT Sans Narrow", "Raleway", "Times New Roman"
)
fig.show()

# %%
fig=px.histogram(
    transformed_laps[transformed_laps['Team']=="Mercedes"],
    x="LapTime (s)",
    title="<b>Lap Time Histogram for the {} {}</b>".format(year,gp),
    # color='Team',
    title="<b>Lap Time Histogram for the {} {}</b>".format(year,gp),
    template="plotly_dark",
    title="<b>Team Pace</b>",

color_discrete_map={
                 "Mercedes": "#6CD3BF",
                 "Red Bull Racing": "#3671C6",
                 "Alpine": "#2293D1",
                 "McLaren": "#FFA500",
                 "Haas": "#B6BABD",
                 "Williams": "#37BEDD",
                 "Alfa Romeo Racing": "#C92D4B",
                 "Ferrari": "#F91536",
                 "Aston Martin": "#358C75",
                 "AlphaTauri": "#5E8FAA" }
)
fig.update_traces(opacity=1)
fig.update_layout(
    yaxis = dict(tickfont = dict(size=15)),
    xaxis = dict(tickfont = dict(size=15)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="White"
    ),
    title_font_family="PT Sans Narrow"
#  "Arial", "Balto", "Courier New", "Droid Sans", "Droid Serif", "Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans", "Overpass", "PT Sans Narrow", "Raleway", "Times New Roman"
)
fig.show()

# %%
fig=px.histogram(
    transformed_laps[transformed_laps['Team']=="Ferrari"],
    title="<b>Lap Time Histogram for the {} {}</b>".format(year,gp),
    x="LapTime (s)",
    # color='Team',
    template="plotly_dark",
    title="<b>Team Pace</b>",

color_discrete_map={
                 "Mercedes": "#6CD3BF",
                 "Red Bull Racing": "#3671C6",
                 "Alpine": "#2293D1",
                 "McLaren": "#FFA500",
                 "Haas": "#B6BABD",
                 "Williams": "#37BEDD",
                 "Alfa Romeo Racing": "#C92D4B",
                 "Ferrari": "#F91536",
                 "Aston Martin": "#358C75",
                 "AlphaTauri": "#5E8FAA" }
)
fig.update_traces(opacity=1)
fig.update_layout(
    font_family="PT Sans Narrow",
    font_color="white")
fig.show()
