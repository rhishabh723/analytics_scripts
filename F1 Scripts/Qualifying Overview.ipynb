# %%
import pandas as pd
import numpy as np
import itertools
import datetime
import matplotlib.pyplot as plt
from datetime import *
from datetime import datetime, timedelta, date
# %load_ext google.colab.data_table
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
project_id = "perceptive-ivy-290216"

# Standard plotly imports
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
query2=f"""
SELECT * FROM `perceptive-ivy-290216.f1_api.qualifying_lap_time`
# WHERE YEAR=2023
# AND GP='Spanish Grand Prix'
"""
track3=pd.read_gbq(query2,project_id,dialect='standard')
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/2531623005.py:6: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   track3=pd.read_gbq(query2,project_id,dialect='standard')

# %%
track2=track3[(track3["GP"]=='British Grand Prix')&(track3["Year"]==2024)]
year=track2['Year'].iloc[0]
gp=track2['GP'].iloc[0]

# %%
Drivers=(track2['Driver'].unique())
Drivers
# Out:
# array(['RUS', 'HAM', 'NOR', 'VER', 'PIA', 'HUL', 'SAI', 'STR', 'ALB',
#        'ALO', 'LEC', 'SAR', 'TSU', 'ZHO', 'RIC', 'BOT', 'MAG', 'OCO',
#        'PER', 'GAS'], dtype=object)

# %%
track2["LapTime"].min()
# Out:
# '0 days 00:01:25.819000'

# %%
#Assign Rank for each entry point
track2["RK"] = track2.groupby(by=["Driver"])["LapTime"].rank(method="dense", ascending=True)
track2["RK"]= track2["RK"].astype(int)
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/2442521796.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/2442521796.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
track_fastest=track2[track2['RK']==1]
track_fastest
# Out:
#                         Time Driver DriverNumber                 LapTime  \
# 819   0 days 01:23:01.707000    RUS           63  0 days 00:01:25.819000
# 829   0 days 01:22:50.177000    HAM           44  0 days 00:01:25.990000
# 838   0 days 01:14:34.691000    NOR            4  0 days 00:01:26.030000
# 850   0 days 01:22:38.775000    VER            1  0 days 00:01:26.203000
# 860   0 days 01:14:22.585000    PIA           81  0 days 00:01:26.237000
# 868   0 days 01:22:30.054000    HUL           27  0 days 00:01:26.338000
# 875   0 days 01:14:44.976000    SAI           55  0 days 00:01:26.509000
# 886   0 days 01:22:20.331000    STR           18  0 days 00:01:26.585000
# 892   0 days 01:22:11.911000    ALB           23  0 days 00:01:26.640000
# 906   0 days 01:02:07.073000    LEC           16  0 days 00:01:27.097000
# 922   0 days 01:02:20.217000    TSU           22  0 days 00:01:27.269000
# 933   0 days 00:59:28.684000    ZHO           24  0 days 00:01:27.867000
# 945   0 days 00:35:02.950000    BOT           77  0 days 00:01:32.431000
# 949   0 days 00:35:16.945000    MAG           20  0 days 00:01:32.905000
# 954   0 days 00:37:40.803000    OCO           31  0 days 00:01:34.557000
# 956   0 days 00:17:50.753000    PER           11  0 days 00:01:38.348000
# 958   0 days 00:17:25.085000    GAS           10  0 days 00:01:39.804000
# 1117  0 days 01:02:29.709000    ALO           14  0 days 00:01:26.730000
# 1122  0 days 00:59:10.892000    SAR            2  0 days 00:01:27.175000
# 1126  0 days 01:03:08.596000    RIC            3  0 days 00:01:27.949000
#
#       LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
#
# 875           Ferrari  0 days 01:13:18.467000  2024-07-06 15:00:31.476
# 886      Aston Martin  0 days 01:20:53.746000  2024-07-06 15:08:06.755
# 892          Williams  0 days 01:20:45.271000  2024-07-06 15:07:58.280
# 906           Ferrari  0 days 01:00:39.976000  2024-07-06 14:47:52.985
# 922                RB  0 days 01:00:52.948000  2024-07-06 14:48:05.957
# 933       Kick Sauber  0 days 00:58:00.817000  2024-07-06 14:45:13.826
# 945       Kick Sauber  0 days 00:33:30.519000  2024-07-06 14:20:43.528
# 949      Haas F1 Team  0 days 00:33:44.040000  2024-07-06 14:20:57.049
# 954            Alpine  0 days 00:36:06.246000  2024-07-06 14:23:19.255
# 956   Red Bull Racing  0 days 00:16:12.405000  2024-07-06 14:03:25.414
# 958            Alpine  0 days 00:15:45.281000  2024-07-06 14:02:58.290
# 1117     Aston Martin  0 days 01:01:02.979000  2024-07-06 14:48:15.988
# 1122         Williams  0 days 00:57:43.717000  2024-07-06 14:44:56.726
# 1126               RB  0 days 01:01:40.647000  2024-07-06 14:48:53.656
#
#      TrackStatus  Position  Deleted DeletedReason  FastF1Generated IsAccurate  \
# 819            1       NaN    False                          False       True
# 829            1       NaN    False                          False       True
# 838            1       NaN    False                          False       True
# 850            1       NaN    False                          False       True
# 860            1       NaN    False                          False       True
# 868            1       NaN    False                          False       True
# 875            1       NaN    False                          False       True
# 886            1       NaN    False                          False       True
# 892            1       NaN    False                          False       True
# 906            1       NaN    False                          False       True
# 922            1       NaN    False                          False       True
# 933            1       NaN    False                          False       True
# 945            1       NaN    False                          False       True
# 949            1       NaN    False                          False       True
# 954            1       NaN    False                          False       True
# 956            1       NaN    False                          False       True
# 958            1       NaN    False                          False       True
# 1117           1       NaN    False                          False       True
# 1122           1       NaN    False                          False       True
# 1126           1       NaN    False                          False       True
#
#       Year                  GP  RK
# 819   2024  British Grand Prix   1
# 829   2024  British Grand Prix   1
# 838   2024  British Grand Prix   1
# 850   2024  British Grand Prix   1
# 860   2024  British Grand Prix   1
# 868   2024  British Grand Prix   1
# 875   2024  British Grand Prix   1
# 886   2024  British Grand Prix   1
# 892   2024  British Grand Prix   1
# 906   2024  British Grand Prix   1
# 922   2024  British Grand Prix   1
# 933   2024  British Grand Prix   1
# 945   2024  British Grand Prix   1
# 949   2024  British Grand Prix   1
# 954   2024  British Grand Prix   1
# 956   2024  British Grand Prix   1
# 958   2024  British Grand Prix   1
# 1117  2024  British Grand Prix   1
# 1122  2024  British Grand Prix   1
# 1126  2024  British Grand Prix   1

# %%
pole_lap = track_fastest["LapTime"].min()
track_fastest['LapTimeDelta']= pd.to_timedelta(track_fastest["LapTime"]) - pd.to_timedelta(pole_lap)
track_fastest['LapTimeDelta'] = track_fastest['LapTimeDelta'] + pd.to_datetime('1970/01/01')

track_fastest['LapTimeDelta2']= pd.to_timedelta(track_fastest["LapTime"]) - pd.to_timedelta(pole_lap)
track_fastest['LapTimeDelta2']=track_fastest['LapTimeDelta2'].astype(str)

track_fastest["LapTimeDelta2"]=track_fastest['LapTimeDelta2'].str.split('days ').str[1]

# track_fastest['LapTimeDelta']=track_fastest['LapTimeDelta'].astype(str)
# for index, row in track_fastest.iterrows():
#   if track_fastest.loc[index, 'LapTimeDelta']=="0 days 00:00:00":
#     track_fastest.loc[index, 'LapTimeDelta']="0 days 00:00:00.000000"
# track_fastest["LapTimeDelta"]=track_fastest['LapTimeDelta'].str.split('days ').str[1]
# track_fastest["LapTimeDelta"]=pd.to_datetime(track_fastest['LapTimeDelta'],format='%H:%M:%S.%f')

# track_fastest['LapTime']=track_fastest['LapTime'].astype(str)
track_fastest.head()
# Out:
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/3082977968.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/3082977968.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/3082977968.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/3082977968.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/x_/b65sxrpx6737wtqnt0ctv71w0000gn/T/ipykernel_4254/3082977968.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Time Driver DriverNumber                 LapTime  \
# 819  0 days 01:23:01.707000    RUS           63  0 days 00:01:25.819000
# 829  0 days 01:22:50.177000    HAM           44  0 days 00:01:25.990000
# 838  0 days 01:14:34.691000    NOR            4  0 days 00:01:26.030000
# 850  0 days 01:22:38.775000    VER            1  0 days 00:01:26.203000
# 860  0 days 01:14:22.585000    PIA           81  0 days 00:01:26.237000
#
#      LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 819       25.0    7.0        NaT       NaT  0 days 00:00:28.016000
# 829       24.0    7.0        NaT       NaT  0 days 00:00:27.990000
# 838       19.0    5.0        NaT       NaT  0 days 00:00:28.025000
# 850       23.0    6.0        NaT       NaT  0 days 00:00:28.136000
# 860       20.0    5.0        NaT       NaT  0 days 00:00:28.043000
#
#                 Sector2Time             Sector3Time      Sector1SessionTime  \
# 819  0 days 00:00:34.508000  0 days 00:00:23.295000  0 days 01:22:03.904000
# 829  0 days 00:00:34.618000  0 days 00:00:23.382000  0 days 01:21:52.177000
# 838  0 days 00:00:34.567000  0 days 00:00:23.438000  0 days 01:13:36.686000
# 850  0 days 00:00:34.587000  0 days 00:00:23.480000  0 days 01:21:40.708000
# 860  0 days 00:00:34.701000  0 days 00:00:23.493000  0 days 01:13:24.391000
#
#          Sector2SessionTime      Sector3SessionTime  SpeedI1  SpeedI2  \
# 819  0 days 01:22:38.412000  0 days 01:23:01.707000    314.0    269.0
# 829  0 days 01:22:26.795000  0 days 01:22:50.177000    312.0    269.0
# 838  0 days 01:14:11.253000  0 days 01:14:34.691000    307.0    268.0
# 850  0 days 01:22:15.295000  0 days 01:22:38.775000    313.0    264.0
# 860  0 days 01:13:59.092000  0 days 01:14:22.585000    309.0    270.0
#
#      SpeedFL  SpeedST IsPersonalBest Compound  TyreLife FreshTyre  \
# 819    252.0    323.0           True     SOFT       2.0      True
# 829    249.0    322.0           True     SOFT       2.0      True
# 838    254.0    317.0           True     SOFT       2.0      True
# 850    252.0    322.0           True     SOFT       2.0      True
# 860    254.0    321.0           True     SOFT       2.0      True
#
#                 Team            LapStartTime             LapStartDate  \
# 819         Mercedes  0 days 01:21:35.888000  2024-07-06 15:08:48.897
# 829         Mercedes  0 days 01:21:24.187000  2024-07-06 15:08:37.196
# 838          McLaren  0 days 01:13:08.661000  2024-07-06 15:00:21.670
# 850  Red Bull Racing  0 days 01:21:12.572000  2024-07-06 15:08:25.581
# 860          McLaren  0 days 01:12:56.348000  2024-07-06 15:00:09.357
#
#     TrackStatus  Position  Deleted DeletedReason  FastF1Generated IsAccurate  \
# 819           1       NaN    False                          False       True
# 829           1       NaN    False                          False       True
# 838           1       NaN    False                          False       True
# 850           1       NaN    False                          False       True
# 860           1       NaN    False                          False       True
#
#      Year                  GP  RK            LapTimeDelta    LapTimeDelta2
# 819  2024  British Grand Prix   1 1970-01-01 00:00:00.000         00:00:00
# 829  2024  British Grand Prix   1 1970-01-01 00:00:00.171  00:00:00.171000
# 838  2024  British Grand Prix   1 1970-01-01 00:00:00.211  00:00:00.211000
# 850  2024  British Grand Prix   1 1970-01-01 00:00:00.384  00:00:00.384000
# 860  2024  British Grand Prix   1 1970-01-01 00:00:00.418  00:00:00.418000

# %%
fig=px.bar(
    track_fastest,
    y="Driver",
    x='LapTimeDelta',
    text='LapTimeDelta2',
    orientation='h',
    color='Driver',
    # template="plotly_dark",
    title="<b>Qualifying Results for the {} {}</b>".format(year,gp),
    height=800, width=1200,

color_discrete_map={
                 "ALB": "#64C4FF",
                 "ALO": "#229971",
                 "BOT": "#52e252",
                 "GAS": "#0093cc",
                 "HAM": "#27F4D2",
                 "HUL": "#B6BABD",
                 "LEC": "#E80020",
                 "MAG": "#B6BABD",
                 "NOR": "#FF8000",
                 "OCO": "#0093cc",
                 "PER": "#3671C6",
                 "PIA": "#FF8000",
                 "RIC": "#6692FF",
                 "RUS": "#27F4D2",
                 "SAI": "#E80020",
                 "SAR": "#37BEDD",
                 "STR": "#229971",
                 "TSU": "#6692FF",
                 "VER": "#3671C6",
                 "ZHO": "#52e252"
                 }
)
fig.update_layout(
    yaxis = dict(tickfont = dict(size=20)),
    xaxis = dict(tickfont = dict(size=20)),

    xaxis_title="<b>Delta</b>",
    yaxis_title="<b>Driver</b>",
    # font_family="Courier New",
    # font_color="blue",
    title_font_family="<b>PT Sans Narrow</b>",
    # title_font_color="red",
    # legend_title_font_color="green"

#  "Arial", "Balto", "Courier New", "Droid Sans", "Droid Serif", "Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans", "Overpass", "PT Sans Narrow", "Raleway", "Times New Roman"
)


# fig['layout']['yaxis']['autorange'] = "reversed"
# fig['layout']['xaxis']['autorange'] = "reversed"
fig.update_layout(xaxis_tickformat='%H:%M:%S.%f')

fig.update_traces(marker_line_width=1,marker_line_color="BLACK")

fig.update_layout(yaxis={'categoryorder':'total descending'})

fig.update_traces(textposition='auto')

fig.update_layout(
    title_x=0.5,
    yaxis = dict(tickfont = dict(size=20)),
    xaxis = dict(tickfont = dict(size=20)),
    font=dict(
        family="PT Sans Narrow",
        size=14,
        color="Black"
    ),
    title_font_family="PT Sans Narrow"
#  "Arial", "Balto", "Courier New", "Droid Sans", "Droid Serif", "Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans", "Overpass", "PT Sans Narrow", "Raleway", "Times New Roman"
)

fig.show()

# %%
fig.write_html("{} {} Qualifying Overview.html".format(year,gp))
